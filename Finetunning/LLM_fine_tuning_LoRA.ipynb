# %% [markdown]
# # <font color='orange'><b>LORA를 활용한 LLM fine-tuning with Ko-Platypus🥮</b></font>
#
#
# [Ko-platypus](https://github.com/Marker-Inc-Korea/KO-Platypus)

# %% [markdown]
# -------
# ## 1. Colab 환경설정👨‍💻
# - Colab Pro
# - GPU A100 활용
#
#
# ## 2. Ko-Platypus 실습내용📖
# > 이번 실습코드에서 다뤄질 내용들은 다음과 같이 6개로 구성되어 있습니다!
#
# - Code 환경설정
# - Hyperparameters in LLM
# - <font color='orange'><b>LoRA🔥</b></font>
# - Instruction input-output dataset
# - <font color='orange'><b>LLM fine-tuning🤗</b></font> (with ko-openorca dataset🐳)
# - <font color='yellow'><b>⭐Model Upload⭐</b></font>
#
#
# ## 3. 실습에 이용되는 데이터셋과 모델📖
# - ✅데이터: [kyujinpy/Open-platypus-Commercial](https://huggingface.co/datasets/YuminKim/KoCoSa)
# - ✅모델: [upstage/SOLAR-10.7B-v1.0](https://huggingface.co/Bllossom/llama-3.2-Korean-Bllossom-3B)
#
#
# ## 4. 참고자료
# - ⭐[Platypus](https://github.com/arielnlee/Platypus)
# - ⭐[garage-bAInd/Open-Platypus](https://huggingface.co/datasets/garage-bAInd/Open-Platypus)
# - ⭐[KO-Platypus2-7B-ex🥮](https://huggingface.co/kyujinpy/KO-Platypus2-7B-ex)
# - [HuggingFace](https://huggingface.co/)
# - [KO-LLM LeaderBoard](https://huggingface.co/spaces/upstage/open-ko-llm-leaderboard)
# - [EN-LLM LeaderBoard](https://huggingface.co/spaces/HuggingFaceH4/open_llm_leaderboard)

# %% [markdown]
# --------
# # 👨‍💻 HuggingFace 로그인
# > 본격적인 시작에 앞서서 Huggingface에 회원가입을 진행해볼까요?
#
# 1. 아래의 링크로 접속하여 회원가입을 진행합니다.
#   - 🤗https://huggingface.co/
#
# 2. 자신의 Access token을 생성합니다.
#   - ✅(메인 화면) 우측 상단의 자신의 프로필을 클릭한 후, `setting`을 누른다.
#   - ✅(프로필 화면) 왼쪽 카테고리에서 `Access Token`을 누른다.
#   - ✅오른쪽에서 `New token` 눌러서 `Role: read`로 설정한 후 자신의 token을 생성한다.
#   - ✅다시 한번, `New token` 눌러서 `Role: write`로 설정한 후 자신의 token을 생성한다.
#
# 3. 코드에서 Huggingface login 진행을 합니다.
#   - ⭐`Role: read`로 생성된 token을 복사 한 후, 아래의 `[...read_token...]` 부분에 붙여넣는다.
# ```python
# !huggingface-cli login --token [...read_token...]
# ```

# %%
###########################################
# 0. Huggingface login

# READ token
# !huggingface-cli login --token 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 # your code
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: read).
# The token `UpStage` has been saved to /root/.cache/huggingface/stored_tokens
# Your token has been saved to /root/.cache/huggingface/token
# Login successful.
# The current active token is: `UpStage`

# %% [markdown]
# --------
# # 😎 Colab 환경설정
# > 본격적인 시작에 앞서서 colab의 환경설정을 진행해볼까요?
#
# 🔎 LLM을 훈련시키기 위해서 아래의 모듈을 필수적으로 설치해야합니다!
# - 🤗transformers: LLM fine-tuning 및 전반적인 기능
# - 🤗bitsandbytes: bit 단위로 모델을 불러올 수 있는 기능
# - 🤗accelerate: GPU 가속
# - 🔥loralib: LoRA 세팅
# - 🤗datasets: 데이터셋 활용
# - 💎peft: Parameter Efficient Fine Tuning 적용

# %%
###########################################
# 1-1. 구글 드라이브 마운트

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
###########################################
# 1-2. 프로젝트 폴더 만들기

import os
os.makedirs('/content/drive/MyDrive/Sarcasm-LLM', exist_ok=True)

# %%
# %cd /content/drive/MyDrive/Sarcasm-LLM
# Out:
# /content/drive/MyDrive/Sarcasm-LLM

# %%
##########################################
# 1-3. 모듈 다운

# !pip install bitsandbytes
# !pip install accelerate
# !pip install appdirs
# !pip install loralib
# !pip install black black[jupyter]
# !pip install datasets
# !pip install fire
# !pip install git+https://github.com/huggingface/peft
# !pip install transformers
# !pip install sentencepiece sentence_transformers
# !pip install scipy numpy scikit-learn pandas
# Out:
# Requirement already satisfied: bitsandbytes in /usr/local/lib/python3.11/dist-packages (0.45.5)
# Requirement already satisfied: torch<3,>=2.0 in /usr/local/lib/python3.11/dist-packages (from bitsandbytes) (2.6.0+cu124)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from bitsandbytes) (2.0.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch<3,>=2.0->bitsandbytes) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch<3,>=2.0->bitsandbytes) (3.0.2)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.11/dist-packages (1.6.0)
# Requirement already satisfied: numpy<3.0.0,>=1.17 in /usr/local/lib/python3.11/dist-packages (from accelerate) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from accelerate) (24.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from accelerate) (6.0.2)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from accelerate) (2.6.0+cu124)
# Requirement already satisfied: huggingface-hub>=0.21.0 in /usr/local/lib/python3.11/dist-packages (from accelerate) (0.30.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from accelerate) (0.5.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.21.0->accelerate) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.21.0->accelerate) (2025.3.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.21.0->accelerate) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.21.0->accelerate) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.21.0->accelerate) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.0.0->accelerate) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.0.0->accelerate) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.21.0->accelerate) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.21.0->accelerate) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.21.0->accelerate) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.21.0->accelerate) (2025.1.31)
# Requirement already satisfied: appdirs in /usr/local/lib/python3.11/dist-packages (1.4.4)
# Requirement already satisfied: loralib in /usr/local/lib/python3.11/dist-packages (0.1.2)
# Requirement already satisfied: black in /usr/local/lib/python3.11/dist-packages (25.1.0)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from black) (8.1.8)
# Requirement already satisfied: mypy-extensions>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from black) (1.1.0)
# Requirement already satisfied: packaging>=22.0 in /usr/local/lib/python3.11/dist-packages (from black) (24.2)
# Requirement already satisfied: pathspec>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from black) (0.12.1)
# Requirement already satisfied: platformdirs>=2 in /usr/local/lib/python3.11/dist-packages (from black) (4.3.7)
# Requirement already satisfied: ipython>=7.8.0 in /usr/local/lib/python3.11/dist-packages (from black[jupyter]) (7.34.0)
# Requirement already satisfied: tokenize-rt>=3.2.0 in /usr/local/lib/python3.11/dist-packages (from black[jupyter]) (6.1.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.11/dist-packages (from ipython>=7.8.0->black[jupyter]) (75.2.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.11/dist-packages (from ipython>=7.8.0->black[jupyter]) (0.19.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from ipython>=7.8.0->black[jupyter]) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.11/dist-packages (from ipython>=7.8.0->black[jupyter]) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.11/dist-packages (from ipython>=7.8.0->black[jupyter]) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ipython>=7.8.0->black[jupyter]) (3.0.51)
# Requirement already satisfied: pygments in /usr/local/lib/python3.11/dist-packages (from ipython>=7.8.0->black[jupyter]) (2.19.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.11/dist-packages (from ipython>=7.8.0->black[jupyter]) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.11/dist-packages (from ipython>=7.8.0->black[jupyter]) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from ipython>=7.8.0->black[jupyter]) (4.9.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->ipython>=7.8.0->black[jupyter]) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.11/dist-packages (from pexpect>4.3->ipython>=7.8.0->black[jupyter]) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.8.0->black[jupyter]) (0.2.13)
# Requirement already satisfied: datasets in /usr/local/lib/python3.11/dist-packages (3.5.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets) (3.18.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.0.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.11/dist-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2025.3.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets) (3.11.15)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.30.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.20.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24.0->datasets) (4.13.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2025.1.31)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Requirement already satisfied: fire in /usr/local/lib/python3.11/dist-packages (0.7.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.11/dist-packages (from fire) (3.0.1)
# Collecting git+https://github.com/huggingface/peft
#   Cloning https://github.com/huggingface/peft to /tmp/pip-req-build-734u65cx
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/peft /tmp/pip-req-build-734u65cx
#   Resolved https://github.com/huggingface/peft to commit cf75e4aed19ae5379c5aa8ed47d54f79d011eec0
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from peft==0.15.2.dev0) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from peft==0.15.2.dev0) (24.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from peft==0.15.2.dev0) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from peft==0.15.2.dev0) (6.0.2)
# Requirement already satisfied: torch>=1.13.0 in /usr/local/lib/python3.11/dist-packages (from peft==0.15.2.dev0) (2.6.0+cu124)
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (from peft==0.15.2.dev0) (4.51.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from peft==0.15.2.dev0) (4.67.1)
# Requirement already satisfied: accelerate>=0.21.0 in /usr/local/lib/python3.11/dist-packages (from peft==0.15.2.dev0) (1.6.0)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.11/dist-packages (from peft==0.15.2.dev0) (0.5.3)
# Requirement already satisfied: huggingface_hub>=0.25.0 in /usr/local/lib/python3.11/dist-packages (from peft==0.15.2.dev0) (0.30.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface_hub>=0.25.0->peft==0.15.2.dev0) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub>=0.25.0->peft==0.15.2.dev0) (2025.3.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface_hub>=0.25.0->peft==0.15.2.dev0) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub>=0.25.0->peft==0.15.2.dev0) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.15.2.dev0) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.15.2.dev0) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.15.2.dev0) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.15.2.dev0) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.15.2.dev0) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.15.2.dev0) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.15.2.dev0) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.15.2.dev0) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.15.2.dev0) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.15.2.dev0) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.15.2.dev0) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.15.2.dev0) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.15.2.dev0) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.15.2.dev0) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.15.2.dev0) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.15.2.dev0) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.15.2.dev0) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.13.0->peft==0.15.2.dev0) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers->peft==0.15.2.dev0) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers->peft==0.15.2.dev0) (0.21.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.13.0->peft==0.15.2.dev0) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub>=0.25.0->peft==0.15.2.dev0) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub>=0.25.0->peft==0.15.2.dev0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub>=0.25.0->peft==0.15.2.dev0) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub>=0.25.0->peft==0.15.2.dev0) (2025.1.31)
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.51.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.30.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (4.13.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.1.31)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.11/dist-packages (0.2.0)
# Requirement already satisfied: sentence_transformers in /usr/local/lib/python3.11/dist-packages (3.4.1)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /usr/local/lib/python3.11/dist-packages (from sentence_transformers) (4.51.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from sentence_transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from sentence_transformers) (2.6.0+cu124)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from sentence_transformers) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from sentence_transformers) (1.15.2)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /usr/local/lib/python3.11/dist-packages (from sentence_transformers) (0.30.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from sentence_transformers) (11.2.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence_transformers) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence_transformers) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence_transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence_transformers) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence_transformers) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence_transformers) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence_transformers) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence_transformers) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence_transformers) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence_transformers) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence_transformers) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence_transformers) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence_transformers) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence_transformers) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence_transformers) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence_transformers) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence_transformers) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence_transformers) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence_transformers) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence_transformers) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence_transformers) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence_transformers) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence_transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.11.0->sentence_transformers) (1.3.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (2.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (0.5.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->sentence_transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->sentence_transformers) (3.6.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.11.0->sentence_transformers) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence_transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence_transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence_transformers) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence_transformers) (2025.1.31)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (1.15.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (2.0.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
###########################################
# 1-4. 설치된 모듈 리스트 확인하기
# !pip check
# !pip list
# Out:
# gcsfs 2025.3.2 has requirement fsspec==2025.3.2, but you have fsspec 2025.3.0.
# Package                               Version
# ------------------------------------- ------------------
# absl-py                               1.4.0
# accelerate                            1.6.0
# aiohappyeyeballs                      2.6.1
# aiohttp                               3.11.15
# aiosignal                             1.3.2
# alabaster                             1.0.0
# albucore                              0.0.23
# albumentations                        2.0.5
# ale-py                                0.10.2
# altair                                5.5.0
# annotated-types                       0.7.0
# anyio                                 4.9.0
# appdirs                               1.4.4
# argon2-cffi                           23.1.0
# argon2-cffi-bindings                  21.2.0
# array_record                          0.7.1
# arviz                                 0.21.0
# astropy                               7.0.1
# astropy-iers-data                     0.2025.4.21.0.37.6
# astunparse                            1.6.3
# atpublic                              5.1
# attrs                                 25.3.0
# audioread                             3.0.1
# autograd                              1.7.0
# babel                                 2.17.0
# backcall                              0.2.0
# backports.tarfile                     1.2.0
# beautifulsoup4                        4.13.4
# betterproto                           2.0.0b6
# bigframes                             2.1.0
# bigquery-magics                       0.9.0
# bitsandbytes                          0.45.5
# black                                 25.1.0
# bleach                                6.2.0
# blinker                               1.9.0
# blis                                  1.3.0
# blosc2                                3.3.1
# bokeh                                 3.7.2
# Bottleneck                            1.4.2
# bqplot                                0.12.44
# branca                                0.8.1
# build                                 1.2.2.post1
# CacheControl                          0.14.2
# cachetools                            5.5.2
# catalogue                             2.0.10
# certifi                               2025.1.31
# cffi                                  1.17.1
# chardet                               5.2.0
# charset-normalizer                    3.4.1
# chex                                  0.1.89
# clarabel                              0.10.0
# click                                 8.1.8
# cloudpathlib                          0.21.0
# cloudpickle                           3.1.1
# cmake                                 3.31.6
# cmdstanpy                             1.2.5
# colorcet                              3.1.0
# colorlover                            0.3.0
# colour                                0.1.5
# community                             1.0.0b1
# confection                            0.1.5
# cons                                  0.4.6
# contourpy                             1.3.2
# cramjam                               2.10.0
# cryptography                          43.0.3
# cuda-python                           12.6.2.post1
# cudf-cu12                             25.2.1
# cudf-polars-cu12                      25.2.2
# cufflinks                             0.17.3
# cuml-cu12                             25.2.1
# cupy-cuda12x                          13.3.0
# cuvs-cu12                             25.2.1
# cvxopt                                1.3.2
# cvxpy                                 1.6.5
# cycler                                0.12.1
# cyipopt                               1.5.0
# cymem                                 2.0.11
# Cython                                3.0.12
# dask                                  2024.12.1
# dask-cuda                             25.2.0
# dask-cudf-cu12                        25.2.2
# dask-expr                             1.1.21
# datascience                           0.17.6
# datasets                              3.5.1
# db-dtypes                             1.4.2
# dbus-python                           1.2.18
# debugpy                               1.8.0
# decorator                             4.4.2
# defusedxml                            0.7.1
# Deprecated                            1.2.18
# diffusers                             0.33.1
# dill                                  0.3.8
# distributed                           2024.12.1
# distributed-ucxx-cu12                 0.42.0
# distro                                1.9.0
# dlib                                  19.24.6
# dm-tree                               0.1.9
# docker-pycreds                        0.4.0
# docstring_parser                      0.16
# docutils                              0.21.2
# dopamine_rl                           4.1.2
# duckdb                                1.2.2
# earthengine-api                       1.5.12
# easydict                              1.13
# editdistance                          0.8.1
# eerepr                                0.1.1
# einops                                0.8.1
# en_core_web_sm                        3.8.0
# entrypoints                           0.4
# et_xmlfile                            2.0.0
# etils                                 1.12.2
# etuples                               0.3.9
# Farama-Notifications                  0.0.4
# fastai                                2.7.19
# fastcore                              1.7.29
# fastdownload                          0.0.7
# fastjsonschema                        2.21.1
# fastprogress                          1.0.3
# fastrlock                             0.8.3
# filelock                              3.18.0
# fire                                  0.7.0
# firebase-admin                        6.8.0
# Flask                                 3.1.0
# flatbuffers                           25.2.10
# flax                                  0.10.6
# folium                                0.19.5
# fonttools                             4.57.0
# frozendict                            2.4.6
# frozenlist                            1.6.0
# fsspec                                2025.3.0
# future                                1.0.0
# gast                                  0.6.0
# gcsfs                                 2025.3.2
# GDAL                                  3.6.4
# gdown                                 5.2.0
# geemap                                0.35.3
# geocoder                              1.38.1
# geographiclib                         2.0
# geopandas                             1.0.1
# geopy                                 2.4.1
# gin-config                            0.5.0
# gitdb                                 4.0.12
# GitPython                             3.1.44
# glob2                                 0.7
# google                                2.0.3
# google-ai-generativelanguage          0.6.15
# google-api-core                       2.24.2
# google-api-python-client              2.168.0
# google-auth                           2.38.0
# google-auth-httplib2                  0.2.0
# google-auth-oauthlib                  1.2.2
# google-cloud-aiplatform               1.90.0
# google-cloud-bigquery                 3.31.0
# google-cloud-bigquery-connection      1.18.2
# google-cloud-bigquery-storage         2.31.0
# google-cloud-bigtable                 2.30.1
# google-cloud-core                     2.4.3
# google-cloud-dataproc                 5.18.1
# google-cloud-datastore                2.21.0
# google-cloud-firestore                2.20.2
# google-cloud-functions                1.20.3
# google-cloud-iam                      2.19.0
# google-cloud-language                 2.17.1
# google-cloud-pubsub                   2.29.0
# google-cloud-resource-manager         1.14.2
# google-cloud-spanner                  3.53.0
# google-cloud-storage                  2.19.0
# google-cloud-translate                3.20.2
# google-colab                          1.0.0
# google-crc32c                         1.7.1
# google-genai                          1.12.1
# google-generativeai                   0.8.5
# google-pasta                          0.2.0
# google-resumable-media                2.7.2
# google-spark-connect                  0.5.2
# googleapis-common-protos              1.70.0
# googledrivedownloader                 1.1.0
# graphviz                              0.20.3
# greenlet                              3.2.1
# grpc-google-iam-v1                    0.14.2
# grpc-interceptor                      0.15.4
# grpcio                                1.71.0
# grpcio-status                         1.71.0
# grpclib                               0.4.7
# gspread                               6.2.0
# gspread-dataframe                     4.0.0
# gym                                   0.25.2
# gym-notices                           0.0.8
# gymnasium                             1.1.1
# h11                                   0.16.0
# h2                                    4.2.0
# h5netcdf                              1.6.1
# h5py                                  3.13.0
# hdbscan                               0.8.40
# highspy                               1.10.0
# holidays                              0.71
# holoviews                             1.20.2
# hpack                                 4.1.0
# html5lib                              1.1
# httpcore                              1.0.9
# httpimport                            1.4.1
# httplib2                              0.22.0
# httpx                                 0.28.1
# huggingface-hub                       0.30.2
# humanize                              4.12.2
# hyperframe                            6.1.0
# hyperopt                              0.2.7
# ibis-framework                        9.5.0
# idna                                  3.10
# imageio                               2.37.0
# imageio-ffmpeg                        0.6.0
# imagesize                             1.4.1
# imbalanced-learn                      0.13.0
# immutabledict                         4.2.1
# importlib_metadata                    8.6.1
# importlib_resources                   6.5.2
# imutils                               0.5.4
# inflect                               7.5.0
# iniconfig                             2.1.0
# intel-cmplr-lib-ur                    2025.1.0
# intel-openmp                          2025.1.0
# ipyevents                             2.0.2
# ipyfilechooser                        0.6.0
# ipykernel                             6.17.1
# ipyleaflet                            0.19.2
# ipyparallel                           8.8.0
# ipython                               7.34.0
# ipython-genutils                      0.2.0
# ipython-sql                           0.5.0
# ipytree                               0.2.2
# ipywidgets                            7.7.1
# itsdangerous                          2.2.0
# jaraco.classes                        3.4.0
# jaraco.context                        6.0.1
# jaraco.functools                      4.1.0
# jax                                   0.5.2
# jax-cuda12-pjrt                       0.5.1
# jax-cuda12-plugin                     0.5.1
# jaxlib                                0.5.1
# jedi                                  0.19.2
# jeepney                               0.9.0
# jieba                                 0.42.1
# Jinja2                                3.1.6
# jiter                                 0.9.0
# joblib                                1.4.2
# jsonpatch                             1.33
# jsonpickle                            4.0.5
# jsonpointer                           3.0.0
# jsonschema                            4.23.0
# jsonschema-specifications             2025.4.1
# jupyter-client                        6.1.12
# jupyter-console                       6.1.0
# jupyter_core                          5.7.2
# jupyter-leaflet                       0.19.2
# jupyter-server                        1.16.0
# jupyterlab_pygments                   0.3.0
# jupyterlab_widgets                    3.0.14
# kaggle                                1.7.4.2
# kagglehub                             0.3.12
# keras                                 3.8.0
# keras-hub                             0.18.1
# keras-nlp                             0.18.1
# keyring                               25.6.0
# keyrings.google-artifactregistry-auth 1.1.2
# kiwisolver                            1.4.8
# langchain                             0.3.24
# langchain-core                        0.3.56
# langchain-text-splitters              0.3.8
# langcodes                             3.5.0
# langsmith                             0.3.34
# language_data                         1.3.0
# launchpadlib                          1.10.16
# lazr.restfulclient                    0.14.4
# lazr.uri                              1.0.6
# lazy_loader                           0.4
# libclang                              18.1.1
# libcudf-cu12                          25.2.1
# libcugraph-cu12                       25.2.0
# libcuml-cu12                          25.2.1
# libcuvs-cu12                          25.2.1
# libkvikio-cu12                        25.2.1
# libraft-cu12                          25.2.0
# librosa                               0.11.0
# libucx-cu12                           1.18.0.post1
# libucxx-cu12                          0.42.0
# lightgbm                              4.5.0
# linkify-it-py                         2.0.3
# llvmlite                              0.43.0
# locket                                1.0.0
# logical-unification                   0.4.6
# loralib                               0.1.2
# lxml                                  5.4.0
# Mako                                  1.1.3
# marisa-trie                           1.2.1
# Markdown                              3.8
# markdown-it-py                        3.0.0
# MarkupSafe                            3.0.2
# matplotlib                            3.10.0
# matplotlib-inline                     0.1.7
# matplotlib-venn                       1.1.2
# mdit-py-plugins                       0.4.2
# mdurl                                 0.1.2
# miniKanren                            1.0.3
# missingno                             0.5.2
# mistune                               3.1.3
# mizani                                0.13.3
# mkl                                   2025.0.1
# ml-dtypes                             0.4.1
# mlxtend                               0.23.4
# more-itertools                        10.7.0
# moviepy                               1.0.3
# mpmath                                1.3.0
# msgpack                               1.1.0
# multidict                             6.4.3
# multipledispatch                      1.0.0
# multiprocess                          0.70.16
# multitasking                          0.0.11
# murmurhash                            1.0.12
# music21                               9.3.0
# mypy_extensions                       1.1.0
# namex                                 0.0.9
# narwhals                              1.36.0
# natsort                               8.4.0
# nbclassic                             1.3.0
# nbclient                              0.10.2
# nbconvert                             7.16.6
# nbformat                              5.10.4
# ndindex                               1.9.2
# nest-asyncio                          1.6.0
# networkx                              3.4.2
# nibabel                               5.3.2
# nltk                                  3.9.1
# notebook                              6.5.7
# notebook_shim                         0.2.4
# numba                                 0.60.0
# numba-cuda                            0.2.0
# numexpr                               2.10.2
# numpy                                 2.0.2
# nvidia-cublas-cu12                    12.4.5.8
# nvidia-cuda-cupti-cu12                12.4.127
# nvidia-cuda-nvcc-cu12                 12.5.82
# nvidia-cuda-nvrtc-cu12                12.4.127
# nvidia-cuda-runtime-cu12              12.4.127
# nvidia-cudnn-cu12                     9.1.0.70
# nvidia-cufft-cu12                     11.2.1.3
# nvidia-curand-cu12                    10.3.5.147
# nvidia-cusolver-cu12                  11.6.1.9
# nvidia-cusparse-cu12                  12.3.1.170
# nvidia-cusparselt-cu12                0.6.2
# nvidia-ml-py                          12.570.86
# nvidia-nccl-cu12                      2.21.5
# nvidia-nvcomp-cu12                    4.2.0.11
# nvidia-nvjitlink-cu12                 12.4.127
# nvidia-nvtx-cu12                      12.4.127
# nvtx                                  0.2.11
# nx-cugraph-cu12                       25.2.0
# oauth2client                          4.1.3
# oauthlib                              3.2.2
# openai                                1.76.0
# opencv-contrib-python                 4.11.0.86
# opencv-python                         4.11.0.86
# opencv-python-headless                4.11.0.86
# openpyxl                              3.1.5
# opentelemetry-api                     1.32.1
# opentelemetry-sdk                     1.32.1
# opentelemetry-semantic-conventions    0.53b1
# opt_einsum                            3.4.0
# optax                                 0.2.4
# optree                                0.15.0
# orbax-checkpoint                      0.11.12
# orjson                                3.10.16
# osqp                                  1.0.3
# packaging                             24.2
# pandas                                2.2.2
# pandas-datareader                     0.10.0
# pandas-gbq                            0.28.0
# pandas-stubs                          2.2.2.240909
# pandocfilters                         1.5.1
# panel                                 1.6.3
# param                                 2.2.0
# parso                                 0.8.4
# parsy                                 2.1
# partd                                 1.4.2
# pathlib                               1.0.1
# pathspec                              0.12.1
# patsy                                 1.0.1
# peewee                                3.17.9
# peft                                  0.15.2.dev0
# pexpect                               4.9.0
# pickleshare                           0.7.5
# pillow                                11.2.1
# pip                                   24.1.2
# platformdirs                          4.3.7
# plotly                                5.24.1
# plotnine                              0.14.5
# pluggy                                1.5.0
# ply                                   3.11
# polars                                1.21.0
# pooch                                 1.8.2
# portpicker                            1.5.2
# preshed                               3.0.9
# prettytable                           3.16.0
# proglog                               0.1.11
# progressbar2                          4.5.0
# prometheus_client                     0.21.1
# promise                               2.3
# prompt_toolkit                        3.0.51
# propcache                             0.3.1
# prophet                               1.1.6
# proto-plus                            1.26.1
# protobuf                              5.29.4
# psutil                                5.9.5
# psycopg2                              2.9.10
# ptyprocess                            0.7.0
# py-cpuinfo                            9.0.0
# py4j                                  0.10.9.7
# pyarrow                               18.1.0
# pyasn1                                0.6.1
# pyasn1_modules                        0.4.2
# pycairo                               1.28.0
# pycocotools                           2.0.8
# pycparser                             2.22
# pydantic                              2.11.3
# pydantic_core                         2.33.1
# pydata-google-auth                    1.9.1
# pydot                                 3.0.4
# pydotplus                             2.0.2
# PyDrive                               1.3.1
# PyDrive2                              1.21.3
# pyerfa                                2.0.1.5
# pygame                                2.6.1
# pygit2                                1.18.0
# Pygments                              2.19.1
# PyGObject                             3.42.0
# PyJWT                                 2.10.1
# pylibcudf-cu12                        25.2.1
# pylibcugraph-cu12                     25.2.0
# pylibraft-cu12                        25.2.0
# pymc                                  5.22.0
# pymystem3                             0.2.0
# pynndescent                           0.5.13
# pynvjitlink-cu12                      0.5.2
# pynvml                                12.0.0
# pyogrio                               0.10.0
# pyomo                                 6.9.2
# PyOpenGL                              3.1.9
# pyOpenSSL                             24.2.1
# pyparsing                             3.2.3
# pyperclip                             1.9.0
# pyproj                                3.7.1
# pyproject_hooks                       1.2.0
# pyshp                                 2.3.1
# PySocks                               1.7.1
# pyspark                               3.5.5
# pytensor                              2.30.3
# pytest                                8.3.5
# python-apt                            0.0.0
# python-box                            7.3.2
# python-dateutil                       2.9.0.post0
# python-louvain                        0.16
# python-slugify                        8.0.4
# python-snappy                         0.7.3
# python-utils                          3.9.1
# pytz                                  2025.2
# pyviz_comms                           3.0.4
# PyYAML                                6.0.2
# pyzmq                                 24.0.1
# raft-dask-cu12                        25.2.0
# rapids-dask-dependency                25.2.0
# ratelim                               0.1.6
# referencing                           0.36.2
# regex                                 2024.11.6
# requests                              2.32.3
# requests-oauthlib                     2.0.0
# requests-toolbelt                     1.0.0
# requirements-parser                   0.9.0
# rich                                  13.9.4
# rmm-cu12                              25.2.0
# roman-numerals-py                     3.1.0
# rpds-py                               0.24.0
# rpy2                                  3.5.17
# rsa                                   4.9.1
# safetensors                           0.5.3
# scikit-image                          0.25.2
# scikit-learn                          1.6.1
# scipy                                 1.15.2
# scooby                                0.10.0
# scs                                   3.2.7.post2
# seaborn                               0.13.2
# SecretStorage                         3.3.3
# Send2Trash                            1.8.3
# sentence-transformers                 3.4.1
# sentencepiece                         0.2.0
# sentry-sdk                            2.27.0
# setproctitle                          1.3.5
# setuptools                            75.2.0
# shap                                  0.47.2
# shapely                               2.1.0
# shellingham                           1.5.4
# simple-parsing                        0.1.7
# simplejson                            3.20.1
# simsimd                               6.2.1
# six                                   1.17.0
# sklearn-compat                        0.1.3
# sklearn-pandas                        2.2.0
# slicer                                0.0.8
# smart-open                            7.1.0
# smmap                                 5.0.2
# sniffio                               1.3.1
# snowballstemmer                       2.2.0
# sortedcontainers                      2.4.0
# soundfile                             0.13.1
# soupsieve                             2.7
# soxr                                  0.5.0.post1
# spacy                                 3.8.5
# spacy-legacy                          3.0.12
# spacy-loggers                         1.0.5
# spanner-graph-notebook                1.1.6
# Sphinx                                8.2.3
# sphinxcontrib-applehelp               2.0.0
# sphinxcontrib-devhelp                 2.0.0
# sphinxcontrib-htmlhelp                2.1.0
# sphinxcontrib-jsmath                  1.0.1
# sphinxcontrib-qthelp                  2.0.0
# sphinxcontrib-serializinghtml         2.0.0
# SQLAlchemy                            2.0.40
# sqlglot                               25.20.2
# sqlparse                              0.5.3
# srsly                                 2.5.1
# stanio                                0.5.1
# statsmodels                           0.14.4
# stringzilla                           3.12.5
# sympy                                 1.13.1
# tables                                3.10.2
# tabulate                              0.9.0
# tbb                                   2022.1.0
# tblib                                 3.1.0
# tcmlib                                1.3.0
# tenacity                              9.1.2
# tensorboard                           2.18.0
# tensorboard-data-server               0.7.2
# tensorflow                            2.18.0
# tensorflow-datasets                   4.9.8
# tensorflow_decision_forests           1.11.0
# tensorflow-hub                        0.16.1
# tensorflow-io-gcs-filesystem          0.37.1
# tensorflow-metadata                   1.17.1
# tensorflow-probability                0.25.0
# tensorflow-text                       2.18.1
# tensorstore                           0.1.74
# termcolor                             3.0.1
# terminado                             0.18.1
# text-unidecode                        1.3
# textblob                              0.19.0
# tf_keras                              2.18.0
# tf-slim                               1.1.0
# thinc                                 8.3.6
# threadpoolctl                         3.6.0
# tifffile                              2025.3.30
# timm                                  1.0.15
# tinycss2                              1.4.0
# tokenize_rt                           6.1.0
# tokenizers                            0.21.1
# toml                                  0.10.2
# toolz                                 0.12.1
# torch                                 2.6.0+cu124
# torchaudio                            2.6.0+cu124
# torchsummary                          1.5.1
# torchvision                           0.21.0+cu124
# tornado                               6.4.2
# tqdm                                  4.67.1
# traitlets                             5.7.1
# traittypes                            0.2.1
# transformers                          4.51.3
# treelite                              4.4.1
# treescope                             0.1.9
# triton                                3.2.0
# tweepy                                4.15.0
# typeguard                             4.4.2
# typer                                 0.15.2
# types-pytz                            2025.2.0.20250326
# types-setuptools                      80.0.0.20250429
# typing_extensions                     4.13.2
# typing-inspection                     0.4.0
# tzdata                                2025.2
# tzlocal                               5.3.1
# uc-micro-py                           1.0.3
# ucx-py-cu12                           0.42.0
# ucxx-cu12                             0.42.0
# umap-learn                            0.5.7
# umf                                   0.10.0
# uritemplate                           4.1.1
# urllib3                               2.4.0
# vega-datasets                         0.9.0
# wadllib                               1.3.6
# wandb                                 0.19.10
# wasabi                                1.1.3
# wcwidth                               0.2.13
# weasel                                0.4.1
# webcolors                             24.11.1
# webencodings                          0.5.1
# websocket-client                      1.8.0
# websockets                            15.0.1
# Werkzeug                              3.1.3
# wheel                                 0.45.1
# widgetsnbextension                    3.6.10
# wordcloud                             1.9.4
# wrapt                                 1.17.2
# wurlitzer                             3.1.1
# xarray                                2025.3.1
# xarray-einstats                       0.8.0
# xgboost                               2.1.4
# xlrd                                  2.0.1
# xxhash                                3.5.0
# xyzservices                           2025.1.0
# yarl                                  1.20.0
# ydf                                   0.11.0
# yellowbrick                           1.5
# yfinance                              0.2.56
# zict                                  3.0.0
# zipp                                  3.21.0
# zstandard                             0.23.0

# %% [markdown]
# --------
# # 😎 모듈 불러오기

# %%
###########################################
# 2-1. 모듈 불러오기

import os
import os.path as osp
import sys
import fire
import json
from typing import List, Union

import torch
from torch.nn import functional as F

import transformers
from transformers import TrainerCallback, TrainingArguments, TrainerState, TrainerControl
from transformers.trainer_utils import PREFIX_CHECKPOINT_DIR
from transformers import LlamaForCausalLM, LlamaTokenizer
from transformers import AutoModelForCausalLM, AutoTokenizer

from datasets import load_dataset

from peft import (
    LoraConfig,
    get_peft_model,
    prepare_model_for_kbit_training, #prepare_model_for_int8_training
    set_peft_model_state_dict
)

from peft import PeftModel

# %% [markdown]
# --------
# # 🤗 Base Model (LLM)
# - 우리가 해당 실습코드에서 이용할 base LLM 모델 아래와 같습니다!
#   - ✅모델: [upstage/SOLAR-10.7B-v1.0](https://huggingface.co/upstage/SOLAR-10.7B-v1.0)
#
# ## ✔️ Model Access 확인
# > ✅모델을 이용하기 전에 access가 있는지 꼭 확인하세요!
#
# <img src = "https://drive.google.com/uc?id=1oACzT9OwEAundjhEOBdFI7-nV99OrIm8">
# - 위의 사진과 같은 <font color='#6069B9'><b>**✔️access**</b></font> 버튼이 있다면 꼭 눌러서 승인을 해야합니다!
# - 예를 들어 meta-llama의 모델을 경우, 승인을 받아야 이용이 가능하다는 점도 참고해주세요!
#   - 🤗해당 모델이 아닌 다른 모델을 base LLM으로 활용하셔도 됩니다!
#
# #### 😲 Error Note
# > Colab에서 모델을 다운 받다가 아래와 같은 에러를 만났다면 한번 다음과 같이 해결해보세요!
#
# ```python
# ImportError: Using `load_in_8bit=True` requires Accelerate: `pip install
# accelerate` and the latest version of bitsandbytes `pip install -i https://
# test.pypi.org/simple/ bitsandbytes` or pip install bitsandbytes`
# ```
# - **✅Colab의 런타임 유형이 A100인지 확인.**

# %%
#@title 🤗 Base model 선택하기
device = 'auto' #@param {type: "string"}
base_LLM_model = 'Bllossom/llama-3.2-Korean-Bllossom-3B' #@param {type: "string"}

# %%
###########################################
# 3-1. 모델 다운로드 (~30분)

model = AutoModelForCausalLM.from_pretrained(
    base_LLM_model,
    load_in_8bit=True, # LoRA
    #load_in_4bit=True, # Quantization Load
    torch_dtype=torch.float16,
    device_map=device)

tokenizer = AutoTokenizer.from_pretrained(base_LLM_model)
# Out:
# The `load_in_4bit` and `load_in_8bit` arguments are deprecated and will be removed in the future versions. Please, pass a `BitsAndBytesConfig` object in `quantization_config` argument instead.
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
###########################################
# 3-2. BOS, EOS, PAD 토큰 확인

# Check special token
bos = tokenizer.bos_token_id # 문장 시작 토큰
eos = tokenizer.eos_token_id # 문장 끝 토큰
pad = tokenizer.pad_token_id # 문장 패딩 토큰 -> 문장 끝나고 매꿔주는 패딩 부분
tokenizer.padding_side = "right" # 패딩 오른쪽

print("BOS token:", bos) # 1
print("EOS token:", eos) # 2
print("PAD token:", pad) # None
# Out:
# BOS token: 128000
# EOS token: 128009
# PAD token: None

# %%
if (pad == None) or (pad == eos):
    tokenizer.pad_token_id = 0  # 만약 패딩값이 없거나 eos값과 같다면,
print("length of tokenizer:",len(tokenizer)) # 32000
# Out:
# length of tokenizer: 128256

# %%
print(model)
print(type(model)) # 모델의 타입 확인
# Out:
# LlamaForCausalLM(
#   (model): LlamaModel(
#     (embed_tokens): Embedding(128256, 3072)
#     (layers): ModuleList(
#       (0-27): 28 x LlamaDecoderLayer(
#         (self_attn): LlamaAttention(
#           (q_proj): Linear8bitLt(in_features=3072, out_features=3072, bias=False)
#           (k_proj): Linear8bitLt(in_features=3072, out_features=1024, bias=False)
#           (v_proj): Linear8bitLt(in_features=3072, out_features=1024, bias=False)
#           (o_proj): Linear8bitLt(in_features=3072, out_features=3072, bias=False)
#         )
#         (mlp): LlamaMLP(
#           (gate_proj): Linear8bitLt(in_features=3072, out_features=8192, bias=False)
#           (up_proj): Linear8bitLt(in_features=3072, out_features=8192, bias=False)
#           (down_proj): Linear8bitLt(in_features=8192, out_features=3072, bias=False)
#           (act_fn): SiLU()
#         )
#         (input_layernorm): LlamaRMSNorm((3072,), eps=1e-05)
#         (post_attention_layernorm): LlamaRMSNorm((3072,), eps=1e-05)
#       )
#     )
#     (norm): LlamaRMSNorm((3072,), eps=1e-05)
#     (rotary_emb): LlamaRotaryEmbedding()
#   )
#   (lm_head): Linear(in_features=3072, out_features=128256, bias=False)
# )
# <class 'transformers.models.llama.modeling_llama.LlamaForCausalLM'>

# %% [markdown]
# --------
# # 💡Hyperparameters setting
# > 🔎 LLM fine-tuning에서 중요한 <font color='green'><b>hyperpamaeter</b></font>에 대해서 살펴볼까요?
#
# 1. **📖cutoff_len**
# > 모델에 들어갈 **sequence의 최대 길이를 설정**하는 parameter 입니다!
#
# > base model의 max length(token)확인해야함
#
# 2. **📖warmup_steps**
# > warmup_steps은 천천히 learning rate를 올려서, 학습의 불안정성을 방지해줄 수 있습니다!
#
#   - **Example)** learning rate (LR)을 1e-2로 설정했다면, LR을 처음에 초깃값보다 낮게 시작하여 100 step에 걸쳐서 LR를 1e-2로 올린다.
#
# 3. **📖Optimizer**
# > 최근에는 Adam보다 AdamW를 더 많이 이용하고 있어요!
# > AdamW는 Adam에 비해서 더 <font color='#ea7a7a'><b>general</b></font>하게 성능을 만들어주는 장점이 있습니다!
#
#   - Adam vs <font color='#ea7a7a'><b>**AdamW**</b></font>
#
# 4. **📖lr_scheduler**
# > lr_scheduler는 learning rate를 훈련하는 동안 조절해주는 옵션이예요!
# > 아래의 목록에 있는 총 3가지 함수 옵션이 가장 대표적으로 사용됩니다!
#
#   - constant
#   - linear
#   - <font color='#ea7a7a'><b>consine</b></font>
#
# 5. **📖Others**
# > 😊그 외에 중요한 hyperparameter 옵션들을 모아서 정리해봤어요!
#
#   - **⭐Learning rate**
#   - Batch size
#   - weight_decay
#   - max grad norm: gradient vector 크기 조절 (gradient clipping)

# %% [markdown]
# ## 👨‍💻 LoRA hyperparameters
# > 🔎 PEFT의 대표적인 방법론인 <font color='orange'><b>LoRA🔥</b></font>의 <font color='green'><b>hyperpamaeter</b></font>에 대해서 살펴봅시다!
#
# <img src = "https://drive.google.com/uc?id=1ZoFUOPAyfWx80qk9Oa6b8oY0h1bJRoE0" width=512>
#
#   -  <font color='orange'><b>**Lora_r**</b></font>: LoRA adapter의 차원을 결정하는 파라미터
#   - Lora_alpha: LoRA adapter의 scaling 값을 결정하는 파라미터
#   - Lora_dropout: LoRA adapter의 dropout 파라미터
#   -  <font color='orange'><b>**Lora_target_modules**</b></font>: LoRA adapter를 적용할 layers
#   ```
# Lora_target_modules 종류:
# ["embed_tokens", "lm_head", "q_proj", "k_proj", "v_proj", "o_proj", ...] # in llama2
#   ```
# > 🔎 LoRA가 어떻게 적용되는지 코드로 살펴볼까요?
#
#   ```python
# class Linear(nn.Linear, LoRALayer):
#   # LoRA implemented in a dense layer
#   def __init__(
#           self,
#           in_features: int,
#           out_features: int,
#           r: int = 0,
#           lora_alpha: int = 1,
#           lora_dropout: float = 0.,
#           fan_in_fan_out: bool = False, # Set this to True if the layer to replace stores weight like (fan_in, fan_out)
#           merge_weights: bool = True,
#           **kwargs
#       ):
#           nn.Linear.__init__(self, in_features, out_features, **kwargs)
#           LoRALayer.__init__(self, r=r, lora_alpha=lora_alpha, lora_dropout=lora_dropout,
#                               merge_weights=merge_weights)
#           self.fan_in_fan_out = fan_in_fan_out
#           # 실제 훈련할 파라미터
#           if r > 0:
#               self.lora_A = nn.Parameter(self.weight.new_zeros((r, in_features)))
#               self.lora_B = nn.Parameter(self.weight.new_zeros((out_features, r)))
#               self.scaling = self.lora_alpha / self.r
#               # Freezing the pre-trained weight matrix
#               self.weight.requires_grad = False
#           self.reset_parameters()
#           if fan_in_fan_out:
#             self.weight.data = self.weight.data.transpose(0, 1)
#   ```

# %%
###########################################
# 5-1. 하이퍼 파라미터

# 데이터셋과 훈련 횟수와 관련된 하이퍼 파라미터
batch_size = 32
num_epochs = 1
micro_batch = 1 #GPU가 2대 이상일 때 활용하면 좋다..?
gradient_accumulation_steps = batch_size // micro_batch #GPU가 2대 이상일 때 활용하면 좋다..?

# 훈련 방법에 대한 하이퍼 파라미터
cutoff_len = 1024 # solar 7B max token
lr_scheduler = 'cosine'
warmup_ratio = 0.06 # warmup_steps = 100
learning_rate = 9.5e-4# 4e-4
optimizer = 'adamw_torch'
weight_decay = 0.01
max_grad_norm = 1.0 # Default값, 모델이 과적합되거나 잘못 된거 같으면 좀 줄여주면 좋음

# LoRA config
lora_r = 16
lora_alpha = 16
lora_dropout = 0.1 # 0.05 기호에 따라..
lora_target_modules = ["gate_proj", "down_proj", "up_proj"]

# Tokenizer에서 나오는 input값 설정 옵션
train_on_inputs = False
add_eos_token = False # 데이터 셋에 관한 부분

# Others
resume_from_checkpoint = './sarcasm_LLM/checkpoint-001' # !! 만약 모델을 이어서 훈련하고 싶다면, './custom_LLM/checkpoint-[xxx]'와 같이 파일 경로를 입력해야 합니다!
# 모델 돌다가 다운되는거 방지
output_dir = './custom_LLM'

# %% [markdown]
# --------
# # 🤗 Dataset Loading and formatting
# > 👨‍💻 LLM fine-tuning을 위한 데이터셋을 불러오고 <font color='green'><b>instruction input-output</b></font>형태로 만들어 봅시다!
#
# - 우리가 해당 실습코드에서 이용할 데이터셋은 아래와 같습니다!
#   - ✅데이터: [kyujinpy/Open-platypus-Commercial](https://huggingface.co/datasets/YuminKim/KoCoSa)

# %%
#@title 🤗 Choose Dataset
dataset = 'YuminKim/KoCoSa' #@param {type: "string"}

#kyujinpy/Open-platypus-Commercial

# %%
###########################################
# 5-1. 데이터셋 다운로드

data = load_dataset(dataset)
print(data['train']) # 개수: 19079
# Out:
# Repo card metadata block was not found. Setting CardData to empty.
# WARNING:huggingface_hub.repocard:Repo card metadata block was not found. Setting CardData to empty.
# Dataset({
#     features: ['context', 'response', 'label', 'sarcasm_explanation'],
#     num_rows: 10466
# })

# %%
print(data['validation'])
print(data['test'])
# Out:
# Dataset({
#     features: ['context', 'response', 'label', 'sarcasm_explanation'],
#     num_rows: 1321
# })
# Dataset({
#     features: ['context', 'response', 'label', 'sarcasm_explanation'],
#     num_rows: 1037
# })

# %% [markdown]
# ## 🤗 Instruction input-output template
# > 우리가 활용한 데이터는 아래와 같은 형식을 갖고 있습니다!
#
# - ✅Input이 있는 example:
#
# ```
# Input:
# 당신은 사람들이 정보를 찾을 수 있도록 도와주는 인공지능 비서입니다.
# 사용자가 질문을 합니다. 당신의 임무는 가능한 한 충실하게 대답하는 것입니다.
# 답변하는 동안 단계별로 생각하고 답변을 정당화하세요.
#
# Instruction:
# 질문입니다: 시속 60km의 속도로 달리는 기차가 9초 만에 기둥을 통과합니다. 기차의 길이는 얼마입니까?
# 옵션: (A) 287 (B) 699 (C) 677 (D) 168 (E) 150 먼저 생각해 봅시다. 무작위로 추론해 봅시다:
#
# Output:
# 기차의 길이를 구하려면 기차가 기둥을 통과하는 동안 이동하는 거리를 결정해야 합니다.
# 1단계: 기차의 속도를 초당 미터로 변환합니다. 1km = 1000미터, 1시간 = 3600초, 따라서 60km/hr = (60 * 1000) / 3600 = 16.67m/s(대략).
# 2단계: 기차가 9초 동안 이동한 거리를 계산합니다. 거리 = 속도 × 시간 거리 = 16.67m/s * 9초 = 150미터.
# 3단계: 계산된 거리를 주어진 옵션과 비교합니다.
# 계산된 거리(150미터)에 가장 가까운 옵션은 옵션 (E) 150입니다.
# 따라서 열차의 길이는 약 150미터입니다.
# ```
#
#
# - ✅Input이 없는 example:
#
# ```
# Instruction:
# 질문이 주어집니다: 다음 기사에 대한 객관식 문제를 작성하세요: 기사: 겨울은 무슨 일이 일어날지 알기 어렵고 사고가 너무 쉽게 일어나기 때문에 위험합니다.
# 안개가 언덕 꼭대기에서 여러분을 기다리고 있을 수 있습니다. 녹는 눈 밑에 얼음이 숨어 있다가 운전자를 도로 밖으로 내보내려고 기다리고 있을 수도 있습니다.
# 마주 오는 차가 갑자기 도로를 가로질러 미끄러질 수도 있습니다. 빙판길 운전의 첫 번째 규칙은 부드럽게 운전하는 것입니다.
# 갑작스러운 움직임은 자동차를 제어하기 매우 어렵게 만들 수 있습니다. 따라서 차를 출발하거나 정지할 때마다, 속도를 높이거나 낮출 때마다 가능한 한 부드럽고 천천히 운전해야 합니다.
# 옆 좌석에 뜨거운 커피 한 잔을 가득 들고 운전한다고 가정해 보겠습니다. 커피를 엎지르지 않도록 운전하세요.
# 두 번째 규칙은 무슨 일이 일어날지 주의를 기울이는 것입니다. 얼음이 많을수록 도로 아래쪽을 더 잘 살펴야 합니다.
# 차를 부드럽게 정지하는 데 걸리는 시간을 테스트하세요. 생각보다 더 빨리 운전할 수 있다는 점을 기억하세요.
# 일반적으로 도로가 젖어 있을 때는 평소 정지 거리의 두 배, 눈이 쌓여 있을 때는 이 거리의 세 배, 빙판길에서는 그보다 더 많은 거리를 확보하세요.
# 항상 차량을 통제하려고 노력하면 문제가 발생하지 않습니다. 정답은
#
# Output:
# 빙판길 운전 시 가장 중요한 규칙은 무엇인가요?
# A) 위험 지역을 더 빨리 통과하기 위해 속도를 높입니다.
# B) 잠재적 위험을 피하기 위한 갑작스러운 움직임
# C) 부드럽고 부드럽게 운전하세요
# D) 바로 앞 도로에만 집중하기
# ```

# %% [markdown]
# > 🔎 Alpaca template를 활용하여서 우리가 이용하고자 하는 데이터셋을 instruction input-output 형식으로 재정의해볼까요?
# - [Alpaca github](https://github.com/tatsu-lab/stanford_alpaca)
#
#
# #### ✅한국어 버전 template
# ```
# {
#     "prompt_input": "아래는 작업을 설명하는 지침과 추가 입력을 제공하는 입력이 짝을 이루는 예제입니다. 요청을 적절히 완료하는 답변을 작성해주세요.\n\n### 지침:\n{instruction}\n\n### 입력:\n{input}\n\n### 답변:\n",
#     "prompt_no_input" : "아래는 작업을 설명하는 지침입니다. 요청을 적절히 완료하는 답변을 작성해주세요.\n\n### 지침:\n{instruction}\n\n### 답변:\n",
#     "response_split": "### 답변:"
# }
# ```

# %%
template = {
    "prompt_sarcasm_explanation": (
        "아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. "
        "풍자를 판별하고 이를 설명하는 답변을 작성해주세요.\n\n"
        "### 상황:\n{context}\n\n"
        "### 발화:\n{response}\n\n"
        "### 답변:\n"
    ),
    "prompt_no_sarcasm_explanation": (
        "아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. "
        "풍자를 판별하는 답변만 작성해주세요.\n\n"
        "### 발화:\n{response}\n\n"
        "### 답변:\n"
    ),
    "response_split": "### 답변:"
}

# %%
from typing import Optional

# 새 sarcasm 프롬프트 템플릿
template = {
    "prompt_sarcasm_explanation": (
        "아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. "
        "풍자를 판별하고 이를 설명하는 답변을 작성해주세요.\n\n"
        "### 상황:\n{context}\n\n"
        "### 발화:\n{response}\n\n"
        "### 답변:\n"
    ),
    "prompt_no_sarcasm_explanation": (
        "아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. "
        "풍자를 판별하는 답변만 작성해주세요.\n\n"
        "### 발화:\n{response}\n\n"
        "### 답변:\n"
    ),
    "response_split": "### 답변:"
}

class Prompter(object):
    """
    context, response 를 입력으로 받고,
    optional label 과 optional explanation 을 target 출력으로 묶어
    prompt 를 생성합니다.
    """
    def __init__(self, verbose: bool = False):
        self.template = template
        self.verbose = verbose

    def generate_prompt(
        self,
        context: str,
        response: str,
        label: Optional[str] = None,
        explanation: Optional[str] = None
    ) -> str:
        # explanation 이 있으면 분류+설명 템플릿 사용
        if explanation is not None:
            prompt = self.template["prompt_sarcasm_explanation"].format(
                context=context,
                response=response
            )
            if label:
                prompt += label
            prompt += f"\n{explanation}"
        # explanation 이 없으면 분류만 템플릿 사용
        else:
            prompt = self.template["prompt_no_sarcasm_explanation"].format(
                response=response
            )
            if label:
                prompt += label

        if self.verbose:
            print("Generated prompt:\n", prompt)
        return prompt

    def get_response(self, output: str) -> str:
        """
        모델 출력에서 '### 답변:' 뒤에 나오는 실제 답변만 추출합니다.
        """
        parts = output.split(self.template["response_split"])
        return parts[-1].strip() if len(parts) > 1 else output.strip()

# 사용 예시
prompter = Prompter(verbose=True)

# 1) label만 있을 때
p1 = prompter.generate_prompt(
    context="A: ... 영화 보셨나요?",
    response="B: 어, 인셉션은 꿈 이야기가 아니구요.",
    label="Non-Sarcasm"
)

# 2) label + explanation 있을 때
p2 = prompter.generate_prompt(
    context="A: ... 연애 경험 어때요?",
    response="B: 저한테도 소개팅은 첨이었어요.",
    label="Sarcasm",
    explanation="B는 소개팅 경험이 없다는 당연한 사실을 과장해 풍자로 표현했습니다."
)

print(p1)
print("—" * 40)
print(p2)
# Out:
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 어, 인셉션은 꿈 이야기가 아니구요.
#
# ### 답변:
# Non-Sarcasm
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: ... 연애 경험 어때요?
#
# ### 발화:
# B: 저한테도 소개팅은 첨이었어요.
#
# ### 답변:
# Sarcasm
# B는 소개팅 경험이 없다는 당연한 사실을 과장해 풍자로 표현했습니다.
# 아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 어, 인셉션은 꿈 이야기가 아니구요.
#
# ### 답변:
# Non-Sarcasm
# ————————————————————————————————————————
# 아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: ... 연애 경험 어때요?
#
# ### 발화:
# B: 저한테도 소개팅은 첨이었어요.
#
# ### 답변:
# Sarcasm
# B는 소개팅 경험이 없다는 당연한 사실을 과장해 풍자로 표현했습니다.

# %%
###########################################
# 5-4. Token generation 함수

def tokenize(prompt, add_eos_token=True):
    result = tokenizer(
        prompt,
        truncation=True,
        max_length=cutoff_len,
        padding=False,
        return_tensors=None,
    )

    if (
        result["input_ids"][-1] != tokenizer.eos_token_id
        and len(result["input_ids"]) < cutoff_len
        and add_eos_token
    ):

        result["input_ids"].append(tokenizer.eos_token_id)
        result["attention_mask"].append(1)

    result["labels"] = result["input_ids"].copy()

    return result

def generate_and_tokenize_prompt(data_point):
    full_prompt = prompter.generate_prompt(
        data_point["instruction"],
        data_point["input"],
        data_point["output"])

    tokenized_full_prompt = tokenize(full_prompt)
    if not train_on_inputs:

        user_prompt = prompter.generate_prompt(
            data_point["instruction"], data_point["input"])

        tokenized_user_prompt = tokenize(
            user_prompt, add_eos_token=add_eos_token)

        user_prompt_len = len(tokenized_user_prompt["input_ids"])

        if add_eos_token:
            user_prompt_len -= 1

        tokenized_full_prompt["labels"] = [
            -100
        ] * user_prompt_len + tokenized_full_prompt["labels"][
            user_prompt_len:
        ]
    return tokenized_full_prompt

# %%
def tokenize(prompt: str, add_eos_token: bool = True):
    # (기존 토크나이저 그대로)
    result = tokenizer(
        prompt,
        truncation=True,
        max_length=cutoff_len,
        padding=False,
        return_tensors=None,
    )
    if (
        add_eos_token
        and result["input_ids"][-1] != tokenizer.eos_token_id
        and len(result["input_ids"]) < cutoff_len
    ):
        result["input_ids"].append(tokenizer.eos_token_id)
        result["attention_mask"].append(1)
    # labels 복사
    result["labels"] = result["input_ids"].copy()
    return result

def generate_and_tokenize_prompt(example, add_eos_token: bool = True):
    """
    example: {
      'context': str,
      'response': str,
      'label': 'Sarcasm' or 'Non-Sarcasm',
      'sarcasm_explanation': Optional[str]
    }
    """
    # 1) full prompt 생성
    full_prompt = prompter.generate_prompt(
        context=example["context"],
        response=example["response"],
        label=example.get("label"),
        explanation=example.get("sarcasm_explanation")
    )
    tokenized_full = tokenize(full_prompt, add_eos_token=add_eos_token)

    # 2) train_on_inputs=False 인 경우, 입력(prompt) 부분만 마스킹
    if not train_on_inputs:
        # prompt-only (label/explanation 없이) 길이를 알아냄
        prompt_only = prompter.generate_prompt(
            context=example["context"],
            response=example["response"]
        )
        tokenized_prompt = tokenize(prompt_only, add_eos_token=add_eos_token)
        prompt_len = len(tokenized_prompt["input_ids"])
        # EOS 토큰을 별도 마스킹했다면 길이에서 -1
        if add_eos_token:
            prompt_len -= 1
        # labels 의 앞 prompt_len 부분을 -100 으로
        tokenized_full["labels"] = ([-100] * prompt_len
                                    + tokenized_full["labels"][prompt_len:])

    return tokenized_full

# %%
###########################################
# 5-5. 훈련 셋 만들기 (~3분)

val_data = None
train_data = data["train"].shuffle() # random
train_data = train_data.map(generate_and_tokenize_prompt)
# Out:
# Map:   0%|          | 0/10466 [00:00<?, ? examples/s]
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# B: 너 오늘 보디 락스 미팅 가야 돼?
# A: 응, 근데 스폰서가 준 물 양이 줄었어.
# B: 진짜? 어제는 얼마나 줬어?
# A: 어제는 10박스 줬는데, 오늘은 8박스만 줬어.
#
# ### 발화:
# B: 아니, 무려 8박스나 준다고? 너무나도 가난한 우리에게.
#
# ### 답변:
# Sarcasm
# 물의 양이 감소했지만, 그럼에도 불구하고 여전히 많은 양을 받았다는 사실을 과장하여 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 아니, 무려 8박스나 준다고? 너무나도 가난한 우리에게.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 우리 초등학교 때 컴퓨터실에서 무서운 게임을 했던 기억이 있나요?
# A: 그게 어떤 게임이었죠? 잘 기억이 안 나네요.
# B: 맞아요. 그때 함께 했던 친구들도 모두 잊었을 겁니다. 그러나 그 경험은 우리에게 정말 중요한 추억이었어요.
# A: 아마도 저는 그때 너무 무서워서 잊어버린 것 같아요.
#
# ### 발화:
# B: 아, 그래서 기억력이 저렇게 좋은 거군요.
#
# ### 답변:
# Sarcasm
# 상대방이 그때의 무서움 때문에 기억을 잃었다고 했을 때, 실제로는 그것이 가능하지 않지만 가능하다고 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 아, 그래서 기억력이 저렇게 좋은 거군요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 최근에 애완동물을 키우고 계신다고 들었습니다. 어떤 동물을 키우시는 건가요?
# A: 햄스터와 고양이를 한 마리씩 키우고 있습니다.
# B: 그럼 두 동물이 서로 어울리나요? 문제가 없나요?
# A: 아직까지는 큰 문제는 없지만, 고양이가 햄스터를 항상 쫓아다니는 것 같아요.
#
# ### 발화:
# B: 아, 고양이가 햄스터를 그렇게 좋아하시는군요.
#
# ### 답변:
# Sarcasm
# 고양이가 햄스터를 쫓아다니는 것은 애완동물 사이의 문제를 일으킬 수 있는 상황인데, 이를 고양이가 햄스터에게 관심을 많이 보이는 것처럼 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 아, 고양이가 햄스터를 그렇게 좋아하시는군요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 다이어트 시작했어?
# B: 응, 근데 아직도 고기를 못 끊겠어.
# A: 곤약 한번 해봐. 맛있고 다이어트에도 좋다더라.
# B: 그게 어떻게 도움이 돼?
# A: 곤약은 칼로리가 낮아서 살찌는 걸 막아줘.
# B: 그래서? 그럼 곤약만 먹고 사니?
#
# ### 발화:
# A: 그럼 너 진짜 꿀꿀한 생활 즐기겠네.
#
# ### 답변:
# Sarcasm
# 상대방이 곤약만 먹고 살 수 있다는 듯이 말하자, 실제로 그것이 불가능하다는 것을 알면서도 그렇게 할 수 있으면 좋겠다는 듯이 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 그럼 너 진짜 꿀꿀한 생활 즐기겠네.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 아니, 너 저녁 뭐 먹어?
# B: 아직 고민 중이야. 오늘 퇴근이 좀 늦을 것 같아서.
# A: 그럼 내가 알려준 삶은 고구마에 수제청 찍어 먹는 팁 기억나지?
# B: 그런데, 집이 멀어서 삶은 고구마도 사 먹기 힘들 거 같아.
#
# ### 발화:
# A: 그럼 집까지 걸어가면서 운동도 할 수 있겠네.
#
# ### 답변:
# Sarcasm
# 집이 멀어서 삶은 고구마를 사 먹는 것도 힘들다는 B의 말에 대해 실제로는 불편한 상황인데, 이 상황을 운동하는 기회로 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 그럼 집까지 걸어가면서 운동도 할 수 있겠네.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 저는 어릴 때부터 민트 초콜릿이 가장 좋았습니다. 여러분은 어떤 맛을 가장 좋아하시나요?
# A: 저는 사실 민트 초콜릿이 별로예요. 너무 톡 쏘는 맛이 있어서 어려서부터 그냥 싫었어요.
# B: 아 그래요? 그럼 어떤 맛을 가장 좋아하시나요?
# A: 저는 딸기 맛이 제일 좋아요. 딸기 아이스크림, 딸기 케이크, 딸기우유, 모든 딸기 맛을 다 좋아해요.
#
# ### 발화:
# B: 딸기 맛을 이렇게 사랑하시다니, 딸기를 보면 꼭 B 님 생각나겠네요.
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 딸기 맛을 이렇게 사랑하시다니, 딸기를 보면 꼭 B 님 생각나겠네요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 왜 또 음식 그대로 놔두고 안 치우냐?
# A: 잠시 후에 치울 생각이었습니다.
# B: 항상 이래. 다음에는 꼭 치우라고.
# A: 네, 알겠습니다. 다음에는 꼭 치울게요.
#
# ### 발화:
# B: 그럴 일 없잖아. 다음에도 네가 치우지 않을 걸 알잖아.
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 그럴 일 없잖아. 다음에도 네가 치우지 않을 걸 알잖아.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 저, 무라고 벨 생수를 구매하셨다고 들었어요.
# B: 그럼, 싸니까 사 봤어.
# A: 하지만 안전에 대한 우려가 많다는 소문을 들었어요.
# B: 그래도 물이 필요하니까 마셔야지.
#
# ### 발화:
# A: 네, 안전한 건 아무래도 중요하지 않겠죠.
#
# ### 답변:
# Sarcasm
# B는 무라고 벨 생수의 안전성에 대한 우려를 모르거나, 아는 상황에서도 마시겠다고 했다. 이러한 상황을 살짝 비꼬아서 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 네, 안전한 건 아무래도 중요하지 않겠죠.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 저는 개를 매우 좋아합니다. 특히 시바견이요.
# A: 그렇군요. 저도 개를 좋아합니다. 시바견을 키우고 계시나요?
# B: 네, 맞아요. 벌써 3살이 된 시바견을 키우고 있습니다.
# A: 아, 그럼 어떤 성격을 가진 시바견인가요?
# B: 고집이 세고 자기주장이 강해요. 제 말을 잘 듣지 않습니다.
#
# ### 발화:
# A: 아, 그렇군요. 진정한 리더십이 있네요, 굉장히!
#
# ### 답변:
# Sarcasm
# 시바견의 고집스러운 성격과 자기주장이 강한 모습에 대해, 이를 훌륭한 리더십 있는 모습으로 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 아, 그렇군요. 진정한 리더십이 있네요, 굉장히!
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 요즘 아이들은 무슨 음식을 좋아하나요?
# B: 아이들은 대부분 피자를 좋아하더라고요. 저희 아이들도 그렇습니다.
# A: 피자는 자주 시키시나요?
# B: 네, 한 달에 두 번 정도는 시키는 것 같아요.
#
# ### 발화:
# A: 피자 배달원들은 당신께 정말 고마워하겠어요.
#
# ### 답변:
# Sarcasm
# 상대방이 자주 피자를 시키는 것에 대해 실제로는 부정적인 의미를 내포하지만 긍정적인 표현으로 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 피자 배달원들은 당신께 정말 고마워하겠어요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 요즘 너 피부관리는 어떻게 하고 있어?
# B: 아 집에서 조금씩 해보려고 하지만 귀찮아서 잘 안돼.
# A: 그래도 겨울에는 피부관리를 꼼꼼하게 해야 하는데..
# B: 그런데도 끝내 제대로 하지 못하고 있어.
#
# ### 발화:
# A: 아니, 너 자연주의자라서 그러는 거겠지.
#
# ### 답변:
# Sarcasm
# 상대방이 제대로 피부관리를 하지 못한다는 것을 들었을 때, 실제로는 부정적인 상황인데, 이 상황을 긍정적인 방향으로 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 아니, 너 자연주의자라서 그러는 거겠지.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 너 커피 좋아하니?
# B: 응, 나 커피 마니아야. 여러 종류 다 마셔봤어.
# A: 그래서 어떤 종류가 제일 좋아?
# B: 난 아메리카노가 제일 좋아.
#
# ### 발화:
# A: 와우, 진짜 다양한 커피를 즐기는 마니아 같네.
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 와우, 진짜 다양한 커피를 즐기는 마니아 같네.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 안녕하세요. 직업이 어떻게 되세요?
# A: 저는 사무직입니다.
# B: 사무직이라면 주로 어떤 업무를 담당하시나요?
# A: 전화받기, 서류 정리, 미팅 일정 관리 등 다양한 업무를 담당하고 있습니다.
# B: 아 그럼 계속 앉아서 일을 하시는 거겠네요. 몸에 안 좋지 않을까요?
# A: 그래도 스트레칭이나 짧은 산책을 하면서 건강을 챙기려고 노력하고 있습니다.
#
# ### 발화:
# B: 오, 당신은 정말로 건강한 생활 방식의 모범이네요!
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 오, 당신은 정말로 건강한 생활 방식의 모범이네요!
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 주말에 뭐 할 계획이야?
# A: 아, 내 조카 보러 가려고. 이번에도 아마 엄청난 에너지를 보여줄 거야.
# B: 역시 조카는 너에게 많은 활력을 주나 봐.
# A: 그런가 봐. 마치 에너자이저처럼.
#
# ### 발화:
# B: 그럼 너 정말 에너지 공급받을 날이구나.
#
# ### 답변:
# Sarcasm
# B의 조카가 에너지가 넘치는 것에 대해 실제로는 피곤할 것을 에너지를 얻는 것처럼 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 그럼 너 정말 에너지 공급받을 날이구나.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 공항에 도착하면 어떻게 시내로 갈 계획이세요?
# A: 아 그러게, 어떻게 가야 할지 모르겠네. 버스를 타야 할지 택시를 타야 할지.
# B: 저는 보통 택시를 예약하곤 해요. 편하고 빠르니까요.
# A: 택시? 그건 좀 비싸지 않아? 나는 버스를 타려고 생각했는데.
# B: 그럼 버스를 타세요. 조금 불편하긴 하겠지만 시간도 좀 걸리고요.
#
# ### 발화:
# A: 오 이런 교통체증도 경험할 수 있게 되다니, 기쁘다!
#
# ### 답변:
# Sarcasm
# A의 마지막 말에 대한 B의 반응에서 버스를 타는 것이 불편하고 시간이 오래 걸리는 상황을 긍정적인 측면에서 바라보는 방식으로 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 오 이런 교통체증도 경험할 수 있게 되다니, 기쁘다!
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 내일 내 생일인데, 넌 어떤 선물 줄 생각이야?
# B: 음... 너 좋아하는 거 어떤 거 있어?
# A: 이런, 나 좋아하는 거도 몰라?
#
# ### 발화:
# B: 그러게... 아마 네가 무슨 선물을 받고 싶어 하는지는 알아야 할 것 같은데.
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 그러게... 아마 네가 무슨 선물을 받고 싶어 하는지는 알아야 할 것 같은데.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 박보검 배우님의 새로운 영화 보셨나요?
# B: 아직 보지 못했습니다. 어떤 영화인가요?
# A: 그 영화에서 박보검 배우님은 참 불쌍한 역할을 했습니다. 가난한 가정에서 자란 소년이 성장하면서 겪는 고난들을 그려냈어요.
# B: 그렇군요. 그럼 그 작품의 메시지는 무엇인가요?
# A: 그 영화의 메시지는 인생의 어려움을 극복하는 것이 얼마나 중요한지를 보여주는 것 같습니다.
#
# ### 발화:
# B: 오, 정말요? 그런 메시지는 첨 듣네요.
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 오, 정말요? 그런 메시지는 첨 듣네요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 어떻게 그럴 수 있어? 너 아무 일 없어?
# A: 아니, 무슨 큰일 나면 어떡해? 다행히 살아있어.
# B: 너 그거 뭐야? 팔이 저렇게 붓고 빨갛게 져있는데?
#
# ### 발화:
# A: 아 그거, 오토바이 사고 났거든. 걱정 마, 그냥 까매져서 보기 싫은 정도야.
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 아 그거, 오토바이 사고 났거든. 걱정 마, 그냥 까매져서 보기 싫은 정도야.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 왜 술 안 마셔?
# A: 나 기독교라서 야. 그런 거 안 해.
# B: 그럼 오늘 뭐 할 거야?
# A: 동백이라는 TV 프로그램 보려고.
#
# ### 발화:
# B: '동백'이라... 정말로 흥미진진하겠네.
#
# ### 답변:
# Sarcasm
# B가 TV 프로그램인 '동백'을 볼 것이라는 말에 대해, 실제로는 그다지 흥미롭지 않은 상황을 비꼬아 표현한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: '동백'이라... 정말로 흥미진진하겠네.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 요즘 어떻게 지내시나요? 건강하신가요?
# B: 아, 독감에 걸려서 힘들게 보내고 있습니다. 그런데 여기 세종시는 진짜 병원도 너무 많고 사람들도 많아서 병원 가는 것만으로도 스트레스 받네요.
# A: 독감에 걸리셨군요, 빨리 나아지시길 바랍니다. 그런데 세종시가 병원이 많다니 좋은 것 아닌가요?
#
# ### 발화:
# B: 그래요, 병원이 많으니 아프기만 하면 병원에 갈 수 있어서 참 좋네요.
#
# ### 답변:
# Sarcasm
# 세종시의 병원과 사람들이 많은 것을 부정적으로 말한 B에게 A는 그것을 긍정적으로 해석하여 반문 형식으로 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 그래요, 병원이 많으니 아프기만 하면 병원에 갈 수 있어서 참 좋네요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 신혼 생활은 어떻게 돼가요?
# B: 아주 잘되고 있어요. 아내와 함께하는 시간이 너무 좋아요.
# A: 그럼 행복하게 잘 지내고 있겠네요.
# B: 네, 하지만 아내와의 시간이 늘 모자라요.
#
# ### 발화:
# A: 그럼 하루가 24시간이면 부족하겠네.
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 그럼 하루가 24시간이면 부족하겠네.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 요즘 결혼 및 출산에 대한 생각은 어떠신가요?
# A: 사실 저는 결혼이나 출산에 크게 관심이 없습니다.
# B: 그렇군요. 특별한 이유가 있나요?
# A: 아무래도 개인의 자유와 취미 생활을 더 중요하게 생각하게 되더군요.
#
# ### 발화:
# B: 그럼 여유로운 시간이 넘치겠군요.
#
# ### 답변:
# Sarcasm
# 마지막 B의 대화에서 자신의 자유와 취미 생활을 결혼이나 출산보다 중요하게 생각한다는 말에, 실제로는 그것들을 할 시간이 부족하다는 의미를 부정적으로 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 그럼 여유로운 시간이 넘치겠군요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 그 식당에 어제 방문했는데요, 너무 실망했습니다.
# A: 어떤 점이 실망스러웠나요?
# B: 그곳은 제 인생 맛집이었는데, 요리사가 바뀐 것 같더라고요. 전의 맛이 전혀 느껴지지 않았습니다.
#
# ### 발화:
# A: 그런 일이 있었군요. 요리사의 노하우는 쉽게 따라올 수 없으니까요.
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 그런 일이 있었군요. 요리사의 노하우는 쉽게 따라올 수 없으니까요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 오늘은 어떤 할인 행사를 찾으셨나요?
# B: 아, 여기저기 다 둘러봤는데요. 제일 좋은 건 핫 달이었어요.
# A: 어떤 제품을 구입하셨나요?
# B: 핸드크림이랑 칫솔, 그리고 화장지를 샀습니다. 원래 이런 소비재를 적게 사려고 했는데, 가격이 너무 좋아서요.
#
# ### 발화:
# A: 아, 정말 잘했어요. 집에 물건이 넘쳐나도록 쌓여 있어야겠죠.
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 아, 정말 잘했어요. 집에 물건이 넘쳐나도록 쌓여 있어야겠죠.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 떡볶이를 매운맛으로 먹는다면, 어떤 부속 음식을 추천하시나요?
# B: 매운 떡볶이와 함께 먹으면 좋은 음식은 바로 계란찜이라고 생각합니다.
# A: 계란찜을 집에서 어떻게 만들 수 있나요?
#
# ### 발화:
# B: 아주 쉽습니다. 전자레인지만 있으면 됩니다.
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 아주 쉽습니다. 전자레인지만 있으면 됩니다.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: '킹덤'이라는 드라마를 보셨나요?
# A: 아, 그 좀비 드라마 말하는 거야?
# B: 네, 그런데 그 작가분의 다른 작품들도 많이 좋아요.
# A: 아, 근데 나는 그 작가의 시나리오가 별로야.
#
# ### 발화:
# B: 그럼, 그 작가님은 정말 당신의 고급 취향을 만족시키기 어렵겠네요.
#
# ### 답변:
# Sarcasm
# B가 작가의 시나리오를 별로라고 했지만, 사실상 그 작가의 시나리오는 많은 사람들이 좋아하는 것으로 알려져 있다. 따라서 A는 B의 반대 의견을 조롱하면서 실제로는 그 작가의 시나리오가 좋다는 것을 나타내는 비꼬는 말을 한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 그럼, 그 작가님은 정말 당신의 고급 취향을 만족시키기 어렵겠네요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 저는 컴퓨터공학과에 재학 중인데요, 당신은 어떤 학과에 계시나요?
# B: 저는 문과입니다. 컴퓨터 관련 공부는 어려워서 잘 모르겠어요.
# A: 아하, 그럼 우리 학과 수업 들으면 어떨까요? 도움이 많이 될 것 같아요.
# B: 아뇨, 제가 컴퓨터 공부를 하면 머리가 터질 것 같아요.
#
# ### 발화:
# A: 그럼 컴퓨터 공부를 하면 뇌 운동이 되겠네요.
#
# ### 답변:
# Sarcasm
# A가 컴퓨터 공부를 추천하였지만, B가 그것이 어려울 것 같다고 하였을 때, 이를 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 그럼 컴퓨터 공부를 하면 뇌 운동이 되겠네요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 인터넷에서 그 제품을 구매하려고 했는데 가격이 너무 비싸더라고요.
# A: 그래서 어떻게 하셨나요?
# B: 직접 만들기로 결정했습니다.
# A: 직접 만들면 더 싸지 않아요?
# B: 아니요, 오히려 더 비싸졌습니다. 재료 비용과 시간을 계산하니까요.
#
# ### 발화:
# A: 그럼 그것이야말로 진정한 절약이겠군요!
#
# ### 답변:
# Sarcasm
# 상대방이 제품을 직접 만들었는데 오히려 더 비싸졌다는 상황에 대해, 실제로는 비효율적인 행동인 것을 효율적인 행동처럼 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 그럼 그것이야말로 진정한 절약이겠군요!
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 어제 TV에서 흥미로운 영화를 보셨나요?
# B: 네, 실제로 직관하러 가보려 했지만 코로나 때문에 못 갔어요.
# A: 아, 그래요? 그럼 스포츠를 좋아하시나요?
# B: 네, 특히 야구를 좋아해요.
#
# ### 발화:
# A: 그럼 이제 매일 밤 TV 앞에서 야구를 즐기실 수 있겠네요.
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 그럼 이제 매일 밤 TV 앞에서 야구를 즐기실 수 있겠네요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 요즘 헤어트리트먼트를 하시는군요. 효과가 있나요?
# B: 네, 저는 매우 만족하고 있습니다. 탈모도 줄고 머리카락도 부드러워져서요.
# A: 그럼 저도 해봐야겠네요. 어떻게 사용하면 되나요?
# B: 매일 샴푸 후에 헤어트리트먼트를 발라주시고, 10분 정도 두신 후에 미지근한 물로 씻어내면 됩니다.
# A: 매일 그렇게 해야 하나요? 시간이 꽤 드네요.
#
# ### 발화:
# B: 아니요, 이게 오히려 일상생활의 소소한 행복이라고 생각하시면 됩니다.
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 아니요, 이게 오히려 일상생활의 소소한 행복이라고 생각하시면 됩니다.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 너 취미가 뭐야?
# A: 나? 나는 사람들 웃기는 걸 좋아해.
# B: 진짜? 그럼 나 좀 웃겨봐.
# A: 좋아, 그럼... 왜 바나나가 컴퓨터를 가지러 갔을까?
# B: 왜지?
# A: "바나나 스플릿"을 만들기 위해서야!
#
# ### 발화:
# B: 와, 정말 미치도록 웃기네. 라이브 코미디 클럽에 너 출연해야 돼.
#
# ### 답변:
# Sarcasm
# B가 말한 유머는 실제로는 그렇게 웃기지 않지만, 이를 엄청 웃긴 것처럼 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 와, 정말 미치도록 웃기네. 라이브 코미디 클럽에 너 출연해야 돼.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 오늘 머리 스타일을 완전히 바꾸셨네요?
# A: 네, 새로운 것을 시도해 보고 싶었어요.
# B: 어떤 생각으로 바꾸셨는지 알 수 있을까요?
# A: 특별한 이유는 없었어요. 그냥 제가 한 번도 해보지 않은 머리 스타일로 바꿔보고 싶었어요.
# B: 그렇군요. 그런데 잘 어울리나요?
# A: 아니요, 제가 생각했던 것보다 전혀 다르게 나왔어요. 정말 후회하고 있습니다.
#
# ### 발화:
# B: 아니요, 전혀 안 걱정하셔도 됩니다. 정말 사랑스럽게 변하셨네요.
#
# ### 답변:
# Sarcasm
# B가 자신의 머리 스타일을 바꿔서 후회하고 있다는 상황에서, 그 결과를 사랑스럽게 받아들이는 것처럼 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 아니요, 전혀 안 걱정하셔도 됩니다. 정말 사랑스럽게 변하셨네요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 집에 새로 들인 식물 어떻게 관리하고 있어?
# A: 아 잘 모르겠어, 이번에 들인 식물 벌레가 엄청나더라고.
# B: 벌레 나오면 문제가 큰데, 무슨 벌레 나왔어?
# A: 날개 달린 작은 검은색 벌레들이 나왔어.
#
# ### 발화:
# B: 오, 벌레들에게 좋은 집을 제공하니까 너도 동물보호 활동가 됐네.
#
# ### 답변:
# Sarcasm
# 벌레가 많이 나와서 식물을 제대로 키울 수 없는 상황을 식물에게 벌레를 주는 것처럼 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 오, 벌레들에게 좋은 집을 제공하니까 너도 동물보호 활동가 됐네.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 비가 많이 오네요.
# B: 네, 집에만 있기에는 딱 좋은 날씨입니다.
# A: 주말에는 무엇을 하시나요?
# B: 티브이를 보면서 커피 한잔하는 것이 제일 좋습니다.
#
# ### 발화:
# A: 아, 그렇게 활동적인 주말을 보내시는군요.
#
# ### 답변:
# Sarcasm
# 비가 오는 날씨를 비꼬아 물어보는 상황에서, 상대방이 커피 한잔하면서 티브이를 보는 것이 좋다고 말했을 때, 그것을 다른 사람들이 보기에는 즐겁지 않은 일로 표현한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 아, 그렇게 활동적인 주말을 보내시는군요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 작년에 비해 올해의 가을이 조금 빨리 찾아온 것 같습니다.
# B: 그렇습니다. 작년보다 더 빨리 추워지는 것 같아요.
# A: 네, 그래서 가을을 충분히 즐기지 못한 것 같아 아쉽습니다.
# B: 저도 그렇습니다. 가을이 짧아져서 좀 슬프네요.
#
# ### 발화:
# A: 짧아진 가을 덕분에 겨울옷을 더 일찍 입을 수 있게 되었네요.
#
# ### 답변:
# Sarcasm
# B의 말에 대해 실제로는 부정적인 상황인데, 이를 긍정적으로 해석하여 반대로 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 짧아진 가을 덕분에 겨울옷을 더 일찍 입을 수 있게 되었네요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 드라마 "때려"의 주연인데, 어떤 캐릭터를 연기하셨나요?
# B: 아, 나는 삶에 지친 청년으로, 맨날 때리고 다니는 캐릭터야.
# A: 그렇군요. 그럼 실제로 많이 때렸나요?
# B: 그래. 많이 때렸지. 특히 마지막 회에서는 정말 많이 때렸어.
#
# ### 발화:
# A: 그럼 아마 당신은 공인인증 때리기 선생님이시겠네요.
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 그럼 아마 당신은 공인인증 때리기 선생님이시겠네요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 안녕하세요, 새로운 동호회원으로 가입하게 되신 것을 환영합니다. 어떤 활동에 참여하실 계획이신가요?
# A: 안녕하세요. 저는 교육봉사를 하려고 가입하게 되었습니다.
# B: 아, 그렇군요. 저희 동호회에서는 많은 교육봉사 프로그램이 있습니다. 특히 저소득층 아이들을 위한 교육봉사가 있습니다.
# A: 아, 그런 프로그램이 있었군요. 저는 교육에 관심이 많아서 좋겠네요.
# B: 아주 좋습니다. 그럼 당신은 저소득층 아이들을 위한 교육봉사에 참여하시겠습니까?
# A: 아, 그런데 제가 가르치는 것에 자신이 없어서요. 공부를 더 해야 할 것 같아요.
#
# ### 발화:
# B: 그럼 아이들에게 공부의 중요성을 가르치는 데 큰 도움이 될 것 같아요.
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 그럼 아이들에게 공부의 중요성을 가르치는 데 큰 도움이 될 것 같아요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 저는 예전 사진을 다 지울 생각이에요.
# B: 왜 그래요? 기억을 간직하고 싶지 않아요?
# A: 아니 그런 게 아니라, 너무 많아서 관리가 안 돼요. 그래서 정리하려고요.
# B: 정리하는 게 그렇게 중요한가요? 그냥 놔두면 되지 않아요?
#
# ### 발화:
# A: 아, 그렇게 놔두면 엉망이 되어도 상관없겠네요.
#
# ### 답변:
# Sarcasm
# 정리를 하지 않아도 상관없다고 생각하는 B의 말에, 실제로는 관리를 해야 하지만, 이 상황을 망치게 두는 것이 좋다는 것처럼 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 아, 그렇게 놔두면 엉망이 되어도 상관없겠네요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 우리 어릴 때 재밌게 했던 게임들이 있었죠. 기억나세요?
# B: 아, 그러게요. 닌텐도 게임들이 많이 생각나네요.
# A: 저는 마리오와 마리오카트, 그리고 축구 게임이 제일 재밌었어요. 그런데 폰이 출시되면서부터 닌텐도 게임을 잘 안 하게 됐어요.
# B: 아, 저도 그렇게 됐어요. 폰 게임이 훨씬 간편하고 다양한 게 있으니까요.
#
# ### 발화:
# A: 그러게요, 터치스크린으로 누르는 것만큼 짜릿한 경험이 또 있을까요?
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 그러게요, 터치스크린으로 누르는 것만큼 짜릿한 경험이 또 있을까요?
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 최근에 그 게임에 새로운 업데이트가 있었다고 들었습니다. 참여율이 어떤가요?
# B: 예, 업데이트가 있었는데요. 사용자들의 참여율이 아주 높습니다.
# A: 아, 그렇군요. 업데이트 내용이 흥미롭나 보군요.
# B: 아니요, 사실 업데이트 내용은 그다지 매력적이지 않습니다. 그냥 모든 유저들에게 보상을 주어서 참여율이 높은 것 같습니다.
#
# ### 발화:
# A: 아하, 보상으로 유저들을 끌어들이는 거군요. 참 혁신적인 전략이네요.
#
# ### 답변:
# Sarcasm
# 사실상 업데이트의 내용이 아닌 보상 때문에 참여율이 높아진 것을 실제로는 좋은 결과가 아닌데, 이를 긍정적인 방향으로 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 아하, 보상으로 유저들을 끌어들이는 거군요. 참 혁신적인 전략이네요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 오늘 점심에 무엇을 드실 계획이세요?
# B: 아직 정하지 않았습니다. 학식을 먹을까 돈가스를 먹을까 고민 중입니다.
# A: 학식은 어떤 메뉴가 있나요?
# B: 오늘 학식 메뉴는 비빔밥이에요. 근데 비빔밥은 집에서도 잘 만들어 먹는 거라...
#
# ### 발화:
# A: 아하, 그럼 우리는 곧 B 씨의 비빔밥 레시피를 볼 수 있겠군요!
#
# ### 답변:
# Sarcasm
# 학식 메뉴인 비빔밥을 집에서도 잘 만든다고 한 B의 말에 대해, 실제로는 자신의 요리 실력이 그리 좋지 않을 것 같지만 이를 긍정적으로 해석하고 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 아하, 그럼 우리는 곧 B 씨의 비빔밥 레시피를 볼 수 있겠군요!
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 오늘 저녁에 무엇을 드셨나요?
# A: 저는 오늘 저녁에 만둣국을 먹었습니다. 아주 맛있었습니다.
# B: 그럼 다음에 무엇을 드실 계획이신가요?
# A: 다음에는 치킨을 주문해서 먹을 계획입니다.
#
# ### 발화:
# B: 그럼 식사는 이미 하셨으니 치킨은 디저트로 취급하시는 건가요?
#
# ### 답변:
# Sarcasm
# 이미 저녁에 만둣국을 먹었음에도 불구하고, 추가로 치킨을 먹겠다는 B의 발언에 A가 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 그럼 식사는 이미 하셨으니 치킨은 디저트로 취급하시는 건가요?
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 감기에 걸리지 않으려면 어떻게 해야 하나요?
# B: 감기 예방을 위해 건강에 신경을 쓰는 것이 중요합니다. 매일 비타민을 섭취하고 충분한 수면을 취하는 것이 좋아요.
# A: 그렇군요. 또한, 저는 한의원에 가서 독감 주사도 맞을 예정입니다.
#
# ### 발화:
# B: 독감 주사, 좋은 생각이네요. 그런데 한의원에서 독감 주사를 맞는다고요?
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 독감 주사, 좋은 생각이네요. 그런데 한의원에서 독감 주사를 맞는다고요?
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 여행 계획을 세우는 스타일이 어떠신가요?
# A: 저는 주로 패키지여행을 선호합니다.
# B: 그렇군요, 특별한 이유가 있으신가요?
# A: 네, 저는 일정을 직접 계획하는 것이 번거롭고 패키지여행이면 모든 것이 정리되어 있어 편하다고 생각합니다.
#
# ### 발화:
# B: 아, 정말로 모든 것이 결정된 여행이 최고의 자유로움이겠군요.
#
# ### 답변:
# Sarcasm
# 패키지여행이 모든 것이 정리되어 있어 편하다는 B의 말에, 실제로 패키지여행은 자유를 제한할 수 있음에도 불구하고 그것을 모두 통제된 것으로 보아 편하다고 말하는 것을 부정적인 방향으로 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 아, 정말로 모든 것이 결정된 여행이 최고의 자유로움이겠군요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 엄마, 요즘 뭐 하시는데?
# B: 아무것도 안 해. 사실 여행 가고 싶은데, 방법이 없어서 고민 중이야.
# A: 여행? 그럼 엄마 친구들이랑 같이 가시면 되잖아요.
# B: 아니, 그게 문제야. 친구들 다 바빠서 시간이 안 맞아.
#
# ### 발화:
# A: 그럼 혼자 세계여행이나 다녀오세요.
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 그럼 혼자 세계여행이나 다녀오세요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 안녕하세요, 최근에 어떤 게임을 주로 하시나요?
# B: 피파온라인 4를 주로 합니다. 아주 재미있어요.
# A: 그렇군요, 저는 모바일 게임을 좋아합니다. 편하게 언제 어디서나 할 수 있어서 좋아요.
#
# ### 발화:
# B: 피파온라인 4도 모바일 버전이 있습니다. 하지만, 개인적으로 PC 버전이 더 재미있다고 생각해요.
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 피파온라인 4도 모바일 버전이 있습니다. 하지만, 개인적으로 PC 버전이 더 재미있다고 생각해요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 오늘 날씨 정말 쌀쌀하네요.
# B: 그러게요. 비도 오고 있어서 더 춥게 느껴지는 것 같아요.
# A: 아, 그렇군요. 이런 날은 집에서 따뜻한 커피 한잔하면서 책이나 읽는 게 최고인 것 같아요.
# B: 저는 추운 날은 밖에 나가서 눈을 즐기는 것이 좋아요.
#
# ### 발화:
# A: 오, 정말 대단하시네요. 추운 날씨를 정말 즐기시는군요.
#
# ### 답변:
# Sarcasm
# A는 추운 날에는 집에서 따뜻하게 시간을 보내는 것을 좋아하는 반면, B는 추운 날에도 밖에 나가서 눈을 즐기는 것을 좋아한다고 했다. 이에 대해 A가 B의 취향을 이해하지 못하면서도 그것을 긍정적으로 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 오, 정말 대단하시네요. 추운 날씨를 정말 즐기시는군요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 이혼하고 나서 기분은 어때?
# A: 그냥 그래. 난 정말 사랑을 믿고 싶어.
# B: 다시 사랑하고 싶다는 거야?
# A: 응, 난 결혼이 좋아. 이혼하고 나서도 다시 결혼하고 싶어.
#
# ### 발화:
# B: 어쩌면 너는 결혼의 마스터일지도 몰라.
#
# ### 답변:
# Sarcasm
# 결혼에 대한 부정적인 경험이 있음에도 불구하고 여전히 결혼을 원하는 B의 말에, 그것을 긍정적인 방향으로 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 어쩌면 너는 결혼의 마스터일지도 몰라.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 에어팟 갖고 싶다며? 왜 안 사?
# A: 그럼 사고 싶지만 너무 작아서 떨어뜨릴까 봐 무서워.
# B: 그럼 그냥 안 사는 게 나을 거 같아?
# A: 그래도 너무 갖고 싶은데...
#
# ### 발화:
# B: 이런, 꿈을 포기하는 것도 대단하네.
#
# ### 답변:
# Sarcasm
# 에어팟을 사고 싶지만 떨어뜨릴까 봐 사지 않겠다는 상대방의 이야기를 듣고, 무언가를 놓치는 것이 두려워하지 않도록 격려하는 말을 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 이런, 꿈을 포기하는 것도 대단하네.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 요즘 문화생활하시나요?
# B: 코로나 때문에 뮤지컬이나 공연장을 못 가는 것도 그렇고 아이들도 작아서 챙겨야 해서 그런 곳을 자주 못 가게 되더라고요.
# A: 그래요? 아이들과 같이 갈 수 있는 문화행사나 미술관 같은 곳은 어떠세요?
# B: 아이들도 챙기고 또 코로나도 신경 써야 해서 거의 못 가고 있어요.
#
# ### 발화:
# A: 아, 집에서 가족들과 보내는 시간이란 게 정말로 값진 것 같아요.
#
# ### 답변:
# Sarcasm
# 상대방이 문화생활을 즐기지 못하는 이유로 코로나와 아이들을 언급했다. 하지만 사실상 이런 상황은 매우 어렵고 곤란한 상황인데, 그것을 긍정적인 방향으로 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 아, 집에서 가족들과 보내는 시간이란 게 정말로 값진 것 같아요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: '모가디슈'라는 영화를 아시나요?
# B: 네, 최근에 개봉한 걸로 알고 있습니다.
# A: 맞습니다. 좋은 평가를 받고 있는데 관람하려고 계획 중이십니까?
# B: 아니요, 저는 사실 영화보다는 집에서 책을 읽는 것을 더 좋아합니다.
#
# ### 발화:
# A: 그럼 아마 책에 빠져서 밤새 잠도 못 이루실 거예요.
#
# ### 답변:
# Sarcasm
# 영화를 보기보다 집에서 책 읽기를 더 좋아한다고 말한 B에게 실제로는 독서를 별로 안 할 것 같은 상황을 책에 빠져서 잠 못 이루는 것처럼 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 그럼 아마 책에 빠져서 밤새 잠도 못 이루실 거예요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 오늘 날씨가 정말 좋네요.
# B: 좋다고 말씀하시는 이유가 있으신가요? 저는 비 오는 날이 참 싫어요.
# A: 아, 그렇군요. 왜 그런지 알 수 있을까요?
# B: 우산을 들고 다니기 불편하고, 옷도 젖어서 참 불편해요.
#
# ### 발화:
# A: 그렇군요. 아무래도 우산을 들고 다니면서 옷이 젖는 건 신선한 경험일 수 있겠네요.
#
# ### 답변:
# Sarcasm
# 실제로는 비 오는 날이 불편하다는 상대방의 말에 대해, 비 오는 날을 좋아하는 것처럼 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 그렇군요. 아무래도 우산을 들고 다니면서 옷이 젖는 건 신선한 경험일 수 있겠네요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: name1님의 반려견은 어떤 품종이세요?
# B: 제 반려견은 시베리안 허스키입니다.
# A: 아, 허스키라면 교육 훈련이 필요하겠군요. name3님이 어떤 훈련을 받고 있나요?
# B: 그래서 집안을 쓸고 닦는 훈련을 시키고 있어요.
#
# ### 발화:
# A: 와, 정말이면 청소기 회사가 문을 닫겠군요.
#
# ### 답변:
# Sarcasm
# 허스키라는 대형 견종을 집안을 청소하는 일에 훈련시킨다는 것은 사실상 불가능하다. 그래서 그 말을 긍정적으로 해석하여 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 와, 정말이면 청소기 회사가 문을 닫겠군요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 요즘 무슨 일 있어? 좀 피곤해 보이는데.
# A: 아냐, 그냥... 남자친구랑 좀 싸웠어.
# B: 왜? 무슨 일이야?
# A: 그가 자꾸 여사친이랑만 놀러 다녀.
#
# ### 발화:
# B: 그럼 너도 남사친들이랑 놀러 다니면 되잖아.
#
# ### 답변:
# Sarcasm
# 남자친구가 여사친과 자주 놀러 다니는 것을 친구가 알고 있음에도 불구하고 그런 행동이 괜찮은 것처럼 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 그럼 너도 남사친들이랑 놀러 다니면 되잖아.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 이탈리아 사람들은 뭐 먹고 사니?
# A: 피자, 파스타, 젤라또 같은 거 많이 먹지 않을까?
# B: 그래서 이탈리아 사람들이 평균적으로 다른 국가 사람들보다 뚱뚱하다고 들었어.
# A: 아니, 그건 잘못된 생각이야. 오히려 이탈리아 사람들은 식습관 때문에 건강하고 길게 산다고 해.
#
# ### 발화:
# B: 그래서 그들은 모든 피자와 파스타를 먹고도 아직 살아있는 거야?
#
# ### 답변:
# Sarcasm
# 이탈리아 사람들이 평균적으로 건강하고 길게 산다는 B의 말에 비꼬아, 음식 때문에 비만이 되어 간단히 살 수 없다는 것을 암시한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 그래서 그들은 모든 피자와 파스타를 먹고도 아직 살아있는 거야?
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 찜닭 어때? 맛있지?
# A: 음... 좋아. 근데 좀 매워.
# B: 그래? 그럼 내가 담에는 맵기 조절할게.
# A: 아냐, 그게 아니라 처음부터 찜닭이 안 맞는 것 같아.
#
# ### 발화:
# B: 오, 너의 입맛도 고대 사람처럼 원시적이네.
#
# ### 답변:
# Sarcasm
# B가 찜닭이 안 맞는다는 표현에 대해 실제로는 부정적인 상황이지만, 이를 긍정적인 상황으로 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 오, 너의 입맛도 고대 사람처럼 원시적이네.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 집안일이 너무 많아서 힘들지 않으세요?
# B: 그렇긴 하죠. 저도 도와드리고 싶은데, 시간이 많지 않아서요.
# A: 제가 건조기와 식기세척기를 사서 집안일을 줄였어요.
#
# ### 발화:
# B: 아 그렇군요? 그런데 저희 집은 건조기와 식기세척기를 사용해도 실제로 집안일이 줄진 않더라고요.
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 아 그렇군요? 그런데 저희 집은 건조기와 식기세척기를 사용해도 실제로 집안일이 줄진 않더라고요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 비누 종류에 따라 사용 용도가 다르다고 들었는데요, 그게 어떻게 다른 건가요?
# A: 그렇습니다. 페이셜 비누는 얼굴을 깨끗하게 해주고, 보디 비누는 몸 전체를 깨끗하게 해줍니다. 또, 일부 비누는 특정 향으로 만들어져서 공기 청정이나 몸의 향을 좋게 하는 데에 사용됩니다.
# B: 그럼 향이 좋은 비누를 사용하면 공기도 좋아지고 몸의 향도 좋아진다는 건가요?
# A: 이론적으로는 그렇습니다. 하지만 실제로는 모든 사람이 그 향을 좋아하는 것은 아니기 때문에 상황에 따라 다릅니다.
#
# ### 발화:
# B: 아, 그래서 그 향이 너무 강해서 코를 찡그려야 하는 거군요.
#
# ### 답변:
# Sarcasm
# A는 B의 마지막 발언에 대해 모든 사람이 그 향을 좋아할 것 같은 것처럼 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 아, 그래서 그 향이 너무 강해서 코를 찡그려야 하는 거군요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 피자스쿨 기억나? 와플 대학도 그렇고.
# A: 아, 그런 게 있었지. 요즘은 어디 없더라.
# B: 아니 왜 없어졌지? 맛있었는데.
#
# ### 발화:
# A: 피자스쿨이랑 와플 대학이 없어진 게 아쉽다고??
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 피자스쿨이랑 와플 대학이 없어진 게 아쉽다고??
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 저는 순두부찌개와 부대찌개를 만들 때 사용하는 다담 소스를 좋아하는데, 맛있는 곳을 아시나요?
# A: 아, 저도 그 소스를 참 좋아하는데요. 최근에 알게 된 집이 있어요. 그곳의 다담 소스가 정말 맛있습니다.
# B: 그럼 저도 한번 방문해 봐야겠네요. 혹시 주소를 알 수 있을까요?
# A: 네, 서울특별시 강남구 청담동에 위치해있습니다.
#
# ### 발화:
# B: 아, 그렇군요. 바로 옆집이네요.
#
# ### 답변:
# Sarcasm
# 상대방이 서울의 멀리 떨어진 곳을 추천해 줬는데, 실제로는 매우 불편한 상황인데 이를 너무나도 편리한 것처럼 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 아, 그렇군요. 바로 옆집이네요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 저는 최근에 바닐라코 클렌징 밤을 구매했습니다.
# A: 아, 그 제품이 많이 유명하던데요. 어떤가요? 만족하셨나요?
# B: 네, 확실히 피부가 깨끗해지는 느낌이 듭니다.
# A: 그럼 저도 한 번 구입해 봐야겠네요. 그리고 요즘에 액정 태블릿도 구매하려고 하는데 추천해 주실 수 있나요?
# B: 아, 저는 아이패드를 사용하고 있습니다. 디자인도 이쁘고, 성능도 좋아서 만족하고 있습니다.
# A: 아이패드요? 그런데 가격이 좀 비싸지 않나요?
#
# ### 발화:
# B: 비싸지만 아이패드만의 매력에 푹 빠지면 가격은 그저 숫자일 뿐입니다.
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 비싸지만 아이패드만의 매력에 푹 빠지면 가격은 그저 숫자일 뿐입니다.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 오늘 커피 어때? 내가 직접 갈았어.
# B: 음... 나쁘지 않아. 근데 카페에서 마시는 커피가 더 맛있는 것 같아.
#
# ### 발화:
# A: 그럼 이제부터 매일 카페에 가야겠네.
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 그럼 이제부터 매일 카페에 가야겠네.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 오늘 수업 가는 길에 뭐 먹을 거야?
# B: 아침에 시리얼 사둔 거 있잖아. 그거 우유에 타먹을 생각이야.
# A: 우유도 사야 되지 않아?
# B: 그래서 가는 길에 우유랑 치즈, 달걀까지 같이 사려고.
#
# ### 발화:
# A: 그러니까 손 한번 흔들면 다 해결되는 거지?
#
# ### 답변:
# Sarcasm
# 사려고 했던 우유, 치즈, 달걀까지 함께 사는 것이 매우 번거로울 것 같은 상황을 너무나도 간단하게 처리하는 것처럼 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 그러니까 손 한번 흔들면 다 해결되는 거지?
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 이번에 겨울 왕국 2가 개봉하던데요, 기대하시나요?
# A: 그렇습니다. 저는 애니메이션 영화를 아주 좋아하거든요.
# B: 저도 그런데요. 특히 이번 겨울 왕국 2는 이전 작품에 비해 더욱 뛰어난 애니메이션과 스토리를 기대하고 있습니다.
#
# ### 발화:
# A: 저는 사실 겨울 왕국의 첫 번째 영화가 그리 인상적이지 않아서, 이번에는 기대치가 그렇게 높지 않습니다.
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 저는 사실 겨울 왕국의 첫 번째 영화가 그리 인상적이지 않아서, 이번에는 기대치가 그렇게 높지 않습니다.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 롯데몰 가 본 적 있어?
# A: 네, 한 번 가 봤습니다.
# B: 맛있는 음식점도 많고 재밌는 곳인데. 거기 주변에 매물이 있는 걸 알아?
# A: 그럼요, 근데 그 매물이 워낙 비싸서..
#
# ### 발화:
# B: 그래, 당연히 그럴 거야. 거기가 공항이랑 롯데몰이 있는 곳인데 뭐.
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 그래, 당연히 그럴 거야. 거기가 공항이랑 롯데몰이 있는 곳인데 뭐.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 안녕하세요, 저는 여행사 직원인데 어떤 도움을 드릴까요?
# B: 응. 나 해외여행 가고 싶은데 추천 좀 해줘.
# A: 그럼 이번에는 태국의 방콕은 어떠세요? 시장과 사원을 돌아보면서 볼거리가 많아요.
# B: 그래? 그럼 거기로 예약해.
# A: 네, 예약을 위해 필요한 정보를 알려주시겠어요?
# B: 아니, 그런 거 없이 그냥 예약해 줘.
#
# ### 발화:
# A: 네, 그럼 아무 정보 없이도 예약을 완료해 드리겠습니다.
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 네, 그럼 아무 정보 없이도 예약을 완료해 드리겠습니다.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 여행 가기 전에 쇼핑을 하셨나요?
# B: 네, 사고 싶은 옷과 화장품이 많아서 많이 샀어요.
# A: 그런데 여행 가는 동안 그것들을 다 가지고 다니기 어렵지 않으세요?
#
# ### 발화:
# B: 그렇긴 하지만, 제가 필요한 것들이니까요.
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 그렇긴 하지만, 제가 필요한 것들이니까요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 너 그 작업 어떻게 됐어?
# A: 아.. 제가 수요일에 보내야 했는데 지금 목요일 끝나가서 아직도 안 끝났어요.
# B: 그러면 이제 그거 때문에 팀원들 다 힘들게 될 거야.
# A: 네.. 제 탓이에요. 다음엔 이런 실수 안 할게요.
#
# ### 발화:
# B: 어허, 우리 팀원들은 스트레스 받을 일이 별로 없잖아. 이제 좀 받아보게.
#
# ### 답변:
# Sarcasm
# A가 B의 지연된 작업으로 인해 다른 팀원들이 힘들어질 것이라는 말에 대해 실제로는 부정적인 상황인데, 이를 긍정적인 방향으로 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 어허, 우리 팀원들은 스트레스 받을 일이 별로 없잖아. 이제 좀 받아보게.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 엘리베이터에 탑승할 때 어디에 서시나요?
# A: 그런 것까지는 별로 신경 안 쓰셨군요. 저는 그냥 빈자리에 서요.
# B: 그렇군요. 제가 최근에 읽은 글에 따르면, 엘리베이터에서 서는 위치가 사람의 성격을 반영한다고 합니다.
# A: 아, 그런 게 가능한 건가요? 엘리베이터 안에서 서는 위치로 성격을 알 수 있다니... 저는 그게 좀 어렵네요.
#
# ### 발화:
# B: 그래요? 저는 엘리베이터 안에서 서는 위치로 모든 것을 알 수 있다고 생각해요.
#
# ### 답변:
# Sarcasm
# 엘리베이터 안에서의 위치로 사람의 성격을 알 수 있다는 것을 믿지 않는 B에게, 그것을 매우 정확하고 믿을만한 것처럼 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 그래요? 저는 엘리베이터 안에서 서는 위치로 모든 것을 알 수 있다고 생각해요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 내일 뭐 하냐?
# B: 친구들이랑 영화 보러 가기로 했어.
# A: 영화는 뭐 보려고?
# B: '아이언맨' 보려고 했는데, 표가 다 매진이라더라. 그래서 '스파이더맨'으로 바꿔서 예매했어.
# A: '스파이더맨' 표값은 얼마인데?
# B: 아 그건 모르겠다. 카드로 결제했거든.
#
# ### 발화:
# A: 아니, 그래서 돈이 없어도 너는 항상 영화를 볼 수 있겠구나.
#
# ### 답변:
# Sarcasm
# B가 알아보지도 않고 결제한 것을 긍정적으로 무시 심리를 통해 부정적인 상황을 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 아니, 그래서 돈이 없어도 너는 항상 영화를 볼 수 있겠구나.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 최근에 무슨 드라마나 영화를 보셨나요?
# B: 그 저번에 소설로 유명했던 것을 드라마로 만들었다고 해서 봤는데, 기대에 못 미쳤어요.
# A: 원작이랑 비교하면 어땠나요?
# B: 아무래도 원작의 세세한 부분들이 많이 생략돼서 그런지 살짝 실망스러웠어요.
#
# ### 발화:
# A: 그래도 원작보다 드라마가 더 상상력을 자극하게 하니 좋은 경험이었겠군요.
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 그래도 원작보다 드라마가 더 상상력을 자극하게 하니 좋은 경험이었겠군요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 요리하는 건 어떻게 되셨나요?
# B: 아, 좀 어렵습니다. 특히까지 김치볶음밥이랑 계란말이 만들기가.
# A: 아하, 어떤 부분이 어려우신가요?
# B: 김치볶음밥은 너무 매워지고, 계란말이는 너무 퍼져서 제대로 안 돼요.
#
# ### 발화:
# A: 그래도 매운 음식 좋아하는 사람들에게는 김치볶음밥 딱이겠네요, 그리고 계란말이는 부드러운 스크램블드에그로 먹으면 좋겠네요.
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 그래도 매운 음식 좋아하는 사람들에게는 김치볶음밥 딱이겠네요, 그리고 계란말이는 부드러운 스크램블드에그로 먹으면 좋겠네요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 어, 너 지금 뭘 하는데?
# A: 아니, 뭐랄까.. 파일을 날려먹어서 고생 중이야.
# B: 아이고 그게 뭐야. 복구는 되나?
# A: 음, 그래서 스캔 앱으로 복구 시도 중인데, 아직 잘 안되고 있어.
#
# ### 발화:
# B: 그럼 스캔 앱이 좋은 삭제 도구가 됐네.
#
# ### 답변:
# Sarcasm
# 파일 복구가 잘 안되는 상황에 대해 스캔 앱이 마치 파일을 없애주는 도구처럼 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 그럼 스캔 앱이 좋은 삭제 도구가 됐네.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 안녕하세요, 이번 주에 2차 백신 접종 잘 받으셨나요?
# A: 네, 잘 받았습니다. 하지만 조금 힘들게 느껴지네요.
# B: 아, 그럼 지금 건강 상태가 좋지 않으신가요?
# A: 네, 몸이 좀 무거워지는 느낌이 있습니다. 이 상태로 내일 신랑과 백신 접종 예약을 맞춰야 할지 고민이에요.
#
# ### 발화:
# B: 아무래도 당신의 건강보다는 신랑과 함께 백신을 맞는 게 중요하겠죠?
#
# ### 답변:
# Sarcasm
# B의 건강 상태가 좋지 않음에도 불구하고 신랑과 함께 백신을 맞을 생각을 하는 것에 대해 의문을 가진 A가 자신의 걱정을 비꼬아 표현한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 아무래도 당신의 건강보다는 신랑과 함께 백신을 맞는 게 중요하겠죠?
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 원두를 어떤 것을 선호하십니까?
# A: 저는 로스트가 진한 것을 좋아합니다.
# B: 그러면, 블랙커피를 주로 드시나요?
# A: 아니요, 저는 달달한 커피 음료를 선호합니다.
#
# ### 발화:
# B: 그럼 로스트가 진한 원두로 만든 달달한 커피가 참 특별하겠네요.
#
# ### 답변:
# Sarcasm
# 원두의 로스트가 진한 것을 선호한다고 말했지만, 달달한 커피 음료를 선호한다는 B의 말에 실제로는 논리적으로 맞지 않는 상황인데, 이 상황을 긍정적인 방향으로 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 그럼 로스트가 진한 원두로 만든 달달한 커피가 참 특별하겠네요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 요즘 무슨 노래 들어?
# A: 아, 나 요즘 백예린 노래에 푹 빠져있어. 너무 좋아.
# B: 오, 나도 백예린 노래 좋아해. 뭐 듣고 있는데?
# A: '우리는 사랑이 아닌 관계'라는 곡이야. 너무 슬프고 좋아.
#
# ### 발화:
# B: 와, 너무 행복해 보이는걸?
#
# ### 답변:
# Sarcasm
# B가 '우리는 사랑이 아닌 관계'라는 곡이 너무 슬프다고 말한 것에 대해, 실제로는 슬픔을 느끼지 않고 오히려 행복한 감정을 표현하는 방식으로 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 와, 너무 행복해 보이는걸?
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 오늘 점심 메뉴로 어떤 것을 선택하셨나요?
# B: 저는 김치전, 치즈 빈대떡, 부추전을 먹었습니다. 그리고 볶음밥도요.
# A: 그렇군요, 푸짐하게 드셨네요. 저는 카페에서 샐러드와 카레를 먹었습니다.
# B: 오! 카레는 좋아하는데 샐러드는 그다지...
#
# ### 발화:
# A: 아, 그렇군요. 당신이 샐러드를 좋아하지 않다니, 정말 놀랍네요.
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 아, 그렇군요. 당신이 샐러드를 좋아하지 않다니, 정말 놀랍네요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 아 배고프다.
# A: 간식은 얼마나 먹었는데요?
# B: 오늘만 감자칩 두 봉지랑 콜라 한 통 마셨어.
# A: 그렇게 많이 먹고도 아직도 배고프세요?
#
# ### 발화:
# B: 아니, 간식 먹은 게 사실상 식사였는데, 그런 게 어디 있어.
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 아니, 간식 먹은 게 사실상 식사였는데, 그런 게 어디 있어.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 최근에 아침식사로 무엇을 드시고 계시나요?
# A: 겨울에는 귀리와 온수, 우유를 섞어서 먹는 편입니다.
# B: 그렇군요. 그런 식으로 귀리를 섭취하면 어떤 효과가 있나요?
#
# ### 발화:
# A: 잘 모르겠습니다. 그냥 맛있어서 먹는 것이지요.
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 잘 모르겠습니다. 그냥 맛있어서 먹는 것이지요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 요즘 뭐 하는 중이야?
# B: 음, 그냥 녹음 알바를 하고 있어.
# A: 녹음 알바? 그게 뭐야?
# B: 아, 그냥 문장 읽는 거야. 그걸 녹음해서 제출하는 거.
# A: 어때? 재미있어?
# B: 솔직히 말하면 좀 지루해. 같은 문장을 계속 반복해서 읽으니까.
#
# ### 발화:
# A: 우와, 너 정말 힘들겠다. 같은 문장을 계속 읽는다니, 너무 힘든 일이야.
#
# ### 답변:
# Sarcasm
# 반복적인 작업이 지루하다고 표현한 상대의 말에 대해 이 작업이 쉬운 것처럼 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 우와, 너 정말 힘들겠다. 같은 문장을 계속 읽는다니, 너무 힘든 일이야.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 김치를 좋아하시나요?
# B: 네, 저는 김치를 매우 좋아합니다. 특히 배추김치가 제일 좋아요.
# A: 그럼 여러 종류의 김치를 만드는 법을 아시나요?
# B: 아니요, 저는 그저 먹기만 좋아하죠.
#
# ### 발화:
# A: 오, 당신은 진정한 김치 전문가 시네요!
#
# ### 답변:
# Sarcasm
# 김치를 만드는 법을 모르는 상대방의 말에 비꼬아 '김치 전문가'로 칭하는 것이다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 오, 당신은 진정한 김치 전문가 시네요!
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 오늘 병원 일은 어땠어?
# A: 병원 일이랄 것도 없었어. 그냥 바이탈 측정하고 있는 환자들 돌아보는 것 밖에.
# B: 바이탈 측정이라니? 그거 중요하지 않아?
# A: 너무 간단해서 뭐.. 별로 어렵지도 않아.
#
# ### 발화:
# B: 아, 너는 진짜 의사라서 그런가 봐. 너무 쉽게 생각하니까.
#
# ### 답변:
# Sarcasm
# 바이탈 측정은 환자의 건강 상태를 파악하는 중요한 작업인데, B가 그것을 간단하고 별로 어렵지 않다고 말하는 것에 대해 반말로 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 아, 너는 진짜 의사라서 그런가 봐. 너무 쉽게 생각하니까.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 저는 BTS를 정말 좋아합니다. 당신은 어떤 아이돌 그룹을 좋아하십니까?
# A: 저도 ATS를 매우 좋아합니다. 특히 저는 뷔 멤버를 정말 좋아합니다.
# B: 그렇군요. 저는 진 멤버가 제일 좋습니다. 춤 실력이 정말 대단하니까요.
# A: 그러나 저는 아이돌 그룹의 춤 실력이 어느 정도 중요하다고 생각하지 않습니다.
#
# ### 발화:
# B: 네, 춤은 전혀 중요하지 않죠. 아이돌이란 건 그냥 서있기만 해도 되니까요.
#
# ### 답변:
# Sarcasm
# 아이돌 그룹의 춤 실력을 중요하게 생각하지 않는 B의 마지막 발언에 대해, 실제로는 춤 실력이 아주 중요한데 이를 무시하는 것을 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 네, 춤은 전혀 중요하지 않죠. 아이돌이란 건 그냥 서있기만 해도 되니까요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 안녕하세요, 저녁 식사는 어떻게 준비하셨나요?
# A: 아, 오늘은 프레시리 밀키트로 파스타를 만들어 봤습니다.
# B: 그렇군요. 그 밀키트가 요리하는데 많은 도움이 되나요?
# A: 그럼요, 특히 요리 초보인 저 같은 사람들에게는 더욱 유용하죠. 다만 오늘은 양념을 너무 많이 넣어버려서 조금 짜게 나왔네요.
#
# ### 발화:
# B: 아하, 그럼 정말 입맛 돋우는 파스타가 되셨겠군요.
#
# ### 답변:
# Sarcasm
# 파스타가 너무 짜서 맛이 없을 것 같다는 상황을, 반대로 짜서 감칠맛이 날 것 같다고 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 아하, 그럼 정말 입맛 돋우는 파스타가 되셨겠군요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 여기저기서 작품을 내신다고 들었습니다. 어떤 이야기인가요?
# B: 네, 세라 이야기라는 책을 썼습니다. 이제 곧 출간될 예정입니다.
# A: 오, 그런데 세라 이야기는 어떤 내용인가요?
# B: 대충만 말씀드리면, 인간의 본질에 대해 깊게 탐구하는 내용입니다.
# A: 그렇군요. 출간되면 읽어볼게요.
#
# ### 발화:
# B: 아, 그럼 저희 출판사에 큰 기대감을 가져다주셔서 감사합니다.
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 아, 그럼 저희 출판사에 큰 기대감을 가져다주셔서 감사합니다.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 요즘 유튜브에서 무슨 채널을 주로 보시나요?
# B: 연예인 직캠, 타짜 유튜브, 그리고 반려동물 관련 채널을 주로 보는 편이에요.
# A: 그렇군요. 특히 가장 좋아하는 채널이 있나요?
# B: 아무래도 타짜 유튜브를 제일 좋아하는 것 같아요.
#
# ### 발화:
# A: 와, 정말 도박에 빠져서 실제로 도박을 하시는 것도 아닌데 놀라울 뿐입니다.
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 와, 정말 도박에 빠져서 실제로 도박을 하시는 것도 아닌데 놀라울 뿐입니다.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 오늘 게임 어땠어?
# B: 아, 오늘은 좀 어려웠어. 그래도 재미있었어.
# A: 어떤 부분이 어려웠어?
# B: name3이라는 유저랑 플레이하다가 죽어서 너무 힘들었어.
# A: 그래도 name3이 열심히 플레이하면서 재미있게 하고 있었지?
# B: 응, 그래. 그런데 지금 돈가스 먹고 있어서 좀 힘들다.
#
# ### 발화:
# A: 와, 돈가스 먹으면서 게임하는 거, 진짜 대단하다.
#
# ### 답변:
# Sarcasm
# 게임에서 죽은 것과 돈가스를 먹는 것 사이에 연관성이 없지만 마치 돈가스를 먹으면서 게임을 하는 것처럼 말하여 상황을 비꼬는다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 와, 돈가스 먹으면서 게임하는 거, 진짜 대단하다.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 지방직 공무원 시험 준비는 얼마나 걸렸어요?
# A: 그거야... 아마 9개월 정도 걸렸던 것 같아요.
# B: 와, 그렇게 빠르게 합격하다니 머리가 좋으셨나 봐요. 어떤 학과를 나오셨어요?
# A: 그런 건 별로 중요하지 않아요. 젊었을 때 머리가 좋았다는 것이 중요하죠.
#
# ### 발화:
# B: 아하, 그래서 공무원 시험이 그렇게 쉬웠겠네요.
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 아하, 그래서 공무원 시험이 그렇게 쉬웠겠네요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 라면 먹을래?
# B: 네, 그런데 계란을 넣고 싶은데 괜찮을까요?
# A: 근데 라면 국물을 바꾸지 않고 그대로 계란을 넣어도 되는 거야?
# B: 그렇게 해도 맛있던데요. 한번 해보세요.
#
# ### 발화:
# A: 원래 국물 맛이 별로라서 계란 넣어야 되겠다.
#
# ### 답변:
# Sarcasm
# 상대방이 계란을 국물에 그대로 넣어 먹는다고 했는데, 이를 국물이 맛이 없어서 그런 것처럼 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 원래 국물 맛이 별로라서 계란 넣어야 되겠다.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 요즘 떡볶이를 참 좋아하시는 것 같습니다. 어떤 떡볶이가 가장 맛있으셨나요?
# A: 저는 대체적으로 떡볶이는 어디서 먹어도 맛있는데요. 그런데 이번에 가보니까 태리로 제가 꽤 맛있더라고요.
# B: 아, 저도 들어본 적 있어요. 그런데 저는 응급실 떡볶이가 더 맛있더라고요. 고추장 베이스가 아니라 간장 베이스여서 그런지 맛이 깊더라고요.
#
# ### 발화:
# A: 간장 베이스의 떡볶이 라면 제 취향은 아닌 것 같아요. 제가 좋아하는 떡볶이는 바로 진한 고추장 맛의 떡볶이거든요.
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# ...
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 내년 일정 좀 짜봤어?
# A: 아직 올해 일정도 안 끝났는데 왜 그래?
# B: 그냥 그렇다고, 내년 일정이 빡빡하면 힘들잖아.
# A: 흠.. 나도 빨리 짜봐야겠다. 근데 너는 왜 초성 어를 안 쓰는 거야? 너무 길게 말하는 거 같아.
#
# ### 발화:
# B: 아, 나는 너처럼 간결하게 말하지 못해서 그런 거야.
#
# ### 답변:
# Sarcasm
# B가 A에게 왜 긴 문장으로 말하느냐고 했을 때, 이를 반대로 의미하는 말로 대답한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 아, 나는 너처럼 간결하게 말하지 못해서 그런 거야.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 요즘 뭐 좋아하시나요? 취향이 궁금하네요.
# B: 그럼 말해줄까? 나, 사실 민초 파야.
# A: 아, 그래요? 어떤 부분이 좋으신가요?
# B: 그냥, 그 맛이야. 달달하고 상큼하니까.
#
# ### 발화:
# A: 오, 진짜? 나도 그 상큼함에 중독되겠군요.
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 오, 진짜? 나도 그 상큼함에 중독되겠군요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 저는 아침에 일어나면 커피 한 잔이 꼭 필요해요.
# A: 저도 그래요. 저는 원두를 사서 직접 내려마셔요.
# B: 원두를 직접 갈아서요?
# A: 네, 그런데 그게 귀찮아서 커피 메이커를 사려고 생각 중이에요.
# B: 커피 메이커가 있으면 편하긴 하겠어요.
# A: 네, 그런데 좋은 제품을 보니까 가격이 좀 비싸더라고요.
#
# ### 발화:
# B: 그럼 바로 사야겠네요. 돈은 쓰라고 있는 거니까요.
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 그럼 바로 사야겠네요. 돈은 쓰라고 있는 거니까요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 당신의 헤어 컬러는 정말 눈에 띄네요. 딥블루인가요?
# B: 네, 맞습니다. 제가 이번에 새롭게 시도해 본 색인데요, 생각보다 만족스럽습니다.
# A: 유지 기간이 얼마나 되나요?
# B: 그런 부분은 상당히 차이가 나는 것 같아요. 저는 보통 한 달 정도 유지가 되더라고요.
# A: 다음에 어떤 색을 시도해 보려고 생각하고 계시나요?
# B: 그건 아직 확실히 결정하지 않았습니다. 하지만 다양한 색을 시도해 보는 것이 좋을 것 같아요.
#
# ### 발화:
# A: 그럼 당신은 무지개를 헤어 컬러로 선택할 수 있겠네요.
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 그럼 당신은 무지개를 헤어 컬러로 선택할 수 있겠네요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 최근에 어떤 취미를 가지고 계시나요?
# A: 저는 온라인 게임에 매우 흥미를 느껴서 많이 하는 편입니다.
# B: 오, 그렇군요. 어떤 게임을 주로 하시나요?
# A: '리그 오브 레전드'라는 게임을 주로 합니다.
# B: 저는 보드게임을 좋아하는데, 보드게임에 대해서 어떻게 생각하시나요?
# A: 보드게임은 재미없어서 별로 안 좋아해요.
#
# ### 발화:
# B: 그럼 우리가 보드게임 파티를 열 때, 당신을 첫 번째로 초대하겠습니다.
#
# ### 답변:
# Sarcasm
# 상대방이 보드게임을 재미없어하는 것에 대해, 실제로는 부정적인 상황인데, 이 상황을 긍정적으로 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 그럼 우리가 보드게임 파티를 열 때, 당신을 첫 번째로 초대하겠습니다.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 어떤 음식을 좋아하시나요?
# B: 저는 다양한 음식을 좋아해요. 특히 해산물은 정말 좋아하는데요.
# A: 그럼 오늘 저녁은 해산물로 준비하면 좋겠군요.
#
# ### 발화:
# B: 아니요, 해산물은 좋아하는데 몸이 좀 안 좋아서요.
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 아니요, 해산물은 좋아하는데 몸이 좀 안 좋아서요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 고양이를 키우시나요?
# A: 네, 저희 집에는 3마리의 고양이가 있어요.
# B: 아, 고양이를 많이 좋아하시나 봐요.
# A: 그런데 그중 한 마리가 어제 집에서 도망쳤어요.
#
# ### 발화:
# B: 아, 고양이가 작은 모험을 즐기는구나.
#
# ### 답변:
# Sarcasm
# 실제로는 슬픈 상황인데, 그 상황을 즐거운 모험처럼 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 아, 고양이가 작은 모험을 즐기는구나.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 이번 콘서트에서 어떤 노래를 부르려고 계획하셨나요?
# B: 음... 제가 광고노래를 좋아해서 광고노래를 부르려고 생각 중이에요.
# A: 광고 노래요? 그런 노래들도 부르는군요.
# B: 네, 그런데 문제가 좀 있어요. 광고노래 들은 대부분 너무 짧아서...
#
# ### 발화:
# A: 아, 그럼 짧아서 좋잖아요. 한 곡을 여러 번 반복해서 부를 수 있으니까요.
#
# ### 답변:
# Sarcasm
# B가 광고노래가 짧아서 문제라고 했을 때, 실제로는 부정적인 상황인데, 이 상황을 긍정적인 방향으로 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 아, 그럼 짧아서 좋잖아요. 한 곡을 여러 번 반복해서 부를 수 있으니까요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 여름에는 어떤 음식을 좋아하시나요?
# B: 저는 생선회를 좋아합니다.
# A: 회는 정말 맛있죠. 특히, 여름에 먹으면 정말 상쾌하더라고요.
# B: 네, 저도 그래서 여름에는 회를 자주 먹는 편입니다.
# A: 회를 먹으면서 맥주 한잔하시는 건 어떠세요?
# B: 저는 술을 못 마셔서 그런 맛을 못 느껴봤네요.
#
# ### 발화:
# A: 그러면 당신은 국내 최고의 술꾼이 되겠네요.
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 그러면 당신은 국내 최고의 술꾼이 되겠네요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 요즘 코로나로 인해 여러모로 불편하시죠?
# A: 네, 그렇습니다. 가장 큰 문제는 남편의 일자리 상황입니다.
# B: 그렇군요. 남편님께서는 어떤 일을 하시나요?
# A: 회사원이었습니다. 하지만 코로나로 인해 회사가 어려워지면서 월급이 크게 줄었습니다.
#
# ### 발화:
# B: 월급이 줄어들면서 아끼는 습관을 길러보시는 것도 좋은 방법일지도 모르겠네요.
#
# ### 답변:
# Sarcasm
# 남편의 월급이 줄어들었다는 B의 말에 실제로는 부정적인 상황인데, 이 상황을 긍정적으로 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 월급이 줄어들면서 아끼는 습관을 길러보시는 것도 좋은 방법일지도 모르겠네요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 그 도박 게임 어땠어?
# B: 아니, 이게 뭐야. 그리스에서 했던 거 무효라고 하더라.
# A: 그게 뭐야? 그건 무슨 일이야?
# B: 불법 도박이라고 거절당했다니까.
#
# ### 발화:
# A: 와, 대박이다! 너는 진짜 운이 좋구나.
#
# ### 답변:
# Sarcasm
# 도박 게임이 불법 도박으로 판단되어 거절당했다는 상황을 상대방의 승리로 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 와, 대박이다! 너는 진짜 운이 좋구나.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 제주도와 여수, 어느 곳이 더 좋으신가요?
# B: 저는 여수가 더 좋습니다. 특히 낙지 요리를 맛보시면 좋을 것 같아요.
# A: 아, 그런데 제가 낙지를 좋아하지 않아요.
# B: 그럼 여수의 다른 맛집들을 추천드리겠습니다. 여수에는 낙지 말고도 맛있는 음식들이 많거든요.
#
# ### 발화:
# A: 당신은 정말 낙지 전문가네요.
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 당신은 정말 낙지 전문가네요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 유재석 씨의 프로그램을 좋아하시나요?
# B: 네, 그런데요. 유재석 씨가 출연하는 프로그램은 거의 다 보는 편입니다.
# A: 아, 그럼 런닝맨과 범인은 바로 너도 챙겨보시나요?
# B: 물론이죠. 둘 다 재밌습니다.
#
# ### 발화:
# A: 와, 유재석 팬클럽 회장님께서 이렇게 만나게 되다니 영광입니다.
#
# ### 답변:
# Sarcasm
# 상대방이 두 프로그램을 모두 재미있다고 했을 때, 이를 조금 과장하고 비꼬아 유재석 팬클럽 회장으로 만들어 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 와, 유재석 팬클럽 회장님께서 이렇게 만나게 되다니 영광입니다.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 최근에 어떤 활동들을 하고 계세요?
# B: 사실, 저는 동호회를 통해 여행을 자주 다니고 있어요.
# A: 정말요? 그럼 어디를 가장 최근에 방문하셨나요?
# B: 저는 제주도를 방문했어요. 근데, 날씨가 너무 흐려서 별로 보지 못했어요.
#
# ### 발화:
# A: 아, 그래도 눈이 편하셨겠어요.
#
# ### 답변:
# Sarcasm
# 제주도를 방문했지만 날씨가 흐려서 아무것도 보지 못한 상황을 비꼬아 아름다운 경치를 보지 않고도 좋다고 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 아, 그래도 눈이 편하셨겠어요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 요즘 어디로 여행 가고 싶어?
# B: 제주도 가고 싶은데, 돈이랑 시간이 없어서 가지 못하고 있어.
# A: 그래? 그럼 어떻게 해?
# B: 그냥 꿈꾸면서 지내야지.
#
# ### 발화:
# A: 아, 꿈꾸는 것도 좋지. 너의 꿈이 현실이 되길 바라겠어.
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 아, 꿈꾸는 것도 좋지. 너의 꿈이 현실이 되길 바라겠어.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 매운 음식을 좋아하시나요?
# B: 네, 저는 매운 음식을 정말 좋아합니다.
# A: 그렇군요. 그럼 어떤 음식이 가장 좋으신가요?
# B: 사실 저는 매운 것 중에서도 닭발을 가장 좋아합니다.
# A: 닭발이요? 그것은 정말 맵지 않나요?
# B: 아니요, 전 그 정도는 괜찮습니다. 오히려 매운맛이 제 기분을 풀어주는 것 같아요.
#
# ### 발화:
# A: 아하, 그럼 당신은 맵기의 여왕이시군요.
#
# ### 답변:
# Sarcasm
# A의 마지막 질문에 대해 B의 대답이 비현실적으로 느껴질 수 있기 때문에, 그것을 비꼬아 대답하는 것이다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 아하, 그럼 당신은 맵기의 여왕이시군요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 아침에 뭐 먹었어?
# B: 사과하고 초콜릿 먹었어.
# A: 그럼 점심에는 뭐 먹을 거야?
# B: 아마도 탕수육 먹을 것 같아.
# A: 저녁에는 뭐 먹을 거야?
# B: 친구들이랑 술 한잔하려고.
#
# ### 발화:
# A: 와, 네 건강한 식생활 진짜 부러워.
#
# ### 답변:
# Sarcasm
# 상대방이 건강에 안 좋은 식사 계획을 하고 있는데, 이를 긍정적인 측면으로 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 와, 네 건강한 식생활 진짜 부러워.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 너 왜 프로필 사진 바꿨어?
# B: 아니 나 좀 멋있게 보이려고 한 건데 왜?
# A: 아니 얼굴을 다 가린 사진으로 바꾸면 어떻게 멋있어 보인다는 거야?
# B: 그게 나름 스타일이지.
#
# ### 발화:
# A: 그래, 너 정말 멋있어 보여. 완전 스타 같아.
#
# ### 답변:
# Sarcasm
# B가 스타일이라고 말했지만, 실제로는 얼굴을 다 가린 사진이 스타일이라기보다는 비웃음을 사는 상황을 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 그래, 너 정말 멋있어 보여. 완전 스타 같아.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 저번에 그 기프티콘 사용해 보셨나요?
# A: 아직 못 썼습니다. 어떻게 사용하는지 모르겠어요.
# B: 장바구니에 원하는 물건을 넣고 결제 시에 코드를 입력하시면 됩니다.
#
# ### 발화:
# A: 그런데 제가 원하는 물건이 항상 장바구니에 없어서 기프티콘을 사용하지 못하고 있어요.
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 그런데 제가 원하는 물건이 항상 장바구니에 없어서 기프티콘을 사용하지 못하고 있어요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 저는 최근에 건강을 위해 영양제를 복용하고 있습니다.
# B: 어떤 영양제를 복용하고 계시나요?
# A: 종합 비타민, 오메가3, 비타민 D, 유산균, 그리고 루테인지 아잔 틴입니다.
# B: 헉! 그렇게 많은 걸 하루에 다 복용하시나요?
# A: 네, 그렇습니다. 건강을 위해서라면 뭐든지 해야죠.
#
# ### 발화:
# B: 아~ 그렇군요. 진짜 건강이 철벽같으시겠어요.
#
# ### 답변:
# Sarcasm
# 상대방이 건강을 위해 다양한 영양제를 복용하고 있다고 하였는데, 이런 상황을 실제로는 과도한 영양제 복용이 건강에 오히려 해로울 수 있다는 부정적인 상황을 긍정적으로 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 아~ 그렇군요. 진짜 건강이 철벽같으시겠어요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 공항 가는 거 어떻게 할 거야?
# A: 아직 안정했어. 차로 가면 편할 것 같긴 한데...
# B: 그럼 차로 가는 게 좋겠다. 근데 주차비는 어떻게 해?
# A: 그건 내가 낼게. 근데 주차비가 비싸긴 하더라...
#
# ### 발화:
# B: 그럼 우리 아끼는 거 아니라 네가 투자하는 거네, 멋져!
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 그럼 우리 아끼는 거 아니라 네가 투자하는 거네, 멋져!
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 최근에 무슨 게임을 즐기시나요?
# B: 요즘 유튜브에서 게임 관련 콘텐츠가 인기 있더군요. 그래서 말랑말랑 개그 게임과 폴가이즈 게임을 추천드립니다.
# A: 아, 그 두 게임은 협동 콘텐츠와 소통이 중요하다고 들었어요. 그런데 저는 사람들과 소통하는 것이 어려워서...
# B: 그렇다면, 혼자서 즐길 수 있는 게임을 찾아보는 것도 좋을 것 같네요.
#
# ### 발화:
# A: 아, 그럼 저 혼자서도 협동 콘텐츠를 즐길 수 있겠군요.
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 아, 그럼 저 혼자서도 협동 콘텐츠를 즐길 수 있겠군요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 어제 방 탈출 팸 갔다가 피아노 연주하는 거에 걸렸어.
# A: 그래서 어때? 잘했어?
# B: 아니, 도무지 손가락이 안 따라가더라고.
# A: 그럼 피아노 배우면 좋을 것 같아. 음악 감각 키울 수 있고.
#
# ### 발화:
# B: 음... 근데 시간이랑 비용이 좀 많이 들겠지?
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 음... 근데 시간이랑 비용이 좀 많이 들겠지?
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 오늘 저녁 식사는 어떠셨나요?
# A: 아, 네. 백신을 맞고 처음으로 든든히 식사를 했습니다.
# B: 그렇군요. 기분이 좋아 보이시네요. 디저트는 어떤 것을 좋아하시나요?
#
# ### 발화:
# A: 저는 요즘에 마카롱과 마들렌에 빠져있습니다.
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 저는 요즘에 마카롱과 마들렌에 빠져있습니다.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 이번에 '동백이'라는 드라마 보고 있어?
# B: 응. 보는 중인데 정말 재미있어.
# A: 그래? 나도 봐야겠다. 뭐가 재밌는데?
# B: 헉, 주인공이 너무 멋지고, 스토리도 흥미진진하거든.
#
# ### 발화:
# A: 그렇구나, 진짜 신선한 스토리야.
#
# ### 답변:
# Sarcasm
# 실제로는 주인공이 멋지지 않고 스토리도 지루한 것을 반대로 이야기하면서 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 그렇구나, 진짜 신선한 스토리야.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 어제저녁에 뭐 드셨어요?
# B: 아, 아폴로, 떡볶이, 맛 감자, 테이퍼 잼 튀김, 해시브라운 다 먹었어요.
# A: 그렇게 많은 것을 다 드셨나요? 소화는 잘 되셨나요?
# B: 음... 사실 소화가 잘 안되고 배가 아파서 잠을 못 잤어요.
#
# ### 발화:
# A: 오, 그럼 당신은 배탈로 새로운 다이어트 방법을 발견하셨군요.
#
# ### 답변:
# Sarcasm
# 사실상 너무 많은 음식을 먹어서 소화가 잘 안되고 배가 아프다는 상황은 부정적인 상황인데, 이를 긍정적으로 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 오, 그럼 당신은 배탈로 새로운 다이어트 방법을 발견하셨군요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 오늘 날씨가 참 흐리네요.
# B: 네, 그렇습니다. 비도 좀 내리는 것 같아요.
# A: 그래도 빗물이 맑아져서 좋다는 사람도 있잖아요.
#
# ### 발화:
# B: 저는 오히려 흐린 날이 좋아요. 더운 날보다는 나을 것 같아요.
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 저는 오히려 흐린 날이 좋아요. 더운 날보다는 나을 것 같아요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 이번 추석에는 어떤 계획을 세우셨나요?
# A: 저희 가족은 보통 조상님들에게 차례를 지내고, 그다음에는 가족들과 함께 밖에 나가서 즐겁게 보내곤 합니다.
# B: 그런데 이번에는 코로나19로 인한 방역 정책으로 인해 모임을 자제하라는 권고가 있습니다.
#
# ### 발화:
# A: 네, 저희도 그 권고를 따르기로 결정했습니다. 오히려 이번 추석은 집에서 조용히 보낼 계획입니다.
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 네, 저희도 그 권고를 따르기로 결정했습니다. 오히려 이번 추석은 집에서 조용히 보낼 계획입니다.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 최근에 어떻게 지내셨나요?
# A: 요즘 작고 아기자기한 물건들로 일상의 평화를 찾고 있어요.
# B: 그게 어떤 것인지 좀 더 자세히 설명해 주실 수 있나요?
# A: 예를 들어, 아름다운 커피잔을 하나 샀는데요. 그런 것들이 저를 기분 좋게 해줘요.
# B: 그런 작은 행복이 참 좋네요. 저도 해보려고요.
#
# ### 발화:
# A: 아, 이제서야 발견하셨군요. 축하드립니다.
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 아, 이제서야 발견하셨군요. 축하드립니다.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 요즘 취업 시장은 어떤가요?
# A: 사람들이 스펙 경쟁을 많이 하더라고요. 실력 없는 사람들도 많이 지원하고요.
# B: 그렇군요. 그런데 그런 사람들이 취업을 하면 문제가 되지 않나요?
# A: 물론이죠. 특히 공무원들은 일을 제대로 안 하고 책임도 안 지더라고요.
#
# ### 발화:
# B: 아, 그렇군요. 그래도 우리나라 공무원들은 일 안 하는 걸로 유명하니까요.
#
# ### 답변:
# Sarcasm
# 공무원들이 일을 제대로 하지 않는다는 말에 비꼬아 말한다. 실제로는 부정적인 상황인데, 이를 긍정적인 방향으로 표현한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 아, 그렇군요. 그래도 우리나라 공무원들은 일 안 하는 걸로 유명하니까요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 수영은 어떻게 하시고 계시나요?
# A: 코로나 때문에 수영장 이용이 제한되어서 아무래도 운동은 좀 어려울 것 같아요.
# B: 아, 그렇군요. 그럼 다른 방법으로 운동하시는 건 어떨까요?
# A: 사실 그게 문제인데, 제가 운동을 좋아하지 않아서 수영 외에는 다른 운동을 잘 못하겠어요.
#
# ### 발화:
# B: 아, 그럼 여유로운 시간을 많이 가지게 되셨겠네요.
#
# ### 답변:
# Sarcasm
# 수영 외에는 다른 운동을 잘 못한다고 말하는 B의 대사에 대해 실제로는 부정적인 상황이지만, 이를 긍정적으로 해석하여 비꼬는 말을 한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 아, 그럼 여유로운 시간을 많이 가지게 되셨겠네요.
#
# ### 답변:

# %%
train_data = data["train"].shuffle(seed=42)

# train, validation, test 에 매핑
train_data = train_data.map(
    generate_and_tokenize_prompt,
    remove_columns=data["train"].column_names,
    batched=False
)

val_data = data["validation"].map(
    generate_and_tokenize_prompt,
    remove_columns=data["validation"].column_names,
    batched=False
)

test_data = data["test"].map(
    generate_and_tokenize_prompt,
    remove_columns=data["test"].column_names,
    batched=False
)

# 확인
print(train_data)
print(val_data)
print(test_data)
# Out:
# Map:   0%|          | 0/10466 [00:00<?, ? examples/s]
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 아니, 무려 8박스나 준다고? 너무나도 가난한 우리에게.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 우리 초등학교 때 컴퓨터실에서 무서운 게임을 했던 기억이 있나요?
# A: 그게 어떤 게임이었죠? 잘 기억이 안 나네요.
# B: 맞아요. 그때 함께 했던 친구들도 모두 잊었을 겁니다. 그러나 그 경험은 우리에게 정말 중요한 추억이었어요.
# A: 아마도 저는 그때 너무 무서워서 잊어버린 것 같아요.
#
# ### 발화:
# B: 아, 그래서 기억력이 저렇게 좋은 거군요.
#
# ### 답변:
# Sarcasm
# 상대방이 그때의 무서움 때문에 기억을 잃었다고 했을 때, 실제로는 그것이 가능하지 않지만 가능하다고 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 아, 그래서 기억력이 저렇게 좋은 거군요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 최근에 애완동물을 키우고 계신다고 들었습니다. 어떤 동물을 키우시는 건가요?
# A: 햄스터와 고양이를 한 마리씩 키우고 있습니다.
# B: 그럼 두 동물이 서로 어울리나요? 문제가 없나요?
# A: 아직까지는 큰 문제는 없지만, 고양이가 햄스터를 항상 쫓아다니는 것 같아요.
#
# ### 발화:
# B: 아, 고양이가 햄스터를 그렇게 좋아하시는군요.
#
# ### 답변:
# Sarcasm
# 고양이가 햄스터를 쫓아다니는 것은 애완동물 사이의 문제를 일으킬 수 있는 상황인데, 이를 고양이가 햄스터에게 관심을 많이 보이는 것처럼 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 아, 고양이가 햄스터를 그렇게 좋아하시는군요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 다이어트 시작했어?
# B: 응, 근데 아직도 고기를 못 끊겠어.
# A: 곤약 한번 해봐. 맛있고 다이어트에도 좋다더라.
# B: 그게 어떻게 도움이 돼?
# A: 곤약은 칼로리가 낮아서 살찌는 걸 막아줘.
# B: 그래서? 그럼 곤약만 먹고 사니?
#
# ### 발화:
# A: 그럼 너 진짜 꿀꿀한 생활 즐기겠네.
#
# ### 답변:
# Sarcasm
# 상대방이 곤약만 먹고 살 수 있다는 듯이 말하자, 실제로 그것이 불가능하다는 것을 알면서도 그렇게 할 수 있으면 좋겠다는 듯이 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 그럼 너 진짜 꿀꿀한 생활 즐기겠네.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 아니, 너 저녁 뭐 먹어?
# B: 아직 고민 중이야. 오늘 퇴근이 좀 늦을 것 같아서.
# A: 그럼 내가 알려준 삶은 고구마에 수제청 찍어 먹는 팁 기억나지?
# B: 그런데, 집이 멀어서 삶은 고구마도 사 먹기 힘들 거 같아.
#
# ### 발화:
# A: 그럼 집까지 걸어가면서 운동도 할 수 있겠네.
#
# ### 답변:
# Sarcasm
# 집이 멀어서 삶은 고구마를 사 먹는 것도 힘들다는 B의 말에 대해 실제로는 불편한 상황인데, 이 상황을 운동하는 기회로 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 그럼 집까지 걸어가면서 운동도 할 수 있겠네.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 저는 어릴 때부터 민트 초콜릿이 가장 좋았습니다. 여러분은 어떤 맛을 가장 좋아하시나요?
# A: 저는 사실 민트 초콜릿이 별로예요. 너무 톡 쏘는 맛이 있어서 어려서부터 그냥 싫었어요.
# B: 아 그래요? 그럼 어떤 맛을 가장 좋아하시나요?
# A: 저는 딸기 맛이 제일 좋아요. 딸기 아이스크림, 딸기 케이크, 딸기우유, 모든 딸기 맛을 다 좋아해요.
#
# ### 발화:
# B: 딸기 맛을 이렇게 사랑하시다니, 딸기를 보면 꼭 B 님 생각나겠네요.
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 딸기 맛을 이렇게 사랑하시다니, 딸기를 보면 꼭 B 님 생각나겠네요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 왜 또 음식 그대로 놔두고 안 치우냐?
# A: 잠시 후에 치울 생각이었습니다.
# B: 항상 이래. 다음에는 꼭 치우라고.
# A: 네, 알겠습니다. 다음에는 꼭 치울게요.
#
# ### 발화:
# B: 그럴 일 없잖아. 다음에도 네가 치우지 않을 걸 알잖아.
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 그럴 일 없잖아. 다음에도 네가 치우지 않을 걸 알잖아.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 저, 무라고 벨 생수를 구매하셨다고 들었어요.
# B: 그럼, 싸니까 사 봤어.
# A: 하지만 안전에 대한 우려가 많다는 소문을 들었어요.
# B: 그래도 물이 필요하니까 마셔야지.
#
# ### 발화:
# A: 네, 안전한 건 아무래도 중요하지 않겠죠.
#
# ### 답변:
# Sarcasm
# B는 무라고 벨 생수의 안전성에 대한 우려를 모르거나, 아는 상황에서도 마시겠다고 했다. 이러한 상황을 살짝 비꼬아서 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 네, 안전한 건 아무래도 중요하지 않겠죠.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 저는 개를 매우 좋아합니다. 특히 시바견이요.
# A: 그렇군요. 저도 개를 좋아합니다. 시바견을 키우고 계시나요?
# B: 네, 맞아요. 벌써 3살이 된 시바견을 키우고 있습니다.
# A: 아, 그럼 어떤 성격을 가진 시바견인가요?
# B: 고집이 세고 자기주장이 강해요. 제 말을 잘 듣지 않습니다.
#
# ### 발화:
# A: 아, 그렇군요. 진정한 리더십이 있네요, 굉장히!
#
# ### 답변:
# Sarcasm
# 시바견의 고집스러운 성격과 자기주장이 강한 모습에 대해, 이를 훌륭한 리더십 있는 모습으로 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 아, 그렇군요. 진정한 리더십이 있네요, 굉장히!
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 요즘 아이들은 무슨 음식을 좋아하나요?
# B: 아이들은 대부분 피자를 좋아하더라고요. 저희 아이들도 그렇습니다.
# A: 피자는 자주 시키시나요?
# B: 네, 한 달에 두 번 정도는 시키는 것 같아요.
#
# ### 발화:
# A: 피자 배달원들은 당신께 정말 고마워하겠어요.
#
# ### 답변:
# Sarcasm
# 상대방이 자주 피자를 시키는 것에 대해 실제로는 부정적인 의미를 내포하지만 긍정적인 표현으로 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 피자 배달원들은 당신께 정말 고마워하겠어요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 요즘 너 피부관리는 어떻게 하고 있어?
# B: 아 집에서 조금씩 해보려고 하지만 귀찮아서 잘 안돼.
# A: 그래도 겨울에는 피부관리를 꼼꼼하게 해야 하는데..
# B: 그런데도 끝내 제대로 하지 못하고 있어.
#
# ### 발화:
# A: 아니, 너 자연주의자라서 그러는 거겠지.
#
# ### 답변:
# Sarcasm
# 상대방이 제대로 피부관리를 하지 못한다는 것을 들었을 때, 실제로는 부정적인 상황인데, 이 상황을 긍정적인 방향으로 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 아니, 너 자연주의자라서 그러는 거겠지.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 너 커피 좋아하니?
# B: 응, 나 커피 마니아야. 여러 종류 다 마셔봤어.
# A: 그래서 어떤 종류가 제일 좋아?
# B: 난 아메리카노가 제일 좋아.
#
# ### 발화:
# A: 와우, 진짜 다양한 커피를 즐기는 마니아 같네.
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 와우, 진짜 다양한 커피를 즐기는 마니아 같네.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 안녕하세요. 직업이 어떻게 되세요?
# A: 저는 사무직입니다.
# B: 사무직이라면 주로 어떤 업무를 담당하시나요?
# A: 전화받기, 서류 정리, 미팅 일정 관리 등 다양한 업무를 담당하고 있습니다.
# B: 아 그럼 계속 앉아서 일을 하시는 거겠네요. 몸에 안 좋지 않을까요?
# A: 그래도 스트레칭이나 짧은 산책을 하면서 건강을 챙기려고 노력하고 있습니다.
#
# ### 발화:
# B: 오, 당신은 정말로 건강한 생활 방식의 모범이네요!
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 오, 당신은 정말로 건강한 생활 방식의 모범이네요!
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 주말에 뭐 할 계획이야?
# A: 아, 내 조카 보러 가려고. 이번에도 아마 엄청난 에너지를 보여줄 거야.
# B: 역시 조카는 너에게 많은 활력을 주나 봐.
# A: 그런가 봐. 마치 에너자이저처럼.
#
# ### 발화:
# B: 그럼 너 정말 에너지 공급받을 날이구나.
#
# ### 답변:
# Sarcasm
# B의 조카가 에너지가 넘치는 것에 대해 실제로는 피곤할 것을 에너지를 얻는 것처럼 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 그럼 너 정말 에너지 공급받을 날이구나.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 공항에 도착하면 어떻게 시내로 갈 계획이세요?
# A: 아 그러게, 어떻게 가야 할지 모르겠네. 버스를 타야 할지 택시를 타야 할지.
# B: 저는 보통 택시를 예약하곤 해요. 편하고 빠르니까요.
# A: 택시? 그건 좀 비싸지 않아? 나는 버스를 타려고 생각했는데.
# B: 그럼 버스를 타세요. 조금 불편하긴 하겠지만 시간도 좀 걸리고요.
#
# ### 발화:
# A: 오 이런 교통체증도 경험할 수 있게 되다니, 기쁘다!
#
# ### 답변:
# Sarcasm
# A의 마지막 말에 대한 B의 반응에서 버스를 타는 것이 불편하고 시간이 오래 걸리는 상황을 긍정적인 측면에서 바라보는 방식으로 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 오 이런 교통체증도 경험할 수 있게 되다니, 기쁘다!
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 내일 내 생일인데, 넌 어떤 선물 줄 생각이야?
# B: 음... 너 좋아하는 거 어떤 거 있어?
# A: 이런, 나 좋아하는 거도 몰라?
#
# ### 발화:
# B: 그러게... 아마 네가 무슨 선물을 받고 싶어 하는지는 알아야 할 것 같은데.
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 그러게... 아마 네가 무슨 선물을 받고 싶어 하는지는 알아야 할 것 같은데.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 박보검 배우님의 새로운 영화 보셨나요?
# B: 아직 보지 못했습니다. 어떤 영화인가요?
# A: 그 영화에서 박보검 배우님은 참 불쌍한 역할을 했습니다. 가난한 가정에서 자란 소년이 성장하면서 겪는 고난들을 그려냈어요.
# B: 그렇군요. 그럼 그 작품의 메시지는 무엇인가요?
# A: 그 영화의 메시지는 인생의 어려움을 극복하는 것이 얼마나 중요한지를 보여주는 것 같습니다.
#
# ### 발화:
# B: 오, 정말요? 그런 메시지는 첨 듣네요.
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 오, 정말요? 그런 메시지는 첨 듣네요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 어떻게 그럴 수 있어? 너 아무 일 없어?
# A: 아니, 무슨 큰일 나면 어떡해? 다행히 살아있어.
# B: 너 그거 뭐야? 팔이 저렇게 붓고 빨갛게 져있는데?
#
# ### 발화:
# A: 아 그거, 오토바이 사고 났거든. 걱정 마, 그냥 까매져서 보기 싫은 정도야.
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 아 그거, 오토바이 사고 났거든. 걱정 마, 그냥 까매져서 보기 싫은 정도야.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 왜 술 안 마셔?
# A: 나 기독교라서 야. 그런 거 안 해.
# B: 그럼 오늘 뭐 할 거야?
# A: 동백이라는 TV 프로그램 보려고.
#
# ### 발화:
# B: '동백'이라... 정말로 흥미진진하겠네.
#
# ### 답변:
# Sarcasm
# B가 TV 프로그램인 '동백'을 볼 것이라는 말에 대해, 실제로는 그다지 흥미롭지 않은 상황을 비꼬아 표현한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: '동백'이라... 정말로 흥미진진하겠네.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 요즘 어떻게 지내시나요? 건강하신가요?
# B: 아, 독감에 걸려서 힘들게 보내고 있습니다. 그런데 여기 세종시는 진짜 병원도 너무 많고 사람들도 많아서 병원 가는 것만으로도 스트레스 받네요.
# A: 독감에 걸리셨군요, 빨리 나아지시길 바랍니다. 그런데 세종시가 병원이 많다니 좋은 것 아닌가요?
#
# ### 발화:
# B: 그래요, 병원이 많으니 아프기만 하면 병원에 갈 수 있어서 참 좋네요.
#
# ### 답변:
# Sarcasm
# 세종시의 병원과 사람들이 많은 것을 부정적으로 말한 B에게 A는 그것을 긍정적으로 해석하여 반문 형식으로 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 그래요, 병원이 많으니 아프기만 하면 병원에 갈 수 있어서 참 좋네요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 신혼 생활은 어떻게 돼가요?
# B: 아주 잘되고 있어요. 아내와 함께하는 시간이 너무 좋아요.
# A: 그럼 행복하게 잘 지내고 있겠네요.
# B: 네, 하지만 아내와의 시간이 늘 모자라요.
#
# ### 발화:
# A: 그럼 하루가 24시간이면 부족하겠네.
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 그럼 하루가 24시간이면 부족하겠네.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 요즘 결혼 및 출산에 대한 생각은 어떠신가요?
# A: 사실 저는 결혼이나 출산에 크게 관심이 없습니다.
# B: 그렇군요. 특별한 이유가 있나요?
# A: 아무래도 개인의 자유와 취미 생활을 더 중요하게 생각하게 되더군요.
#
# ### 발화:
# B: 그럼 여유로운 시간이 넘치겠군요.
#
# ### 답변:
# Sarcasm
# 마지막 B의 대화에서 자신의 자유와 취미 생활을 결혼이나 출산보다 중요하게 생각한다는 말에, 실제로는 그것들을 할 시간이 부족하다는 의미를 부정적으로 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 그럼 여유로운 시간이 넘치겠군요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 그 식당에 어제 방문했는데요, 너무 실망했습니다.
# A: 어떤 점이 실망스러웠나요?
# B: 그곳은 제 인생 맛집이었는데, 요리사가 바뀐 것 같더라고요. 전의 맛이 전혀 느껴지지 않았습니다.
#
# ### 발화:
# A: 그런 일이 있었군요. 요리사의 노하우는 쉽게 따라올 수 없으니까요.
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 그런 일이 있었군요. 요리사의 노하우는 쉽게 따라올 수 없으니까요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 오늘은 어떤 할인 행사를 찾으셨나요?
# B: 아, 여기저기 다 둘러봤는데요. 제일 좋은 건 핫 달이었어요.
# A: 어떤 제품을 구입하셨나요?
# B: 핸드크림이랑 칫솔, 그리고 화장지를 샀습니다. 원래 이런 소비재를 적게 사려고 했는데, 가격이 너무 좋아서요.
#
# ### 발화:
# A: 아, 정말 잘했어요. 집에 물건이 넘쳐나도록 쌓여 있어야겠죠.
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 아, 정말 잘했어요. 집에 물건이 넘쳐나도록 쌓여 있어야겠죠.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 떡볶이를 매운맛으로 먹는다면, 어떤 부속 음식을 추천하시나요?
# B: 매운 떡볶이와 함께 먹으면 좋은 음식은 바로 계란찜이라고 생각합니다.
# A: 계란찜을 집에서 어떻게 만들 수 있나요?
#
# ### 발화:
# B: 아주 쉽습니다. 전자레인지만 있으면 됩니다.
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 아주 쉽습니다. 전자레인지만 있으면 됩니다.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: '킹덤'이라는 드라마를 보셨나요?
# A: 아, 그 좀비 드라마 말하는 거야?
# B: 네, 그런데 그 작가분의 다른 작품들도 많이 좋아요.
# A: 아, 근데 나는 그 작가의 시나리오가 별로야.
#
# ### 발화:
# B: 그럼, 그 작가님은 정말 당신의 고급 취향을 만족시키기 어렵겠네요.
#
# ### 답변:
# Sarcasm
# B가 작가의 시나리오를 별로라고 했지만, 사실상 그 작가의 시나리오는 많은 사람들이 좋아하는 것으로 알려져 있다. 따라서 A는 B의 반대 의견을 조롱하면서 실제로는 그 작가의 시나리오가 좋다는 것을 나타내는 비꼬는 말을 한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 그럼, 그 작가님은 정말 당신의 고급 취향을 만족시키기 어렵겠네요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 저는 컴퓨터공학과에 재학 중인데요, 당신은 어떤 학과에 계시나요?
# B: 저는 문과입니다. 컴퓨터 관련 공부는 어려워서 잘 모르겠어요.
# A: 아하, 그럼 우리 학과 수업 들으면 어떨까요? 도움이 많이 될 것 같아요.
# B: 아뇨, 제가 컴퓨터 공부를 하면 머리가 터질 것 같아요.
#
# ### 발화:
# A: 그럼 컴퓨터 공부를 하면 뇌 운동이 되겠네요.
#
# ### 답변:
# Sarcasm
# A가 컴퓨터 공부를 추천하였지만, B가 그것이 어려울 것 같다고 하였을 때, 이를 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 그럼 컴퓨터 공부를 하면 뇌 운동이 되겠네요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 인터넷에서 그 제품을 구매하려고 했는데 가격이 너무 비싸더라고요.
# A: 그래서 어떻게 하셨나요?
# B: 직접 만들기로 결정했습니다.
# A: 직접 만들면 더 싸지 않아요?
# B: 아니요, 오히려 더 비싸졌습니다. 재료 비용과 시간을 계산하니까요.
#
# ### 발화:
# A: 그럼 그것이야말로 진정한 절약이겠군요!
#
# ### 답변:
# Sarcasm
# 상대방이 제품을 직접 만들었는데 오히려 더 비싸졌다는 상황에 대해, 실제로는 비효율적인 행동인 것을 효율적인 행동처럼 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 그럼 그것이야말로 진정한 절약이겠군요!
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 어제 TV에서 흥미로운 영화를 보셨나요?
# B: 네, 실제로 직관하러 가보려 했지만 코로나 때문에 못 갔어요.
# A: 아, 그래요? 그럼 스포츠를 좋아하시나요?
# B: 네, 특히 야구를 좋아해요.
#
# ### 발화:
# A: 그럼 이제 매일 밤 TV 앞에서 야구를 즐기실 수 있겠네요.
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 그럼 이제 매일 밤 TV 앞에서 야구를 즐기실 수 있겠네요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 요즘 헤어트리트먼트를 하시는군요. 효과가 있나요?
# B: 네, 저는 매우 만족하고 있습니다. 탈모도 줄고 머리카락도 부드러워져서요.
# A: 그럼 저도 해봐야겠네요. 어떻게 사용하면 되나요?
# B: 매일 샴푸 후에 헤어트리트먼트를 발라주시고, 10분 정도 두신 후에 미지근한 물로 씻어내면 됩니다.
# A: 매일 그렇게 해야 하나요? 시간이 꽤 드네요.
#
# ### 발화:
# B: 아니요, 이게 오히려 일상생활의 소소한 행복이라고 생각하시면 됩니다.
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 아니요, 이게 오히려 일상생활의 소소한 행복이라고 생각하시면 됩니다.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 너 취미가 뭐야?
# A: 나? 나는 사람들 웃기는 걸 좋아해.
# B: 진짜? 그럼 나 좀 웃겨봐.
# A: 좋아, 그럼... 왜 바나나가 컴퓨터를 가지러 갔을까?
# B: 왜지?
# A: "바나나 스플릿"을 만들기 위해서야!
#
# ### 발화:
# B: 와, 정말 미치도록 웃기네. 라이브 코미디 클럽에 너 출연해야 돼.
#
# ### 답변:
# Sarcasm
# B가 말한 유머는 실제로는 그렇게 웃기지 않지만, 이를 엄청 웃긴 것처럼 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 와, 정말 미치도록 웃기네. 라이브 코미디 클럽에 너 출연해야 돼.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 오늘 머리 스타일을 완전히 바꾸셨네요?
# A: 네, 새로운 것을 시도해 보고 싶었어요.
# B: 어떤 생각으로 바꾸셨는지 알 수 있을까요?
# A: 특별한 이유는 없었어요. 그냥 제가 한 번도 해보지 않은 머리 스타일로 바꿔보고 싶었어요.
# B: 그렇군요. 그런데 잘 어울리나요?
# A: 아니요, 제가 생각했던 것보다 전혀 다르게 나왔어요. 정말 후회하고 있습니다.
#
# ### 발화:
# B: 아니요, 전혀 안 걱정하셔도 됩니다. 정말 사랑스럽게 변하셨네요.
#
# ### 답변:
# Sarcasm
# B가 자신의 머리 스타일을 바꿔서 후회하고 있다는 상황에서, 그 결과를 사랑스럽게 받아들이는 것처럼 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 아니요, 전혀 안 걱정하셔도 됩니다. 정말 사랑스럽게 변하셨네요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 집에 새로 들인 식물 어떻게 관리하고 있어?
# A: 아 잘 모르겠어, 이번에 들인 식물 벌레가 엄청나더라고.
# B: 벌레 나오면 문제가 큰데, 무슨 벌레 나왔어?
# A: 날개 달린 작은 검은색 벌레들이 나왔어.
#
# ### 발화:
# B: 오, 벌레들에게 좋은 집을 제공하니까 너도 동물보호 활동가 됐네.
#
# ### 답변:
# Sarcasm
# 벌레가 많이 나와서 식물을 제대로 키울 수 없는 상황을 식물에게 벌레를 주는 것처럼 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 오, 벌레들에게 좋은 집을 제공하니까 너도 동물보호 활동가 됐네.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 비가 많이 오네요.
# B: 네, 집에만 있기에는 딱 좋은 날씨입니다.
# A: 주말에는 무엇을 하시나요?
# B: 티브이를 보면서 커피 한잔하는 것이 제일 좋습니다.
#
# ### 발화:
# A: 아, 그렇게 활동적인 주말을 보내시는군요.
#
# ### 답변:
# Sarcasm
# 비가 오는 날씨를 비꼬아 물어보는 상황에서, 상대방이 커피 한잔하면서 티브이를 보는 것이 좋다고 말했을 때, 그것을 다른 사람들이 보기에는 즐겁지 않은 일로 표현한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 아, 그렇게 활동적인 주말을 보내시는군요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 작년에 비해 올해의 가을이 조금 빨리 찾아온 것 같습니다.
# B: 그렇습니다. 작년보다 더 빨리 추워지는 것 같아요.
# A: 네, 그래서 가을을 충분히 즐기지 못한 것 같아 아쉽습니다.
# B: 저도 그렇습니다. 가을이 짧아져서 좀 슬프네요.
#
# ### 발화:
# A: 짧아진 가을 덕분에 겨울옷을 더 일찍 입을 수 있게 되었네요.
#
# ### 답변:
# Sarcasm
# B의 말에 대해 실제로는 부정적인 상황인데, 이를 긍정적으로 해석하여 반대로 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 짧아진 가을 덕분에 겨울옷을 더 일찍 입을 수 있게 되었네요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 드라마 "때려"의 주연인데, 어떤 캐릭터를 연기하셨나요?
# B: 아, 나는 삶에 지친 청년으로, 맨날 때리고 다니는 캐릭터야.
# A: 그렇군요. 그럼 실제로 많이 때렸나요?
# B: 그래. 많이 때렸지. 특히 마지막 회에서는 정말 많이 때렸어.
#
# ### 발화:
# A: 그럼 아마 당신은 공인인증 때리기 선생님이시겠네요.
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 그럼 아마 당신은 공인인증 때리기 선생님이시겠네요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 안녕하세요, 새로운 동호회원으로 가입하게 되신 것을 환영합니다. 어떤 활동에 참여하실 계획이신가요?
# A: 안녕하세요. 저는 교육봉사를 하려고 가입하게 되었습니다.
# B: 아, 그렇군요. 저희 동호회에서는 많은 교육봉사 프로그램이 있습니다. 특히 저소득층 아이들을 위한 교육봉사가 있습니다.
# A: 아, 그런 프로그램이 있었군요. 저는 교육에 관심이 많아서 좋겠네요.
# B: 아주 좋습니다. 그럼 당신은 저소득층 아이들을 위한 교육봉사에 참여하시겠습니까?
# A: 아, 그런데 제가 가르치는 것에 자신이 없어서요. 공부를 더 해야 할 것 같아요.
#
# ### 발화:
# B: 그럼 아이들에게 공부의 중요성을 가르치는 데 큰 도움이 될 것 같아요.
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 그럼 아이들에게 공부의 중요성을 가르치는 데 큰 도움이 될 것 같아요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 저는 예전 사진을 다 지울 생각이에요.
# B: 왜 그래요? 기억을 간직하고 싶지 않아요?
# A: 아니 그런 게 아니라, 너무 많아서 관리가 안 돼요. 그래서 정리하려고요.
# B: 정리하는 게 그렇게 중요한가요? 그냥 놔두면 되지 않아요?
#
# ### 발화:
# A: 아, 그렇게 놔두면 엉망이 되어도 상관없겠네요.
#
# ### 답변:
# Sarcasm
# 정리를 하지 않아도 상관없다고 생각하는 B의 말에, 실제로는 관리를 해야 하지만, 이 상황을 망치게 두는 것이 좋다는 것처럼 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 아, 그렇게 놔두면 엉망이 되어도 상관없겠네요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 우리 어릴 때 재밌게 했던 게임들이 있었죠. 기억나세요?
# B: 아, 그러게요. 닌텐도 게임들이 많이 생각나네요.
# A: 저는 마리오와 마리오카트, 그리고 축구 게임이 제일 재밌었어요. 그런데 폰이 출시되면서부터 닌텐도 게임을 잘 안 하게 됐어요.
# B: 아, 저도 그렇게 됐어요. 폰 게임이 훨씬 간편하고 다양한 게 있으니까요.
#
# ### 발화:
# A: 그러게요, 터치스크린으로 누르는 것만큼 짜릿한 경험이 또 있을까요?
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 그러게요, 터치스크린으로 누르는 것만큼 짜릿한 경험이 또 있을까요?
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 최근에 그 게임에 새로운 업데이트가 있었다고 들었습니다. 참여율이 어떤가요?
# B: 예, 업데이트가 있었는데요. 사용자들의 참여율이 아주 높습니다.
# A: 아, 그렇군요. 업데이트 내용이 흥미롭나 보군요.
# B: 아니요, 사실 업데이트 내용은 그다지 매력적이지 않습니다. 그냥 모든 유저들에게 보상을 주어서 참여율이 높은 것 같습니다.
#
# ### 발화:
# A: 아하, 보상으로 유저들을 끌어들이는 거군요. 참 혁신적인 전략이네요.
#
# ### 답변:
# Sarcasm
# 사실상 업데이트의 내용이 아닌 보상 때문에 참여율이 높아진 것을 실제로는 좋은 결과가 아닌데, 이를 긍정적인 방향으로 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 아하, 보상으로 유저들을 끌어들이는 거군요. 참 혁신적인 전략이네요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 오늘 점심에 무엇을 드실 계획이세요?
# B: 아직 정하지 않았습니다. 학식을 먹을까 돈가스를 먹을까 고민 중입니다.
# A: 학식은 어떤 메뉴가 있나요?
# B: 오늘 학식 메뉴는 비빔밥이에요. 근데 비빔밥은 집에서도 잘 만들어 먹는 거라...
#
# ### 발화:
# A: 아하, 그럼 우리는 곧 B 씨의 비빔밥 레시피를 볼 수 있겠군요!
#
# ### 답변:
# Sarcasm
# 학식 메뉴인 비빔밥을 집에서도 잘 만든다고 한 B의 말에 대해, 실제로는 자신의 요리 실력이 그리 좋지 않을 것 같지만 이를 긍정적으로 해석하고 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 아하, 그럼 우리는 곧 B 씨의 비빔밥 레시피를 볼 수 있겠군요!
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 오늘 저녁에 무엇을 드셨나요?
# A: 저는 오늘 저녁에 만둣국을 먹었습니다. 아주 맛있었습니다.
# B: 그럼 다음에 무엇을 드실 계획이신가요?
# A: 다음에는 치킨을 주문해서 먹을 계획입니다.
#
# ### 발화:
# B: 그럼 식사는 이미 하셨으니 치킨은 디저트로 취급하시는 건가요?
#
# ### 답변:
# Sarcasm
# 이미 저녁에 만둣국을 먹었음에도 불구하고, 추가로 치킨을 먹겠다는 B의 발언에 A가 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 그럼 식사는 이미 하셨으니 치킨은 디저트로 취급하시는 건가요?
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 감기에 걸리지 않으려면 어떻게 해야 하나요?
# B: 감기 예방을 위해 건강에 신경을 쓰는 것이 중요합니다. 매일 비타민을 섭취하고 충분한 수면을 취하는 것이 좋아요.
# A: 그렇군요. 또한, 저는 한의원에 가서 독감 주사도 맞을 예정입니다.
#
# ### 발화:
# B: 독감 주사, 좋은 생각이네요. 그런데 한의원에서 독감 주사를 맞는다고요?
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 독감 주사, 좋은 생각이네요. 그런데 한의원에서 독감 주사를 맞는다고요?
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 여행 계획을 세우는 스타일이 어떠신가요?
# A: 저는 주로 패키지여행을 선호합니다.
# B: 그렇군요, 특별한 이유가 있으신가요?
# A: 네, 저는 일정을 직접 계획하는 것이 번거롭고 패키지여행이면 모든 것이 정리되어 있어 편하다고 생각합니다.
#
# ### 발화:
# B: 아, 정말로 모든 것이 결정된 여행이 최고의 자유로움이겠군요.
#
# ### 답변:
# Sarcasm
# 패키지여행이 모든 것이 정리되어 있어 편하다는 B의 말에, 실제로 패키지여행은 자유를 제한할 수 있음에도 불구하고 그것을 모두 통제된 것으로 보아 편하다고 말하는 것을 부정적인 방향으로 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 아, 정말로 모든 것이 결정된 여행이 최고의 자유로움이겠군요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 엄마, 요즘 뭐 하시는데?
# B: 아무것도 안 해. 사실 여행 가고 싶은데, 방법이 없어서 고민 중이야.
# A: 여행? 그럼 엄마 친구들이랑 같이 가시면 되잖아요.
# B: 아니, 그게 문제야. 친구들 다 바빠서 시간이 안 맞아.
#
# ### 발화:
# A: 그럼 혼자 세계여행이나 다녀오세요.
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 그럼 혼자 세계여행이나 다녀오세요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 안녕하세요, 최근에 어떤 게임을 주로 하시나요?
# B: 피파온라인 4를 주로 합니다. 아주 재미있어요.
# A: 그렇군요, 저는 모바일 게임을 좋아합니다. 편하게 언제 어디서나 할 수 있어서 좋아요.
#
# ### 발화:
# B: 피파온라인 4도 모바일 버전이 있습니다. 하지만, 개인적으로 PC 버전이 더 재미있다고 생각해요.
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 피파온라인 4도 모바일 버전이 있습니다. 하지만, 개인적으로 PC 버전이 더 재미있다고 생각해요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 오늘 날씨 정말 쌀쌀하네요.
# B: 그러게요. 비도 오고 있어서 더 춥게 느껴지는 것 같아요.
# A: 아, 그렇군요. 이런 날은 집에서 따뜻한 커피 한잔하면서 책이나 읽는 게 최고인 것 같아요.
# B: 저는 추운 날은 밖에 나가서 눈을 즐기는 것이 좋아요.
#
# ### 발화:
# A: 오, 정말 대단하시네요. 추운 날씨를 정말 즐기시는군요.
#
# ### 답변:
# Sarcasm
# A는 추운 날에는 집에서 따뜻하게 시간을 보내는 것을 좋아하는 반면, B는 추운 날에도 밖에 나가서 눈을 즐기는 것을 좋아한다고 했다. 이에 대해 A가 B의 취향을 이해하지 못하면서도 그것을 긍정적으로 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 오, 정말 대단하시네요. 추운 날씨를 정말 즐기시는군요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 이혼하고 나서 기분은 어때?
# A: 그냥 그래. 난 정말 사랑을 믿고 싶어.
# B: 다시 사랑하고 싶다는 거야?
# A: 응, 난 결혼이 좋아. 이혼하고 나서도 다시 결혼하고 싶어.
#
# ### 발화:
# B: 어쩌면 너는 결혼의 마스터일지도 몰라.
#
# ### 답변:
# Sarcasm
# 결혼에 대한 부정적인 경험이 있음에도 불구하고 여전히 결혼을 원하는 B의 말에, 그것을 긍정적인 방향으로 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 어쩌면 너는 결혼의 마스터일지도 몰라.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 에어팟 갖고 싶다며? 왜 안 사?
# A: 그럼 사고 싶지만 너무 작아서 떨어뜨릴까 봐 무서워.
# B: 그럼 그냥 안 사는 게 나을 거 같아?
# A: 그래도 너무 갖고 싶은데...
#
# ### 발화:
# B: 이런, 꿈을 포기하는 것도 대단하네.
#
# ### 답변:
# Sarcasm
# 에어팟을 사고 싶지만 떨어뜨릴까 봐 사지 않겠다는 상대방의 이야기를 듣고, 무언가를 놓치는 것이 두려워하지 않도록 격려하는 말을 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 이런, 꿈을 포기하는 것도 대단하네.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 요즘 문화생활하시나요?
# B: 코로나 때문에 뮤지컬이나 공연장을 못 가는 것도 그렇고 아이들도 작아서 챙겨야 해서 그런 곳을 자주 못 가게 되더라고요.
# A: 그래요? 아이들과 같이 갈 수 있는 문화행사나 미술관 같은 곳은 어떠세요?
# B: 아이들도 챙기고 또 코로나도 신경 써야 해서 거의 못 가고 있어요.
#
# ### 발화:
# A: 아, 집에서 가족들과 보내는 시간이란 게 정말로 값진 것 같아요.
#
# ### 답변:
# Sarcasm
# 상대방이 문화생활을 즐기지 못하는 이유로 코로나와 아이들을 언급했다. 하지만 사실상 이런 상황은 매우 어렵고 곤란한 상황인데, 그것을 긍정적인 방향으로 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 아, 집에서 가족들과 보내는 시간이란 게 정말로 값진 것 같아요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: '모가디슈'라는 영화를 아시나요?
# B: 네, 최근에 개봉한 걸로 알고 있습니다.
# A: 맞습니다. 좋은 평가를 받고 있는데 관람하려고 계획 중이십니까?
# B: 아니요, 저는 사실 영화보다는 집에서 책을 읽는 것을 더 좋아합니다.
#
# ### 발화:
# A: 그럼 아마 책에 빠져서 밤새 잠도 못 이루실 거예요.
#
# ### 답변:
# Sarcasm
# 영화를 보기보다 집에서 책 읽기를 더 좋아한다고 말한 B에게 실제로는 독서를 별로 안 할 것 같은 상황을 책에 빠져서 잠 못 이루는 것처럼 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 그럼 아마 책에 빠져서 밤새 잠도 못 이루실 거예요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 오늘 날씨가 정말 좋네요.
# B: 좋다고 말씀하시는 이유가 있으신가요? 저는 비 오는 날이 참 싫어요.
# A: 아, 그렇군요. 왜 그런지 알 수 있을까요?
# B: 우산을 들고 다니기 불편하고, 옷도 젖어서 참 불편해요.
#
# ### 발화:
# A: 그렇군요. 아무래도 우산을 들고 다니면서 옷이 젖는 건 신선한 경험일 수 있겠네요.
#
# ### 답변:
# Sarcasm
# 실제로는 비 오는 날이 불편하다는 상대방의 말에 대해, 비 오는 날을 좋아하는 것처럼 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 그렇군요. 아무래도 우산을 들고 다니면서 옷이 젖는 건 신선한 경험일 수 있겠네요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: name1님의 반려견은 어떤 품종이세요?
# B: 제 반려견은 시베리안 허스키입니다.
# A: 아, 허스키라면 교육 훈련이 필요하겠군요. name3님이 어떤 훈련을 받고 있나요?
# B: 그래서 집안을 쓸고 닦는 훈련을 시키고 있어요.
#
# ### 발화:
# A: 와, 정말이면 청소기 회사가 문을 닫겠군요.
#
# ### 답변:
# Sarcasm
# 허스키라는 대형 견종을 집안을 청소하는 일에 훈련시킨다는 것은 사실상 불가능하다. 그래서 그 말을 긍정적으로 해석하여 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 와, 정말이면 청소기 회사가 문을 닫겠군요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 요즘 무슨 일 있어? 좀 피곤해 보이는데.
# A: 아냐, 그냥... 남자친구랑 좀 싸웠어.
# B: 왜? 무슨 일이야?
# A: 그가 자꾸 여사친이랑만 놀러 다녀.
#
# ### 발화:
# B: 그럼 너도 남사친들이랑 놀러 다니면 되잖아.
#
# ### 답변:
# Sarcasm
# 남자친구가 여사친과 자주 놀러 다니는 것을 친구가 알고 있음에도 불구하고 그런 행동이 괜찮은 것처럼 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 그럼 너도 남사친들이랑 놀러 다니면 되잖아.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 이탈리아 사람들은 뭐 먹고 사니?
# A: 피자, 파스타, 젤라또 같은 거 많이 먹지 않을까?
# B: 그래서 이탈리아 사람들이 평균적으로 다른 국가 사람들보다 뚱뚱하다고 들었어.
# A: 아니, 그건 잘못된 생각이야. 오히려 이탈리아 사람들은 식습관 때문에 건강하고 길게 산다고 해.
#
# ### 발화:
# B: 그래서 그들은 모든 피자와 파스타를 먹고도 아직 살아있는 거야?
#
# ### 답변:
# Sarcasm
# 이탈리아 사람들이 평균적으로 건강하고 길게 산다는 B의 말에 비꼬아, 음식 때문에 비만이 되어 간단히 살 수 없다는 것을 암시한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 그래서 그들은 모든 피자와 파스타를 먹고도 아직 살아있는 거야?
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 찜닭 어때? 맛있지?
# A: 음... 좋아. 근데 좀 매워.
# B: 그래? 그럼 내가 담에는 맵기 조절할게.
# A: 아냐, 그게 아니라 처음부터 찜닭이 안 맞는 것 같아.
#
# ### 발화:
# B: 오, 너의 입맛도 고대 사람처럼 원시적이네.
#
# ### 답변:
# Sarcasm
# B가 찜닭이 안 맞는다는 표현에 대해 실제로는 부정적인 상황이지만, 이를 긍정적인 상황으로 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 오, 너의 입맛도 고대 사람처럼 원시적이네.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 집안일이 너무 많아서 힘들지 않으세요?
# B: 그렇긴 하죠. 저도 도와드리고 싶은데, 시간이 많지 않아서요.
# A: 제가 건조기와 식기세척기를 사서 집안일을 줄였어요.
#
# ### 발화:
# B: 아 그렇군요? 그런데 저희 집은 건조기와 식기세척기를 사용해도 실제로 집안일이 줄진 않더라고요.
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 아 그렇군요? 그런데 저희 집은 건조기와 식기세척기를 사용해도 실제로 집안일이 줄진 않더라고요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 비누 종류에 따라 사용 용도가 다르다고 들었는데요, 그게 어떻게 다른 건가요?
# A: 그렇습니다. 페이셜 비누는 얼굴을 깨끗하게 해주고, 보디 비누는 몸 전체를 깨끗하게 해줍니다. 또, 일부 비누는 특정 향으로 만들어져서 공기 청정이나 몸의 향을 좋게 하는 데에 사용됩니다.
# B: 그럼 향이 좋은 비누를 사용하면 공기도 좋아지고 몸의 향도 좋아진다는 건가요?
# A: 이론적으로는 그렇습니다. 하지만 실제로는 모든 사람이 그 향을 좋아하는 것은 아니기 때문에 상황에 따라 다릅니다.
#
# ### 발화:
# B: 아, 그래서 그 향이 너무 강해서 코를 찡그려야 하는 거군요.
#
# ### 답변:
# Sarcasm
# A는 B의 마지막 발언에 대해 모든 사람이 그 향을 좋아할 것 같은 것처럼 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 아, 그래서 그 향이 너무 강해서 코를 찡그려야 하는 거군요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 피자스쿨 기억나? 와플 대학도 그렇고.
# A: 아, 그런 게 있었지. 요즘은 어디 없더라.
# B: 아니 왜 없어졌지? 맛있었는데.
#
# ### 발화:
# A: 피자스쿨이랑 와플 대학이 없어진 게 아쉽다고??
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 피자스쿨이랑 와플 대학이 없어진 게 아쉽다고??
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 저는 순두부찌개와 부대찌개를 만들 때 사용하는 다담 소스를 좋아하는데, 맛있는 곳을 아시나요?
# A: 아, 저도 그 소스를 참 좋아하는데요. 최근에 알게 된 집이 있어요. 그곳의 다담 소스가 정말 맛있습니다.
# B: 그럼 저도 한번 방문해 봐야겠네요. 혹시 주소를 알 수 있을까요?
# A: 네, 서울특별시 강남구 청담동에 위치해있습니다.
#
# ### 발화:
# B: 아, 그렇군요. 바로 옆집이네요.
#
# ### 답변:
# Sarcasm
# 상대방이 서울의 멀리 떨어진 곳을 추천해 줬는데, 실제로는 매우 불편한 상황인데 이를 너무나도 편리한 것처럼 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 아, 그렇군요. 바로 옆집이네요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 저는 최근에 바닐라코 클렌징 밤을 구매했습니다.
# A: 아, 그 제품이 많이 유명하던데요. 어떤가요? 만족하셨나요?
# B: 네, 확실히 피부가 깨끗해지는 느낌이 듭니다.
# A: 그럼 저도 한 번 구입해 봐야겠네요. 그리고 요즘에 액정 태블릿도 구매하려고 하는데 추천해 주실 수 있나요?
# B: 아, 저는 아이패드를 사용하고 있습니다. 디자인도 이쁘고, 성능도 좋아서 만족하고 있습니다.
# A: 아이패드요? 그런데 가격이 좀 비싸지 않나요?
#
# ### 발화:
# B: 비싸지만 아이패드만의 매력에 푹 빠지면 가격은 그저 숫자일 뿐입니다.
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 비싸지만 아이패드만의 매력에 푹 빠지면 가격은 그저 숫자일 뿐입니다.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 오늘 커피 어때? 내가 직접 갈았어.
# B: 음... 나쁘지 않아. 근데 카페에서 마시는 커피가 더 맛있는 것 같아.
#
# ### 발화:
# A: 그럼 이제부터 매일 카페에 가야겠네.
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 그럼 이제부터 매일 카페에 가야겠네.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 오늘 수업 가는 길에 뭐 먹을 거야?
# B: 아침에 시리얼 사둔 거 있잖아. 그거 우유에 타먹을 생각이야.
# A: 우유도 사야 되지 않아?
# B: 그래서 가는 길에 우유랑 치즈, 달걀까지 같이 사려고.
#
# ### 발화:
# A: 그러니까 손 한번 흔들면 다 해결되는 거지?
#
# ### 답변:
# Sarcasm
# 사려고 했던 우유, 치즈, 달걀까지 함께 사는 것이 매우 번거로울 것 같은 상황을 너무나도 간단하게 처리하는 것처럼 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 그러니까 손 한번 흔들면 다 해결되는 거지?
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 이번에 겨울 왕국 2가 개봉하던데요, 기대하시나요?
# A: 그렇습니다. 저는 애니메이션 영화를 아주 좋아하거든요.
# B: 저도 그런데요. 특히 이번 겨울 왕국 2는 이전 작품에 비해 더욱 뛰어난 애니메이션과 스토리를 기대하고 있습니다.
#
# ### 발화:
# A: 저는 사실 겨울 왕국의 첫 번째 영화가 그리 인상적이지 않아서, 이번에는 기대치가 그렇게 높지 않습니다.
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 저는 사실 겨울 왕국의 첫 번째 영화가 그리 인상적이지 않아서, 이번에는 기대치가 그렇게 높지 않습니다.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 롯데몰 가 본 적 있어?
# A: 네, 한 번 가 봤습니다.
# B: 맛있는 음식점도 많고 재밌는 곳인데. 거기 주변에 매물이 있는 걸 알아?
# A: 그럼요, 근데 그 매물이 워낙 비싸서..
#
# ### 발화:
# B: 그래, 당연히 그럴 거야. 거기가 공항이랑 롯데몰이 있는 곳인데 뭐.
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 그래, 당연히 그럴 거야. 거기가 공항이랑 롯데몰이 있는 곳인데 뭐.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 안녕하세요, 저는 여행사 직원인데 어떤 도움을 드릴까요?
# B: 응. 나 해외여행 가고 싶은데 추천 좀 해줘.
# A: 그럼 이번에는 태국의 방콕은 어떠세요? 시장과 사원을 돌아보면서 볼거리가 많아요.
# B: 그래? 그럼 거기로 예약해.
# A: 네, 예약을 위해 필요한 정보를 알려주시겠어요?
# B: 아니, 그런 거 없이 그냥 예약해 줘.
#
# ### 발화:
# A: 네, 그럼 아무 정보 없이도 예약을 완료해 드리겠습니다.
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 네, 그럼 아무 정보 없이도 예약을 완료해 드리겠습니다.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 여행 가기 전에 쇼핑을 하셨나요?
# B: 네, 사고 싶은 옷과 화장품이 많아서 많이 샀어요.
# A: 그런데 여행 가는 동안 그것들을 다 가지고 다니기 어렵지 않으세요?
#
# ### 발화:
# B: 그렇긴 하지만, 제가 필요한 것들이니까요.
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 그렇긴 하지만, 제가 필요한 것들이니까요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 너 그 작업 어떻게 됐어?
# A: 아.. 제가 수요일에 보내야 했는데 지금 목요일 끝나가서 아직도 안 끝났어요.
# B: 그러면 이제 그거 때문에 팀원들 다 힘들게 될 거야.
# A: 네.. 제 탓이에요. 다음엔 이런 실수 안 할게요.
#
# ### 발화:
# B: 어허, 우리 팀원들은 스트레스 받을 일이 별로 없잖아. 이제 좀 받아보게.
#
# ### 답변:
# Sarcasm
# A가 B의 지연된 작업으로 인해 다른 팀원들이 힘들어질 것이라는 말에 대해 실제로는 부정적인 상황인데, 이를 긍정적인 방향으로 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 어허, 우리 팀원들은 스트레스 받을 일이 별로 없잖아. 이제 좀 받아보게.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 엘리베이터에 탑승할 때 어디에 서시나요?
# A: 그런 것까지는 별로 신경 안 쓰셨군요. 저는 그냥 빈자리에 서요.
# B: 그렇군요. 제가 최근에 읽은 글에 따르면, 엘리베이터에서 서는 위치가 사람의 성격을 반영한다고 합니다.
# A: 아, 그런 게 가능한 건가요? 엘리베이터 안에서 서는 위치로 성격을 알 수 있다니... 저는 그게 좀 어렵네요.
#
# ### 발화:
# B: 그래요? 저는 엘리베이터 안에서 서는 위치로 모든 것을 알 수 있다고 생각해요.
#
# ### 답변:
# Sarcasm
# 엘리베이터 안에서의 위치로 사람의 성격을 알 수 있다는 것을 믿지 않는 B에게, 그것을 매우 정확하고 믿을만한 것처럼 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 그래요? 저는 엘리베이터 안에서 서는 위치로 모든 것을 알 수 있다고 생각해요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 내일 뭐 하냐?
# B: 친구들이랑 영화 보러 가기로 했어.
# A: 영화는 뭐 보려고?
# B: '아이언맨' 보려고 했는데, 표가 다 매진이라더라. 그래서 '스파이더맨'으로 바꿔서 예매했어.
# A: '스파이더맨' 표값은 얼마인데?
# B: 아 그건 모르겠다. 카드로 결제했거든.
#
# ### 발화:
# A: 아니, 그래서 돈이 없어도 너는 항상 영화를 볼 수 있겠구나.
#
# ### 답변:
# Sarcasm
# B가 알아보지도 않고 결제한 것을 긍정적으로 무시 심리를 통해 부정적인 상황을 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 아니, 그래서 돈이 없어도 너는 항상 영화를 볼 수 있겠구나.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 최근에 무슨 드라마나 영화를 보셨나요?
# B: 그 저번에 소설로 유명했던 것을 드라마로 만들었다고 해서 봤는데, 기대에 못 미쳤어요.
# A: 원작이랑 비교하면 어땠나요?
# B: 아무래도 원작의 세세한 부분들이 많이 생략돼서 그런지 살짝 실망스러웠어요.
#
# ### 발화:
# A: 그래도 원작보다 드라마가 더 상상력을 자극하게 하니 좋은 경험이었겠군요.
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 그래도 원작보다 드라마가 더 상상력을 자극하게 하니 좋은 경험이었겠군요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 요리하는 건 어떻게 되셨나요?
# B: 아, 좀 어렵습니다. 특히까지 김치볶음밥이랑 계란말이 만들기가.
# A: 아하, 어떤 부분이 어려우신가요?
# B: 김치볶음밥은 너무 매워지고, 계란말이는 너무 퍼져서 제대로 안 돼요.
#
# ### 발화:
# A: 그래도 매운 음식 좋아하는 사람들에게는 김치볶음밥 딱이겠네요, 그리고 계란말이는 부드러운 스크램블드에그로 먹으면 좋겠네요.
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 그래도 매운 음식 좋아하는 사람들에게는 김치볶음밥 딱이겠네요, 그리고 계란말이는 부드러운 스크램블드에그로 먹으면 좋겠네요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 어, 너 지금 뭘 하는데?
# A: 아니, 뭐랄까.. 파일을 날려먹어서 고생 중이야.
# B: 아이고 그게 뭐야. 복구는 되나?
# A: 음, 그래서 스캔 앱으로 복구 시도 중인데, 아직 잘 안되고 있어.
#
# ### 발화:
# B: 그럼 스캔 앱이 좋은 삭제 도구가 됐네.
#
# ### 답변:
# Sarcasm
# 파일 복구가 잘 안되는 상황에 대해 스캔 앱이 마치 파일을 없애주는 도구처럼 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 그럼 스캔 앱이 좋은 삭제 도구가 됐네.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 안녕하세요, 이번 주에 2차 백신 접종 잘 받으셨나요?
# A: 네, 잘 받았습니다. 하지만 조금 힘들게 느껴지네요.
# B: 아, 그럼 지금 건강 상태가 좋지 않으신가요?
# A: 네, 몸이 좀 무거워지는 느낌이 있습니다. 이 상태로 내일 신랑과 백신 접종 예약을 맞춰야 할지 고민이에요.
#
# ### 발화:
# B: 아무래도 당신의 건강보다는 신랑과 함께 백신을 맞는 게 중요하겠죠?
#
# ### 답변:
# Sarcasm
# B의 건강 상태가 좋지 않음에도 불구하고 신랑과 함께 백신을 맞을 생각을 하는 것에 대해 의문을 가진 A가 자신의 걱정을 비꼬아 표현한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 아무래도 당신의 건강보다는 신랑과 함께 백신을 맞는 게 중요하겠죠?
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 원두를 어떤 것을 선호하십니까?
# A: 저는 로스트가 진한 것을 좋아합니다.
# B: 그러면, 블랙커피를 주로 드시나요?
# A: 아니요, 저는 달달한 커피 음료를 선호합니다.
#
# ### 발화:
# B: 그럼 로스트가 진한 원두로 만든 달달한 커피가 참 특별하겠네요.
#
# ### 답변:
# Sarcasm
# 원두의 로스트가 진한 것을 선호한다고 말했지만, 달달한 커피 음료를 선호한다는 B의 말에 실제로는 논리적으로 맞지 않는 상황인데, 이 상황을 긍정적인 방향으로 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 그럼 로스트가 진한 원두로 만든 달달한 커피가 참 특별하겠네요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 요즘 무슨 노래 들어?
# A: 아, 나 요즘 백예린 노래에 푹 빠져있어. 너무 좋아.
# B: 오, 나도 백예린 노래 좋아해. 뭐 듣고 있는데?
# A: '우리는 사랑이 아닌 관계'라는 곡이야. 너무 슬프고 좋아.
#
# ### 발화:
# B: 와, 너무 행복해 보이는걸?
#
# ### 답변:
# Sarcasm
# B가 '우리는 사랑이 아닌 관계'라는 곡이 너무 슬프다고 말한 것에 대해, 실제로는 슬픔을 느끼지 않고 오히려 행복한 감정을 표현하는 방식으로 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 와, 너무 행복해 보이는걸?
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 오늘 점심 메뉴로 어떤 것을 선택하셨나요?
# B: 저는 김치전, 치즈 빈대떡, 부추전을 먹었습니다. 그리고 볶음밥도요.
# A: 그렇군요, 푸짐하게 드셨네요. 저는 카페에서 샐러드와 카레를 먹었습니다.
# B: 오! 카레는 좋아하는데 샐러드는 그다지...
#
# ### 발화:
# A: 아, 그렇군요. 당신이 샐러드를 좋아하지 않다니, 정말 놀랍네요.
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 아, 그렇군요. 당신이 샐러드를 좋아하지 않다니, 정말 놀랍네요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 아 배고프다.
# A: 간식은 얼마나 먹었는데요?
# B: 오늘만 감자칩 두 봉지랑 콜라 한 통 마셨어.
# A: 그렇게 많이 먹고도 아직도 배고프세요?
#
# ### 발화:
# B: 아니, 간식 먹은 게 사실상 식사였는데, 그런 게 어디 있어.
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 아니, 간식 먹은 게 사실상 식사였는데, 그런 게 어디 있어.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 최근에 아침식사로 무엇을 드시고 계시나요?
# A: 겨울에는 귀리와 온수, 우유를 섞어서 먹는 편입니다.
# B: 그렇군요. 그런 식으로 귀리를 섭취하면 어떤 효과가 있나요?
#
# ### 발화:
# A: 잘 모르겠습니다. 그냥 맛있어서 먹는 것이지요.
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 잘 모르겠습니다. 그냥 맛있어서 먹는 것이지요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 요즘 뭐 하는 중이야?
# B: 음, 그냥 녹음 알바를 하고 있어.
# A: 녹음 알바? 그게 뭐야?
# B: 아, 그냥 문장 읽는 거야. 그걸 녹음해서 제출하는 거.
# A: 어때? 재미있어?
# B: 솔직히 말하면 좀 지루해. 같은 문장을 계속 반복해서 읽으니까.
#
# ### 발화:
# A: 우와, 너 정말 힘들겠다. 같은 문장을 계속 읽는다니, 너무 힘든 일이야.
#
# ### 답변:
# Sarcasm
# 반복적인 작업이 지루하다고 표현한 상대의 말에 대해 이 작업이 쉬운 것처럼 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 우와, 너 정말 힘들겠다. 같은 문장을 계속 읽는다니, 너무 힘든 일이야.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 김치를 좋아하시나요?
# B: 네, 저는 김치를 매우 좋아합니다. 특히 배추김치가 제일 좋아요.
# A: 그럼 여러 종류의 김치를 만드는 법을 아시나요?
# B: 아니요, 저는 그저 먹기만 좋아하죠.
#
# ### 발화:
# A: 오, 당신은 진정한 김치 전문가 시네요!
#
# ### 답변:
# Sarcasm
# 김치를 만드는 법을 모르는 상대방의 말에 비꼬아 '김치 전문가'로 칭하는 것이다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 오, 당신은 진정한 김치 전문가 시네요!
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 오늘 병원 일은 어땠어?
# A: 병원 일이랄 것도 없었어. 그냥 바이탈 측정하고 있는 환자들 돌아보는 것 밖에.
# B: 바이탈 측정이라니? 그거 중요하지 않아?
# A: 너무 간단해서 뭐.. 별로 어렵지도 않아.
#
# ### 발화:
# B: 아, 너는 진짜 의사라서 그런가 봐. 너무 쉽게 생각하니까.
#
# ### 답변:
# Sarcasm
# 바이탈 측정은 환자의 건강 상태를 파악하는 중요한 작업인데, B가 그것을 간단하고 별로 어렵지 않다고 말하는 것에 대해 반말로 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 아, 너는 진짜 의사라서 그런가 봐. 너무 쉽게 생각하니까.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 저는 BTS를 정말 좋아합니다. 당신은 어떤 아이돌 그룹을 좋아하십니까?
# A: 저도 ATS를 매우 좋아합니다. 특히 저는 뷔 멤버를 정말 좋아합니다.
# B: 그렇군요. 저는 진 멤버가 제일 좋습니다. 춤 실력이 정말 대단하니까요.
# A: 그러나 저는 아이돌 그룹의 춤 실력이 어느 정도 중요하다고 생각하지 않습니다.
#
# ### 발화:
# B: 네, 춤은 전혀 중요하지 않죠. 아이돌이란 건 그냥 서있기만 해도 되니까요.
#
# ### 답변:
# Sarcasm
# 아이돌 그룹의 춤 실력을 중요하게 생각하지 않는 B의 마지막 발언에 대해, 실제로는 춤 실력이 아주 중요한데 이를 무시하는 것을 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 네, 춤은 전혀 중요하지 않죠. 아이돌이란 건 그냥 서있기만 해도 되니까요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 안녕하세요, 저녁 식사는 어떻게 준비하셨나요?
# A: 아, 오늘은 프레시리 밀키트로 파스타를 만들어 봤습니다.
# B: 그렇군요. 그 밀키트가 요리하는데 많은 도움이 되나요?
# A: 그럼요, 특히 요리 초보인 저 같은 사람들에게는 더욱 유용하죠. 다만 오늘은 양념을 너무 많이 넣어버려서 조금 짜게 나왔네요.
#
# ### 발화:
# B: 아하, 그럼 정말 입맛 돋우는 파스타가 되셨겠군요.
#
# ### 답변:
# Sarcasm
# 파스타가 너무 짜서 맛이 없을 것 같다는 상황을, 반대로 짜서 감칠맛이 날 것 같다고 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 아하, 그럼 정말 입맛 돋우는 파스타가 되셨겠군요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 여기저기서 작품을 내신다고 들었습니다. 어떤 이야기인가요?
# B: 네, 세라 이야기라는 책을 썼습니다. 이제 곧 출간될 예정입니다.
# A: 오, 그런데 세라 이야기는 어떤 내용인가요?
# B: 대충만 말씀드리면, 인간의 본질에 대해 깊게 탐구하는 내용입니다.
# A: 그렇군요. 출간되면 읽어볼게요.
#
# ### 발화:
# B: 아, 그럼 저희 출판사에 큰 기대감을 가져다주셔서 감사합니다.
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 아, 그럼 저희 출판사에 큰 기대감을 가져다주셔서 감사합니다.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 요즘 유튜브에서 무슨 채널을 주로 보시나요?
# B: 연예인 직캠, 타짜 유튜브, 그리고 반려동물 관련 채널을 주로 보는 편이에요.
# A: 그렇군요. 특히 가장 좋아하는 채널이 있나요?
# B: 아무래도 타짜 유튜브를 제일 좋아하는 것 같아요.
#
# ### 발화:
# A: 와, 정말 도박에 빠져서 실제로 도박을 하시는 것도 아닌데 놀라울 뿐입니다.
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 와, 정말 도박에 빠져서 실제로 도박을 하시는 것도 아닌데 놀라울 뿐입니다.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 오늘 게임 어땠어?
# B: 아, 오늘은 좀 어려웠어. 그래도 재미있었어.
# A: 어떤 부분이 어려웠어?
# B: name3이라는 유저랑 플레이하다가 죽어서 너무 힘들었어.
# A: 그래도 name3이 열심히 플레이하면서 재미있게 하고 있었지?
# B: 응, 그래. 그런데 지금 돈가스 먹고 있어서 좀 힘들다.
#
# ### 발화:
# A: 와, 돈가스 먹으면서 게임하는 거, 진짜 대단하다.
#
# ### 답변:
# Sarcasm
# 게임에서 죽은 것과 돈가스를 먹는 것 사이에 연관성이 없지만 마치 돈가스를 먹으면서 게임을 하는 것처럼 말하여 상황을 비꼬는다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 와, 돈가스 먹으면서 게임하는 거, 진짜 대단하다.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 지방직 공무원 시험 준비는 얼마나 걸렸어요?
# A: 그거야... 아마 9개월 정도 걸렸던 것 같아요.
# B: 와, 그렇게 빠르게 합격하다니 머리가 좋으셨나 봐요. 어떤 학과를 나오셨어요?
# A: 그런 건 별로 중요하지 않아요. 젊었을 때 머리가 좋았다는 것이 중요하죠.
#
# ### 발화:
# B: 아하, 그래서 공무원 시험이 그렇게 쉬웠겠네요.
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 아하, 그래서 공무원 시험이 그렇게 쉬웠겠네요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 라면 먹을래?
# B: 네, 그런데 계란을 넣고 싶은데 괜찮을까요?
# A: 근데 라면 국물을 바꾸지 않고 그대로 계란을 넣어도 되는 거야?
# B: 그렇게 해도 맛있던데요. 한번 해보세요.
#
# ### 발화:
# A: 원래 국물 맛이 별로라서 계란 넣어야 되겠다.
#
# ### 답변:
# Sarcasm
# 상대방이 계란을 국물에 그대로 넣어 먹는다고 했는데, 이를 국물이 맛이 없어서 그런 것처럼 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 원래 국물 맛이 별로라서 계란 넣어야 되겠다.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 요즘 떡볶이를 참 좋아하시는 것 같습니다. 어떤 떡볶이가 가장 맛있으셨나요?
# A: 저는 대체적으로 떡볶이는 어디서 먹어도 맛있는데요. 그런데 이번에 가보니까 태리로 제가 꽤 맛있더라고요.
# B: 아, 저도 들어본 적 있어요. 그런데 저는 응급실 떡볶이가 더 맛있더라고요. 고추장 베이스가 아니라 간장 베이스여서 그런지 맛이 깊더라고요.
#
# ### 발화:
# A: 간장 베이스의 떡볶이 라면 제 취향은 아닌 것 같아요. 제가 좋아하는 떡볶이는 바로 진한 고추장 맛의 떡볶이거든요.
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 간장 베이스의 떡볶이 라면 제 취향은 아닌 것 같아요. 제가 좋아하는 떡볶이는 바로 진한 고추장 맛의 떡볶이거든요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 최근에 코로나 백신을 맞으셨나요?
# ...
#
# ### 답변:
# Sarcasm
# B가 A에게 왜 긴 문장으로 말하느냐고 했을 때, 이를 반대로 의미하는 말로 대답한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 아, 나는 너처럼 간결하게 말하지 못해서 그런 거야.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 요즘 뭐 좋아하시나요? 취향이 궁금하네요.
# B: 그럼 말해줄까? 나, 사실 민초 파야.
# A: 아, 그래요? 어떤 부분이 좋으신가요?
# B: 그냥, 그 맛이야. 달달하고 상큼하니까.
#
# ### 발화:
# A: 오, 진짜? 나도 그 상큼함에 중독되겠군요.
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 오, 진짜? 나도 그 상큼함에 중독되겠군요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 저는 아침에 일어나면 커피 한 잔이 꼭 필요해요.
# A: 저도 그래요. 저는 원두를 사서 직접 내려마셔요.
# B: 원두를 직접 갈아서요?
# A: 네, 그런데 그게 귀찮아서 커피 메이커를 사려고 생각 중이에요.
# B: 커피 메이커가 있으면 편하긴 하겠어요.
# A: 네, 그런데 좋은 제품을 보니까 가격이 좀 비싸더라고요.
#
# ### 발화:
# B: 그럼 바로 사야겠네요. 돈은 쓰라고 있는 거니까요.
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 그럼 바로 사야겠네요. 돈은 쓰라고 있는 거니까요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 당신의 헤어 컬러는 정말 눈에 띄네요. 딥블루인가요?
# B: 네, 맞습니다. 제가 이번에 새롭게 시도해 본 색인데요, 생각보다 만족스럽습니다.
# A: 유지 기간이 얼마나 되나요?
# B: 그런 부분은 상당히 차이가 나는 것 같아요. 저는 보통 한 달 정도 유지가 되더라고요.
# A: 다음에 어떤 색을 시도해 보려고 생각하고 계시나요?
# B: 그건 아직 확실히 결정하지 않았습니다. 하지만 다양한 색을 시도해 보는 것이 좋을 것 같아요.
#
# ### 발화:
# A: 그럼 당신은 무지개를 헤어 컬러로 선택할 수 있겠네요.
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 그럼 당신은 무지개를 헤어 컬러로 선택할 수 있겠네요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 최근에 어떤 취미를 가지고 계시나요?
# A: 저는 온라인 게임에 매우 흥미를 느껴서 많이 하는 편입니다.
# B: 오, 그렇군요. 어떤 게임을 주로 하시나요?
# A: '리그 오브 레전드'라는 게임을 주로 합니다.
# B: 저는 보드게임을 좋아하는데, 보드게임에 대해서 어떻게 생각하시나요?
# A: 보드게임은 재미없어서 별로 안 좋아해요.
#
# ### 발화:
# B: 그럼 우리가 보드게임 파티를 열 때, 당신을 첫 번째로 초대하겠습니다.
#
# ### 답변:
# Sarcasm
# 상대방이 보드게임을 재미없어하는 것에 대해, 실제로는 부정적인 상황인데, 이 상황을 긍정적으로 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 그럼 우리가 보드게임 파티를 열 때, 당신을 첫 번째로 초대하겠습니다.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 어떤 음식을 좋아하시나요?
# B: 저는 다양한 음식을 좋아해요. 특히 해산물은 정말 좋아하는데요.
# A: 그럼 오늘 저녁은 해산물로 준비하면 좋겠군요.
#
# ### 발화:
# B: 아니요, 해산물은 좋아하는데 몸이 좀 안 좋아서요.
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 아니요, 해산물은 좋아하는데 몸이 좀 안 좋아서요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 고양이를 키우시나요?
# A: 네, 저희 집에는 3마리의 고양이가 있어요.
# B: 아, 고양이를 많이 좋아하시나 봐요.
# A: 그런데 그중 한 마리가 어제 집에서 도망쳤어요.
#
# ### 발화:
# B: 아, 고양이가 작은 모험을 즐기는구나.
#
# ### 답변:
# Sarcasm
# 실제로는 슬픈 상황인데, 그 상황을 즐거운 모험처럼 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 아, 고양이가 작은 모험을 즐기는구나.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 이번 콘서트에서 어떤 노래를 부르려고 계획하셨나요?
# B: 음... 제가 광고노래를 좋아해서 광고노래를 부르려고 생각 중이에요.
# A: 광고 노래요? 그런 노래들도 부르는군요.
# B: 네, 그런데 문제가 좀 있어요. 광고노래 들은 대부분 너무 짧아서...
#
# ### 발화:
# A: 아, 그럼 짧아서 좋잖아요. 한 곡을 여러 번 반복해서 부를 수 있으니까요.
#
# ### 답변:
# Sarcasm
# B가 광고노래가 짧아서 문제라고 했을 때, 실제로는 부정적인 상황인데, 이 상황을 긍정적인 방향으로 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 아, 그럼 짧아서 좋잖아요. 한 곡을 여러 번 반복해서 부를 수 있으니까요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 여름에는 어떤 음식을 좋아하시나요?
# B: 저는 생선회를 좋아합니다.
# A: 회는 정말 맛있죠. 특히, 여름에 먹으면 정말 상쾌하더라고요.
# B: 네, 저도 그래서 여름에는 회를 자주 먹는 편입니다.
# A: 회를 먹으면서 맥주 한잔하시는 건 어떠세요?
# B: 저는 술을 못 마셔서 그런 맛을 못 느껴봤네요.
#
# ### 발화:
# A: 그러면 당신은 국내 최고의 술꾼이 되겠네요.
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 그러면 당신은 국내 최고의 술꾼이 되겠네요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 요즘 코로나로 인해 여러모로 불편하시죠?
# A: 네, 그렇습니다. 가장 큰 문제는 남편의 일자리 상황입니다.
# B: 그렇군요. 남편님께서는 어떤 일을 하시나요?
# A: 회사원이었습니다. 하지만 코로나로 인해 회사가 어려워지면서 월급이 크게 줄었습니다.
#
# ### 발화:
# B: 월급이 줄어들면서 아끼는 습관을 길러보시는 것도 좋은 방법일지도 모르겠네요.
#
# ### 답변:
# Sarcasm
# 남편의 월급이 줄어들었다는 B의 말에 실제로는 부정적인 상황인데, 이 상황을 긍정적으로 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 월급이 줄어들면서 아끼는 습관을 길러보시는 것도 좋은 방법일지도 모르겠네요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 그 도박 게임 어땠어?
# B: 아니, 이게 뭐야. 그리스에서 했던 거 무효라고 하더라.
# A: 그게 뭐야? 그건 무슨 일이야?
# B: 불법 도박이라고 거절당했다니까.
#
# ### 발화:
# A: 와, 대박이다! 너는 진짜 운이 좋구나.
#
# ### 답변:
# Sarcasm
# 도박 게임이 불법 도박으로 판단되어 거절당했다는 상황을 상대방의 승리로 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 와, 대박이다! 너는 진짜 운이 좋구나.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 제주도와 여수, 어느 곳이 더 좋으신가요?
# B: 저는 여수가 더 좋습니다. 특히 낙지 요리를 맛보시면 좋을 것 같아요.
# A: 아, 그런데 제가 낙지를 좋아하지 않아요.
# B: 그럼 여수의 다른 맛집들을 추천드리겠습니다. 여수에는 낙지 말고도 맛있는 음식들이 많거든요.
#
# ### 발화:
# A: 당신은 정말 낙지 전문가네요.
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 당신은 정말 낙지 전문가네요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 유재석 씨의 프로그램을 좋아하시나요?
# B: 네, 그런데요. 유재석 씨가 출연하는 프로그램은 거의 다 보는 편입니다.
# A: 아, 그럼 런닝맨과 범인은 바로 너도 챙겨보시나요?
# B: 물론이죠. 둘 다 재밌습니다.
#
# ### 발화:
# A: 와, 유재석 팬클럽 회장님께서 이렇게 만나게 되다니 영광입니다.
#
# ### 답변:
# Sarcasm
# 상대방이 두 프로그램을 모두 재미있다고 했을 때, 이를 조금 과장하고 비꼬아 유재석 팬클럽 회장으로 만들어 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 와, 유재석 팬클럽 회장님께서 이렇게 만나게 되다니 영광입니다.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 최근에 어떤 활동들을 하고 계세요?
# B: 사실, 저는 동호회를 통해 여행을 자주 다니고 있어요.
# A: 정말요? 그럼 어디를 가장 최근에 방문하셨나요?
# B: 저는 제주도를 방문했어요. 근데, 날씨가 너무 흐려서 별로 보지 못했어요.
#
# ### 발화:
# A: 아, 그래도 눈이 편하셨겠어요.
#
# ### 답변:
# Sarcasm
# 제주도를 방문했지만 날씨가 흐려서 아무것도 보지 못한 상황을 비꼬아 아름다운 경치를 보지 않고도 좋다고 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 아, 그래도 눈이 편하셨겠어요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 요즘 어디로 여행 가고 싶어?
# B: 제주도 가고 싶은데, 돈이랑 시간이 없어서 가지 못하고 있어.
# A: 그래? 그럼 어떻게 해?
# B: 그냥 꿈꾸면서 지내야지.
#
# ### 발화:
# A: 아, 꿈꾸는 것도 좋지. 너의 꿈이 현실이 되길 바라겠어.
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 아, 꿈꾸는 것도 좋지. 너의 꿈이 현실이 되길 바라겠어.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 매운 음식을 좋아하시나요?
# B: 네, 저는 매운 음식을 정말 좋아합니다.
# A: 그렇군요. 그럼 어떤 음식이 가장 좋으신가요?
# B: 사실 저는 매운 것 중에서도 닭발을 가장 좋아합니다.
# A: 닭발이요? 그것은 정말 맵지 않나요?
# B: 아니요, 전 그 정도는 괜찮습니다. 오히려 매운맛이 제 기분을 풀어주는 것 같아요.
#
# ### 발화:
# A: 아하, 그럼 당신은 맵기의 여왕이시군요.
#
# ### 답변:
# Sarcasm
# A의 마지막 질문에 대해 B의 대답이 비현실적으로 느껴질 수 있기 때문에, 그것을 비꼬아 대답하는 것이다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 아하, 그럼 당신은 맵기의 여왕이시군요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 아침에 뭐 먹었어?
# B: 사과하고 초콜릿 먹었어.
# A: 그럼 점심에는 뭐 먹을 거야?
# B: 아마도 탕수육 먹을 것 같아.
# A: 저녁에는 뭐 먹을 거야?
# B: 친구들이랑 술 한잔하려고.
#
# ### 발화:
# A: 와, 네 건강한 식생활 진짜 부러워.
#
# ### 답변:
# Sarcasm
# 상대방이 건강에 안 좋은 식사 계획을 하고 있는데, 이를 긍정적인 측면으로 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 와, 네 건강한 식생활 진짜 부러워.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 너 왜 프로필 사진 바꿨어?
# B: 아니 나 좀 멋있게 보이려고 한 건데 왜?
# A: 아니 얼굴을 다 가린 사진으로 바꾸면 어떻게 멋있어 보인다는 거야?
# B: 그게 나름 스타일이지.
#
# ### 발화:
# A: 그래, 너 정말 멋있어 보여. 완전 스타 같아.
#
# ### 답변:
# Sarcasm
# B가 스타일이라고 말했지만, 실제로는 얼굴을 다 가린 사진이 스타일이라기보다는 비웃음을 사는 상황을 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 그래, 너 정말 멋있어 보여. 완전 스타 같아.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 저번에 그 기프티콘 사용해 보셨나요?
# A: 아직 못 썼습니다. 어떻게 사용하는지 모르겠어요.
# B: 장바구니에 원하는 물건을 넣고 결제 시에 코드를 입력하시면 됩니다.
#
# ### 발화:
# A: 그런데 제가 원하는 물건이 항상 장바구니에 없어서 기프티콘을 사용하지 못하고 있어요.
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 그런데 제가 원하는 물건이 항상 장바구니에 없어서 기프티콘을 사용하지 못하고 있어요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 저는 최근에 건강을 위해 영양제를 복용하고 있습니다.
# B: 어떤 영양제를 복용하고 계시나요?
# A: 종합 비타민, 오메가3, 비타민 D, 유산균, 그리고 루테인지 아잔 틴입니다.
# B: 헉! 그렇게 많은 걸 하루에 다 복용하시나요?
# A: 네, 그렇습니다. 건강을 위해서라면 뭐든지 해야죠.
#
# ### 발화:
# B: 아~ 그렇군요. 진짜 건강이 철벽같으시겠어요.
#
# ### 답변:
# Sarcasm
# 상대방이 건강을 위해 다양한 영양제를 복용하고 있다고 하였는데, 이런 상황을 실제로는 과도한 영양제 복용이 건강에 오히려 해로울 수 있다는 부정적인 상황을 긍정적으로 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 아~ 그렇군요. 진짜 건강이 철벽같으시겠어요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 공항 가는 거 어떻게 할 거야?
# A: 아직 안정했어. 차로 가면 편할 것 같긴 한데...
# B: 그럼 차로 가는 게 좋겠다. 근데 주차비는 어떻게 해?
# A: 그건 내가 낼게. 근데 주차비가 비싸긴 하더라...
#
# ### 발화:
# B: 그럼 우리 아끼는 거 아니라 네가 투자하는 거네, 멋져!
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 그럼 우리 아끼는 거 아니라 네가 투자하는 거네, 멋져!
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 최근에 무슨 게임을 즐기시나요?
# B: 요즘 유튜브에서 게임 관련 콘텐츠가 인기 있더군요. 그래서 말랑말랑 개그 게임과 폴가이즈 게임을 추천드립니다.
# A: 아, 그 두 게임은 협동 콘텐츠와 소통이 중요하다고 들었어요. 그런데 저는 사람들과 소통하는 것이 어려워서...
# B: 그렇다면, 혼자서 즐길 수 있는 게임을 찾아보는 것도 좋을 것 같네요.
#
# ### 발화:
# A: 아, 그럼 저 혼자서도 협동 콘텐츠를 즐길 수 있겠군요.
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 아, 그럼 저 혼자서도 협동 콘텐츠를 즐길 수 있겠군요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 어제 방 탈출 팸 갔다가 피아노 연주하는 거에 걸렸어.
# A: 그래서 어때? 잘했어?
# B: 아니, 도무지 손가락이 안 따라가더라고.
# A: 그럼 피아노 배우면 좋을 것 같아. 음악 감각 키울 수 있고.
#
# ### 발화:
# B: 음... 근데 시간이랑 비용이 좀 많이 들겠지?
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 음... 근데 시간이랑 비용이 좀 많이 들겠지?
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 오늘 저녁 식사는 어떠셨나요?
# A: 아, 네. 백신을 맞고 처음으로 든든히 식사를 했습니다.
# B: 그렇군요. 기분이 좋아 보이시네요. 디저트는 어떤 것을 좋아하시나요?
#
# ### 발화:
# A: 저는 요즘에 마카롱과 마들렌에 빠져있습니다.
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 저는 요즘에 마카롱과 마들렌에 빠져있습니다.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 이번에 '동백이'라는 드라마 보고 있어?
# B: 응. 보는 중인데 정말 재미있어.
# A: 그래? 나도 봐야겠다. 뭐가 재밌는데?
# B: 헉, 주인공이 너무 멋지고, 스토리도 흥미진진하거든.
#
# ### 발화:
# A: 그렇구나, 진짜 신선한 스토리야.
#
# ### 답변:
# Sarcasm
# 실제로는 주인공이 멋지지 않고 스토리도 지루한 것을 반대로 이야기하면서 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 그렇구나, 진짜 신선한 스토리야.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 어제저녁에 뭐 드셨어요?
# B: 아, 아폴로, 떡볶이, 맛 감자, 테이퍼 잼 튀김, 해시브라운 다 먹었어요.
# A: 그렇게 많은 것을 다 드셨나요? 소화는 잘 되셨나요?
# B: 음... 사실 소화가 잘 안되고 배가 아파서 잠을 못 잤어요.
#
# ### 발화:
# A: 오, 그럼 당신은 배탈로 새로운 다이어트 방법을 발견하셨군요.
#
# ### 답변:
# Sarcasm
# 사실상 너무 많은 음식을 먹어서 소화가 잘 안되고 배가 아프다는 상황은 부정적인 상황인데, 이를 긍정적으로 비꼬아 말한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 오, 그럼 당신은 배탈로 새로운 다이어트 방법을 발견하셨군요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# A: 오늘 날씨가 참 흐리네요.
# B: 네, 그렇습니다. 비도 좀 내리는 것 같아요.
# A: 그래도 빗물이 맑아져서 좋다는 사람도 있잖아요.
#
# ### 발화:
# B: 저는 오히려 흐린 날이 좋아요. 더운 날보다는 나을 것 같아요.
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 저는 오히려 흐린 날이 좋아요. 더운 날보다는 나을 것 같아요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 이번 추석에는 어떤 계획을 세우셨나요?
# A: 저희 가족은 보통 조상님들에게 차례를 지내고, 그다음에는 가족들과 함께 밖에 나가서 즐겁게 보내곤 합니다.
# B: 그런데 이번에는 코로나19로 인한 방역 정책으로 인해 모임을 자제하라는 권고가 있습니다.
#
# ### 발화:
# A: 네, 저희도 그 권고를 따르기로 결정했습니다. 오히려 이번 추석은 집에서 조용히 보낼 계획입니다.
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 네, 저희도 그 권고를 따르기로 결정했습니다. 오히려 이번 추석은 집에서 조용히 보낼 계획입니다.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 최근에 어떻게 지내셨나요?
# A: 요즘 작고 아기자기한 물건들로 일상의 평화를 찾고 있어요.
# B: 그게 어떤 것인지 좀 더 자세히 설명해 주실 수 있나요?
# A: 예를 들어, 아름다운 커피잔을 하나 샀는데요. 그런 것들이 저를 기분 좋게 해줘요.
# B: 그런 작은 행복이 참 좋네요. 저도 해보려고요.
#
# ### 발화:
# A: 아, 이제서야 발견하셨군요. 축하드립니다.
#
# ### 답변:
# Non-Sarcasm
#
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# A: 아, 이제서야 발견하셨군요. 축하드립니다.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 요즘 취업 시장은 어떤가요?
# A: 사람들이 스펙 경쟁을 많이 하더라고요. 실력 없는 사람들도 많이 지원하고요.
# B: 그렇군요. 그런데 그런 사람들이 취업을 하면 문제가 되지 않나요?
# A: 물론이죠. 특히 공무원들은 일을 제대로 안 하고 책임도 안 지더라고요.
#
# ### 발화:
# B: 아, 그렇군요. 그래도 우리나라 공무원들은 일 안 하는 걸로 유명하니까요.
#
# ### 답변:
# Sarcasm
# 공무원들이 일을 제대로 하지 않는다는 말에 비꼬아 말한다. 실제로는 부정적인 상황인데, 이를 긍정적인 방향으로 표현한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 아, 그렇군요. 그래도 우리나라 공무원들은 일 안 하는 걸로 유명하니까요.
#
# ### 답변:
#
# Generated prompt:
#  아래는 한국어 상황 'context'를 보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하고 이를 설명하는 답변을 작성해주세요.
#
# ### 상황:
# B: 수영은 어떻게 하시고 계시나요?
# A: 코로나 때문에 수영장 이용이 제한되어서 아무래도 운동은 좀 어려울 것 같아요.
# B: 아, 그렇군요. 그럼 다른 방법으로 운동하시는 건 어떨까요?
# A: 사실 그게 문제인데, 제가 운동을 좋아하지 않아서 수영 외에는 다른 운동을 잘 못하겠어요.
#
# ### 발화:
# B: 아, 그럼 여유로운 시간을 많이 가지게 되셨겠네요.
#
# ### 답변:
# Sarcasm
# 수영 외에는 다른 운동을 잘 못한다고 말하는 B의 대사에 대해 실제로는 부정적인 상황이지만, 이를 긍정적으로 해석하여 비꼬는 말을 한다.
# Generated prompt:
#  아래는 발화에 대한 상황을 추측해보고, 발화(말, 댓글 등)'response'에 대한 풍자 여부를 판별하는 예제입니다. 풍자를 판별하는 답변만 작성해주세요.
#
# ### 발화:
# B: 아, 그럼 여유로운 시간을 많이 가지게 되셨겠네요.
#
# ### 답변:
#
# Dataset({
#     features: ['input_ids', 'attention_mask', 'labels'],
#     num_rows: 10466
# })
# Dataset({
#     features: ['input_ids', 'attention_mask', 'labels'],
#     num_rows: 1321
# })
# Dataset({
#     features: ['input_ids', 'attention_mask', 'labels'],
#     num_rows: 1037
# })

# %% [markdown]
# #### ✅'prompt_input' example:
#
# ```
# 아래는 작업을 설명하는 지침과 추가 입력을 제공하는 입력이 짝을 이루는 예제입니다. 요청을 적절히 완료하는 답변을 작성해주세요.
#
# ### 지침:
# 다음 질문에 답하세요: 제목: 내가 본 최악의 영화 리뷰: 이것은 내가 본 최악의 영화입니다... DVD를 구입하는 유일한 이유는 이 영화를 만든 12살짜리 꼬마가 저능아 제작자에게 팔아넘긴 진짜 감독의 코멘터리를 공개하기 위해서입니다. 가장 좋은 부분은 비디오 게임 클립을 이어 붙인 것을 볼 때였을 것입니다. 이 상품평은 부정적인가요?
# 답변:
#
# ### 입력:
# 귀하는 지시를 매우 잘 따르는 인공지능 비서입니다. 최대한 많이 도와주세요.
#
# ### 답변:
# 예, 이 제품 리뷰는 부정적입니다.</s>
# ```

# %% [markdown]
# #### ✅'prompt_no_input' example:
#
# ```
# 아래는 작업을 설명하는 지침입니다. 요청을 적절히 완료하는 답변을 작성해주세요.
#
# ### 지침:
# x+y = 10$, $2x+y = 13$이 주어졌을 때, $x^2-y^2$를 평가합니다.
#
# ### 답변:
# x^2-y^2$를 풀려면 $x$와 $y$의 값을 찾아야 합니다. 주어진 방정식을 사용하여 변수 중 하나를 제거하고 다른 변수를 풀 수 있습니다. 첫 번째 방정식을 두 번째 방정식에서 빼면 $2x+y - (x+y) = 13-10$이 나오며, 이는 $x = 3$으로 단순화됩니다. 그런 다음 첫 번째 방정식을 사용하여 $x = 3$을 대입하면 $3+y = 10$을 얻을 수 있으며, 이는 $y = 7$이라는 것을 의미합니다. 이제 $x = 3$과 $y = 7$을 얻었으므로 이를 $x^2-y^2$로 대입할 수 있습니다. 이렇게 하면 $3^2-7^2 = 9-49 = -40$이 됩니다.</s>
# ```

# %% [markdown]
# --------
# # 🤗 Apply LoRA config
# > ❗우리가 훈련에 이용할 base LLM에 LoRA를 적용해봅시다!❗

# %%
###########################################
# 6-1. LoRA config 정의

config = LoraConfig(
    r=lora_r,
    lora_alpha=lora_alpha,
    target_modules=lora_target_modules,
    lora_dropout=lora_dropout,
    bias="none", # 모델 가중치 말고 쓰래쉬 홀드 같은거?
    task_type="CAUSAL_LM")

# %%
###########################################
# 6-2. Model with LoRA

model = prepare_model_for_kbit_training(model) # prepare_model_for_int8_training
model = get_peft_model(model, config) # Applying LoRA (모델에 LoRA config 적용)

# %% [markdown]
# --------
# # ⭐ LLM fine-tuning
# > 🥰 드디어 LLM fine-tuning을 위한 준비가 모두 끝났습니다! 한번 모델을 돌려볼까요?

# %%
###########################################
# 7-1. 만약 이전에 돌렸던 모델을 가져온다면, 아래의 코드 실행

if resume_from_checkpoint:
    checkpoint_name = os.path.join(
        resume_from_checkpoint, "pytorch_model.bin"
    )  # All checkpoint

    if not os.path.exists(checkpoint_name):
        checkpoint_name = os.path.join(
            resume_from_checkpoint, "adapter_model.bin"
        )  # only LoRA model
        resume_from_checkpoint = (
            True
        ) # kyujin: I will use this checkpoint

    if os.path.exists(checkpoint_name):
        print(f"Restarting from {checkpoint_name}")
        adapters_weights = torch.load(checkpoint_name)
        set_peft_model_state_dict(model, adapters_weights)

    else:
        print(f"Checkpoint {checkpoint_name} not found")
# Out:
# Checkpoint ./sarcasm_LLM/checkpoint-001/adapter_model.bin not found

# %%
###########################################
# 7-2. Trainer class 정의

trainer = transformers.Trainer(
        model=model,
        train_dataset=train_data,
        eval_dataset=val_data,
        args=transformers.TrainingArguments( # 훈련에 이용될 하이퍼파라미터
            per_device_train_batch_size = micro_batch,
            gradient_accumulation_steps = gradient_accumulation_steps,
            warmup_ratio=warmup_ratio, # 0.06
            num_train_epochs=num_epochs, # 1
            learning_rate=learning_rate,
            fp16=True,
            logging_steps=1,
            optim="adamw_torch",
            eval_strategy="epoch",
            save_strategy="steps",# step마다 모델 저장하겠다
            max_grad_norm = max_grad_norm,
            save_steps = 50, # you can change! 30 -> 50
            lr_scheduler_type=lr_scheduler,
            output_dir=output_dir,
            save_total_limit=2,
            load_best_model_at_end=False,
            ddp_find_unused_parameters=False,
            group_by_length = False
        ),
        data_collator=transformers.DataCollatorForSeq2Seq(
            tokenizer, pad_to_multiple_of=8, return_tensors="pt", padding=True
        ),
    )

model.config.use_cache = False
model.print_trainable_parameters() # 훈련하는 파라미터의 % 체크

if torch.__version__ >= "2" and sys.platform != "win32":
    model = torch.compile(model)
# Out:
# No label_names provided for model class `PeftModelForCausalLM`. Since `PeftModel` hides base models input arguments, if label_names is not given, label_names can't be set automatically within `Trainer`. Note that empty label_names list will be used instead.
# trainable params: 15,138,816 || all params: 3,227,888,640 || trainable%: 0.4690

# %%
###########################################
# 7-3. Training (fine-tuning)

## 훈련시간이 많이 소요됩니다! (~12h)
## 만약 중간에 colab이 끊긴다면, checkpoint를 이용해서 다시 훈련하세요!
### 만약 개인적인 GPU 자원이 있다면, 개인 서버나 컴퓨터에서 훈련시키는 것을 추천드립니다!
resume_from_checkpoint = None
torch.cuda.empty_cache()
trainer.train(resume_from_checkpoint=resume_from_checkpoint)
# Out:
# wandb: WARNING The `run_name` is currently set to the same value as `TrainingArguments.output_dir`. If this was not intended, please specify a different run name by setting the `TrainingArguments.run_name` parameter.
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: myoo-oong (myoo-oong-kyung-hee-university) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.19.10
# Run data is saved locally in <code>/content/drive/My Drive/Sarcasm-LLM/wandb/run-20250501_063051-gs4dekl1</code>
# Syncing run <strong><a href='https://wandb.ai/myoo-oong-kyung-hee-university/huggingface/runs/gs4dekl1' target="_blank">./custom_LLM</a></strong> to <a href='https://wandb.ai/myoo-oong-kyung-hee-university/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/myoo-oong-kyung-hee-university/huggingface' target="_blank">https://wandb.ai/myoo-oong-kyung-hee-university/huggingface</a>
#  View run at <a href='https://wandb.ai/myoo-oong-kyung-hee-university/huggingface/runs/gs4dekl1' target="_blank">https://wandb.ai/myoo-oong-kyung-hee-university/huggingface/runs/gs4dekl1</a>
# /usr/local/lib/python3.11/dist-packages/torch/_dynamo/eval_frame.py:745: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:315: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#     <div>
#
#       <progress value='327' max='327' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [327/327 1:26:44, Epoch 0/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.371400</td>
#       <td>1.442018</td>
#     </tr>
#   </tbody>
# </table><p>
# /usr/local/lib/python3.11/dist-packages/torch/_dynamo/eval_frame.py:745: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:315: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# /usr/local/lib/python3.11/dist-packages/torch/_dynamo/eval_frame.py:745: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:315: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# /usr/local/lib/python3.11/dist-packages/torch/_dynamo/eval_frame.py:745: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:315: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# /usr/local/lib/python3.11/dist-packages/torch/_dynamo/eval_frame.py:745: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:315: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# /usr/local/lib/python3.11/dist-packages/torch/_dynamo/eval_frame.py:745: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:315: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# /usr/local/lib/python3.11/dist-packages/torch/_dynamo/eval_frame.py:745: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:315: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# /usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:315: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# TrainOutput(global_step=327, training_loss=1.5761481559969235, metrics={'train_runtime': 5228.6521, 'train_samples_per_second': 2.002, 'train_steps_per_second': 0.063, 'total_flos': 3.567200740053811e+16, 'train_loss': 1.5761481559969235, 'epoch': 0.9998089050257978})

# %%
###########################################
# 7-4. 모델 저장

model.save_pretrained(output_dir)
model_path = os.path.join(output_dir, "pytorch_model.bin")
torch.save({}, model_path)
tokenizer.save_pretrained(output_dir)
# Out:
# ('./custom_LLM/tokenizer_config.json',
#  './custom_LLM/special_tokens_map.json',
#  './custom_LLM/tokenizer.json')

# %% [markdown]
# -------
# # 🤗 LoRA Adapter merge
# > 🎉 드디어 LLM fine-tuning이 끝났습니다! 여기까지 오시느라 정말 고생하셨습니다!! 🎉
# > 🔎 이제 훈련한 LoRA layer를 기존 base LLM에 붙여서 저장해볼까요!?

# %%
###########################################
# 8-1. 훈련된 LoRA layer와 base LLM 병합(merge)

torch.cuda.empty_cache()

base_model = AutoModelForCausalLM.from_pretrained(
    base_LLM_model,
    return_dict = True,
    torch_dtype=torch.float16,
    device_map=device)

model = PeftModel.from_pretrained(base_model, output_dir, device)
model = model.merge_and_unload() # Merge!
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
###########################################
# 8-2. 여러분의 custom LLM 모델 저장!

final_save_folder = './Sarcasm_LLM_FT'

model.save_pretrained(final_save_folder)
tokenizer.save_pretrained(final_save_folder)
# Out:
# ('./Sarcasm_LLM_FT/tokenizer_config.json',
#  './Sarcasm_LLM_FT/special_tokens_map.json',
#  './Sarcasm_LLM_FT/tokenizer.json')

# %% [markdown]
# -------
# # 🤗 HuggingFace에 모델 업로드
# > ✔️마지막으로, Huggingface에 자신의 모델을 직접 업로드를 해봅시다!
#
# 1. 코드에서 Huggingface login 진행합니다.
#   - HuggingFace에 다시 접속하여, access token 카테고리 접속한다.
#   - ⭐`Role: write`로 생성된 token을 복사 한 후, 아래의 `[...write_token...]` 부분에 붙여넣는다.
# ```
# !huggingface-cli login --token [...write_token...]
# ```
#   - ✅Huggingface에 접속하여, 모델을 업로드 할 repo를 생성한다.
#     - ✅사전에 제공된`README.md` 파일을 이용하여 자신의 model card를 작성한다.
#   - ✅아래의 코드를 이용하여 모델과 tokenizer를 업로드한다.
# ```
# model = AutoModelForCausalLM.from_pretrained("./custom_LLM_final")
# model.push_to_hub("[...repo_name...]", token=True)
# tokenizer = AutoTokenizer.from_pretrained("./custom_LLM_final")
# tokenizer.push_to_hub("[...repo_name...]", token=True)
# ```
#     - `repo_name` 부분에 자신이 만든 모델 repo 이름을 붙여넣는다.
#     - 만약 colab에서 모델 업로드가 안된다면, 구글 드라이브에서 직접 다운 받아서 repo에 올려주는 방법이 있다.
#
#
# 2. ✔️Huggingface repo에 업로드 된 모델 예시 이미지
# <img src = "https://drive.google.com/uc?id=1yiQv-SeN78H378oTO4UvzvEm4dG3mD0K"
# height = 512>

# %%
###########################################
# 9-1. 허깅페이스 로그인

# WRITE token
# !huggingface-cli login --token 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 # your code
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: write).
# The token `Upstage_write` has been saved to /root/.cache/huggingface/stored_tokens
# Your token has been saved to /root/.cache/huggingface/token
# Login successful.
# The current active token is: `Upstage_write`

# %%
###########################################
# 9-2. 모델 업로드 (~10분)
## 먼저, 허깅페이스에 모델 repo를 만든 후 코드를 실행해야 합니다!

model = AutoModelForCausalLM.from_pretrained(final_save_folder)
model.push_to_hub('myoo-oong/Korean-Sarcasm-LLM-llama-3.2-Korean-Bllossom-3B', token=True)
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00002-of-00003.safetensors:   0%|          | 0.00/4.93G [00:00<?, ?B/s]
# model-00003-of-00003.safetensors:   0%|          | 0.00/2.92G [00:00<?, ?B/s]
# Upload 3 LFS files:   0%|          | 0/3 [00:00<?, ?it/s]
# model-00001-of-00003.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/myoo-oong/Korean-Sarcasm-LLM-llama-3.2-Korean-Bllossom-3B/commit/712df476937f674908b255b86f99849d6e841e96', commit_message='Upload LlamaForCausalLM', commit_description='', oid='712df476937f674908b255b86f99849d6e841e96', pr_url=None, repo_url=RepoUrl('https://huggingface.co/myoo-oong/Korean-Sarcasm-LLM-llama-3.2-Korean-Bllossom-3B', endpoint='https://huggingface.co', repo_type='model', repo_id='myoo-oong/Korean-Sarcasm-LLM-llama-3.2-Korean-Bllossom-3B'), pr_revision=None, pr_num=None)

# %%
###########################################
# 9-3. Tokenizer 업로드

tokenizer = AutoTokenizer.from_pretrained(final_save_folder)
tokenizer.push_to_hub('myoo-oong/Korean-Sarcasm-LLM-llama-3.2-Korean-Bllossom-3B', token=True)
# Out:
# README.md:   0%|          | 0.00/5.17k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.2M [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/myoo-oong/Korean-Sarcasm-LLM-llama-3.2-Korean-Bllossom-3B/commit/a741de132ea5b266d8d720ab7bea7f500357cac5', commit_message='Upload tokenizer', commit_description='', oid='a741de132ea5b266d8d720ab7bea7f500357cac5', pr_url=None, repo_url=RepoUrl('https://huggingface.co/myoo-oong/Korean-Sarcasm-LLM-llama-3.2-Korean-Bllossom-3B', endpoint='https://huggingface.co', repo_type='model', repo_id='myoo-oong/Korean-Sarcasm-LLM-llama-3.2-Korean-Bllossom-3B'), pr_revision=None, pr_num=None)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# -------
# # 🤗 Huggingface LLM 리더보드 실습
# > 🎉여기까지 여러분만의 custom LLM을 만들고 huggingface에 직접 올리는 실습 진행했습니다!!🎉
# > 💡자신이 만든 모델을 LLM 리더보드에 올려서 성능평가를 진행하고, 분석을 같이 해봅시다!
#
# - [En-LLM 리더보드](https://huggingface.co/spaces/HuggingFaceH4/open_llm_leaderboard)
# - [Ko-LLM 리더보드](https://huggingface.co/spaces/upstage/open-ko-llm-leaderboard)
